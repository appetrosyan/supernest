# %% [markdown]
# # Example of `supernest` + `polychord`
#
# ## Background
#
# `supernest` is meant to accelerate nested sampling via use of covariance matrices, which are usually provided by inference packages such as `cobaya` (TODO link). Supernest's design goals were to make the process seamless and work regardless of the nested sampler (or mcmc-sampler) in use.
#
# For these purposes, we shall first do a run of a simulated cosmological likelihood (27 dimensions, 53 total parameters, Gaussian approximation of the covariance structure), and then produce the same result with supernest.
#
# We shall track the acccuracy of the result with the *evidence* ($\log \mathcal{Z}$), and the performance increase via the number of likelihood evaluations. Additionally, *triangle plots* of the posterior distribution shall be provided to contrast the behaviour.

# %% [markdown]
# <html><head><meta name="qrichtext" content="1" /><style type="text/css">
# p, li { white-space: pre-wrap; }
# </style></head><body style=" font-family:'Hack'; font-size:10pt; font-weight:400; font-style:normal;">
# <p style=" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;">Firstly, let's install the dependencies. </p></body></html>

# %%
# !pip3 install supernest anesthetic mpi4py
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: supernest in /mnt/Archive/Git/sspr (3.4.0)
# Requirement already satisfied: anesthetic in /home/app/.local/lib/python3.9/site-packages (2.0.0b9)
# Requirement already satisfied: mpi4py in /home/app/.local/lib/python3.9/site-packages (3.1.1)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/app/.local/lib/python3.9/site-packages (from anesthetic) (3.4.2)
# Requirement already satisfied: numpy in /usr/lib/python3.9/site-packages (from anesthetic) (1.21.1)
# Requirement already satisfied: pandas>=1.1.0 in /home/app/.local/lib/python3.9/site-packages (from anesthetic) (1.3.3)
# Requirement already satisfied: scipy>=1.2.0 in /usr/lib/python3.9/site-packages (from anesthetic) (1.7.1)
# Requirement already satisfied: cycler>=0.10 in /home/app/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (2.4.7)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (2.8.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (8.3.2)
# Requirement already satisfied: six in /usr/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.3.0->anesthetic) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3.9/site-packages (from pandas>=1.1.0->anesthetic) (2021.1)

# %% [markdown]
# <html><head><meta name="qrichtext" content="1" /><style type="text/css">
# p, li { white-space: pre-wrap; }
# </style></head><body style=" font-family:'Hack'; font-size:10pt; font-weight:400; font-style:normal;">
# <p style=" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;">Secondly, install PolyChord</p></body></html>

# %%
# !pip3 install https://github.com/PolyChord/PolyChordLite/archive/master.zip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting https://github.com/PolyChord/PolyChordLite/archive/master.zip
#   Using cached https://github.com/PolyChord/PolyChordLite/archive/master.zip
# Requirement already satisfied: numpy in /usr/lib/python3.9/site-packages (from pypolychord==1.18.2) (1.21.1)
# Requirement already satisfied: scipy in /usr/lib/python3.9/site-packages (from pypolychord==1.18.2) (1.7.1)

# %% [markdown]
# <html><head><meta name="qrichtext" content="1" /><style type="text/css">
# p, li { white-space: pre-wrap; }
# </style></head><body style=" font-family:'Hack'; font-size:10pt; font-weight:400; font-style:normal;">
# <p style=" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;">Finally, let us import the prior bounds: </p></body></html>

# %%
import numpy as np

# %%
bounds = np.array([[1.610000000000000098e+00, 3.910000000000000142e+00],
                  [8.000000000000000444e-01, 1.199999999999999956e+00],
                  [5.000000000000000000e-01, 1.000000000000000000e+01],
                  [5.000000000000000104e-03, 1.000000000000000056e-01],
                  [1.000000000000000021e-03, 9.899999999999999911e-01],
                  [1.000000000000000021e-02, 8.000000000000000444e-01],
                  [9.874342179098187788e-01, 1.012565782090074640e+00],
                  [9.966815810147492405e-01, 1.003718418985220850e+00],
                  [9.947828966565528397e-01, 1.001317103343419390e+00],
                  [0.000000000000000000e+00, 2.000000000000000000e+02],
                  [0.000000000000000000e+00, 1.000000000000000000e+00],
                  [0.000000000000000000e+00, 1.000000000000000000e+01],
                  [0.000000000000000000e+00, 1.000000000000000000e+01],
                  [-1.452625672144938207e+00, 1.865262567205973454e+01],
                  [5.473743278550617930e-01, 2.065262567205973454e+01],
                  [-1.922365910661598321e+01, 6.622365910625386221e+01],
                  [-8.626256721449379938e+00, 1.924262567205973369e+02],
                  [0.000000000000000000e+00, 4.000000000000000000e+02],
                  [0.000000000000000000e+00, 4.000000000000000000e+02],
                  [0.000000000000000000e+00, 4.000000000000000000e+02],
                  [0.000000000000000000e+00, 4.000000000000000000e+02],
                  [-8.110513911504371731e-02, 3.411051391132544075e-01],
                  [-5.094726209860886423e-02, 3.109472620970751833e-01],
                  [7.631844753477834420e-03, 9.123681552426879948e-01],
                  [-1.548945241972177478e-01, 5.688945241941503195e-01],
                  [2.376318447534777611e-01, 1.142368155242687866e+00],
                  [-7.762089314791336125e-01, 4.652208931456128127e+00]])

# %% [markdown]
# <html><head><meta name="qrichtext" content="1" /><style type="text/css">
# p, li { white-space: pre-wrap; }
# </style></head><body style=" font-family:'Hack'; font-size:10pt; font-weight:400; font-style:normal;">
# <p style=" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;">The model covariance matrix: </p></body></html>

# %%
covs = np.array([[1.966721383534008152e-04, 1.291097180639769482e-05, 5.693634640132524955e-07, 4.772209314169435741e-07, -4.496445527830370466e-06, 9.322408552378461512e-05, 9.421926820888628024e-06, 1.100375630390723051e-07, -1.098063919659239207e-07, -1.867817278813608617e-03, 1.945019518484858000e-04, 6.804441695333571802e-04, -1.743706029095589251e-03, 2.398915556636300149e-04, -3.089237148441134921e-04, -5.392956974194408485e-04, 7.206579943931729288e-04, -1.219105224558518150e-02, -5.581079408533948932e-03, 1.605451063743458572e-03, 2.727571544902513984e-03, -3.428669328492376554e-07, -1.074672941406098990e-05, 2.691855891555073173e-05, -2.767183985449993394e-05, -6.780842674588625166e-06, -5.885254697216294113e-05],
# %% [markdown]
# <html><head><meta name="qrichtext" content="1" /><style type="text/css">
# p, li { white-space: pre-wrap; }
# </style></head><body style=" font-family:'Hack'; font-size:10pt; font-weight:400; font-style:normal;">
# <p style=" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;">And finally, the most important variable: the means. </p></body></html>

# %%
means  = np.array([3.044216694712165161e+00,
9.650855758442943300e-01,
1.040924144831850029e+00,
2.237283121732486224e-02,
1.200560651155456460e-01,
5.410301296354644296e-02,
1.000634474760722314e+00,
9.996787729141320966e-01,
9.981818020437438488e-01,
4.678440579185234327e+01,
5.244381951336937187e-01,
5.479402746454355544e+00,
3.268370700471646462e+00,
8.920107392228670662e+00,
1.091392531032157187e+01,
1.865309777799564728e+01,
9.375259342019231212e+01,
2.585815407864638473e+02,
4.590609762313613373e+01,
4.226589856534864253e+01,
1.150610766831279932e+02,
1.140319089380447543e-01,
1.349241126954108805e-01,
4.812167446020677031e-01,
2.250448376583276677e-01,
6.657249956786769340e-01,
2.083381582310556812e+00])

# %%
import pypolychord as pp
from pypolychord.settings import PolyChordSettings as Settings
from mpi4py import MPI

# %% [markdown]
# <html><head><meta name="qrichtext" content="1" /><style type="text/css">
# p, li { white-space: pre-wrap; }
# </style></head><body style=" font-family:'Hack'; font-size:10pt; font-weight:400; font-style:normal;">
# <p style=" margin-top:0px; margin-bottom:0px; margin-left:0px; margin-right:0px; -qt-block-indent:0; text-indent:0px;">We create convenience methods for generating the prior and the likelihood as a tuple. </p></body></html>

# %%
def generate_model(bounds, means, covs):
    thetamin, thetamax = bounds[:,0], bounds[:,1]
    invCov = np.linalg.inv(covs)

    def prior(cube):
        return thetamin + cube * (thetamax - thetamin)

    def log_likelihood(theta):
        return (-(theta - means) @ invCov @ (theta - means) / 2.0 , [])

    return prior, log_likelihood

# %% [markdown]
# Set up some settings. Most defaults are fine, although the execution could take a while, so we will change the `nlive` variable.

# %%
settings = Settings(len(means), 0)
settings.file_root = "control"
settings.nlive = 200

# %%
control = generate_model(bounds, means, covs)

# %%
output = {"control": pp.run_polychord(control[1], len(means), 0, settings, prior=control[0])}
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     200
# nDims    :      27
# nDerived :       0
# Doing Clustering
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file tochains/control.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.342E-04 seconds
# number of repeats:          135
# started sampling
#
# __________________
# lives      |  200 |
# phantoms   |16958 |
# posteriors |  201 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 201
# nposterior =                 201
# nequals    =                   1
# nlike      =               32282
# <nlike>    =         160.41   (           1.19 per slice )
# log(Z)     =    -89993304.44 +/-  0.83
# log(Z_1)   =    -89993304.44 +/-  0.83 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |23071 |
# posteriors |  402 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 402
# nposterior =                 402
# nequals    =                   1
# nlike      =               74501
# <nlike>    =         211.09   (           1.56 per slice )
# log(Z)     =     -8692326.29 +/-  0.84
# log(Z_1)   =     -8692326.29 +/-  0.84 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25129 |
# posteriors |  603 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 603
# nposterior =                 603
# nequals    =                   1
# nlike      =              117753
# <nlike>    =         216.26   (           1.60 per slice )
# log(Z)     =     -2006117.55 +/-  0.84
# log(Z_1)   =     -2006117.55 +/-  0.84 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26658 |
# posteriors |  804 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 804
# nposterior =                 804
# nequals    =                   1
# nlike      =              161946
# <nlike>    =         220.97   (           1.64 per slice )
# log(Z)     =      -947250.07 +/-  0.84
# log(Z_1)   =      -947250.07 +/-  0.84 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26955 |
# posteriors | 1005 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1005
# nposterior =                1005
# nequals    =                   1
# nlike      =              206633
# <nlike>    =         223.44   (           1.66 per slice )
# log(Z)     =      -487469.38 +/-  0.84
# log(Z_1)   =      -487469.38 +/-  0.84 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25322 |
# posteriors | 1206 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1206
# nposterior =                1206
# nequals    =                   1
# nlike      =              250721
# <nlike>    =         220.44   (           1.63 per slice )
# log(Z)     =      -236240.88 +/-  0.85
# log(Z_1)   =      -236240.88 +/-  0.85 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26781 |
# posteriors | 1407 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1407
# nposterior =                1407
# nequals    =                   1
# nlike      =              295931
# <nlike>    =         226.05   (           1.67 per slice )
# log(Z)     =      -124652.62 +/-  0.85
# log(Z_1)   =      -124652.62 +/-  0.85 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29037 |
# posteriors | 1608 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1608
# nposterior =                1608
# nequals    =                   1
# nlike      =              341512
# <nlike>    =         227.91   (           1.69 per slice )
# log(Z)     =       -74323.63 +/-  0.85
# log(Z_1)   =       -74323.63 +/-  0.85 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28312 |
# posteriors | 1809 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1809
# nposterior =                1809
# nequals    =                   1
# nlike      =              388142
# <nlike>    =         233.15   (           1.73 per slice )
# log(Z)     =       -43952.34 +/-  0.86
# log(Z_1)   =       -43952.34 +/-  0.86 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25865 |
# posteriors | 2010 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2010
# nposterior =                2010
# nequals    =                   1
# nlike      =              435640
# <nlike>    =         237.49   (           1.76 per slice )
# log(Z)     =       -27185.76 +/-  0.86
# log(Z_1)   =       -27185.76 +/-  0.86 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |24216 |
# posteriors | 2211 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2211
# nposterior =                2211
# nequals    =                   1
# nlike      =              483969
# <nlike>    =         241.65   (           1.79 per slice )
# log(Z)     =       -17994.35 +/-  0.86
# log(Z_1)   =       -17994.35 +/-  0.86 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27705 |
# posteriors | 2412 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2412
# nposterior =                2412
# nequals    =                   2
# nlike      =              533500
# <nlike>    =         247.66   (           1.83 per slice )
# log(Z)     =       -13493.16 +/-  0.68
# log(Z_1)   =       -13493.16 +/-  0.68 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27608 |
# posteriors | 2613 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2613
# nposterior =                2613
# nequals    =                   1
# nlike      =              583714
# <nlike>    =         251.07   (           1.86 per slice )
# log(Z)     =       -10236.54 +/-  0.87
# log(Z_1)   =       -10236.54 +/-  0.87 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26738 |
# posteriors | 2814 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2814
# nposterior =                2814
# nequals    =                   1
# nlike      =              634507
# <nlike>    =         253.97   (           1.88 per slice )
# log(Z)     =        -7988.27 +/-  0.87
# log(Z_1)   =        -7988.27 +/-  0.87 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26349 |
# posteriors | 3015 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3015
# nposterior =                3015
# nequals    =                   1
# nlike      =              686503
# <nlike>    =         259.98   (           1.93 per slice )
# log(Z)     =        -6257.21 +/-  0.87
# log(Z_1)   =        -6257.21 +/-  0.87 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26365 |
# posteriors | 3216 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3216
# nposterior =                3216
# nequals    =                   2
# nlike      =              738715
# <nlike>    =         261.06   (           1.93 per slice )
# log(Z)     =        -5010.82 +/-  0.69
# log(Z_1)   =        -5010.82 +/-  0.69 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27246 |
# posteriors | 3417 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3417
# nposterior =                3417
# nequals    =                   1
# nlike      =              791401
# <nlike>    =         263.43   (           1.95 per slice )
# log(Z)     =        -4026.38 +/-  0.88
# log(Z_1)   =        -4026.38 +/-  0.88 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27712 |
# posteriors | 3618 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3618
# nposterior =                3618
# nequals    =                   1
# nlike      =              844155
# <nlike>    =         263.77   (           1.95 per slice )
# log(Z)     =        -3319.33 +/-  0.85
# log(Z_1)   =        -3319.33 +/-  0.85 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27451 |
# posteriors | 3819 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3819
# nposterior =                3819
# nequals    =                   1
# nlike      =              898351
# <nlike>    =         270.98   (           2.01 per slice )
# log(Z)     =        -2718.22 +/-  0.88
# log(Z_1)   =        -2718.22 +/-  0.88 (still evaluating)
# __________________
# lives      |  200 |
# phantoms   |25123 |
# posteriors | 4020 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4020
# nposterior =                4020
# nequals    =                   1
# nlike      =              952628
# <nlike>    =         271.38   (           2.01 per slice )
# log(Z)     =        -2196.37 +/-  0.72
# log(Z_1)   =        -2196.37 +/-  0.72 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25834 |
# posteriors | 4221 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4221
# nposterior =                4221
# nequals    =                   1
# nlike      =             1007266
# <nlike>    =         273.19   (           2.02 per slice )
# log(Z)     =        -1816.03 +/-  0.78
# log(Z_1)   =        -1816.03 +/-  0.78 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26786 |
# posteriors | 4422 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4422
# nposterior =                4422
# nequals    =                   1
# nlike      =             1062431
# <nlike>    =         275.82   (           2.04 per slice )
# log(Z)     =        -1499.69 +/-  0.87
# log(Z_1)   =        -1499.69 +/-  0.87 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29072 |
# posteriors | 4623 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4623
# nposterior =                4623
# nequals    =                   1
# nlike      =             1117908
# <nlike>    =         277.38   (           2.05 per slice )
# log(Z)     =        -1272.50 +/-  0.75
# log(Z_1)   =        -1272.50 +/-  0.75 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28377 |
# posteriors | 4824 |
# equals     |    3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4824
# nposterior =                4824
# nequals    =                   4
# nlike      =             1174486
# <nlike>    =         282.89   (           2.10 per slice )
# log(Z)     =        -1068.20 +/-  0.59
# log(Z_1)   =        -1068.20 +/-  0.59 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26459 |
# posteriors | 5025 |
# equals     |    4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5025
# nposterior =                5025
# nequals    =                   1
# nlike      =             1231544
# <nlike>    =         285.29   (           2.11 per slice )
# log(Z)     =         -895.26 +/-  0.63
# log(Z_1)   =         -895.26 +/-  0.63 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26540 |
# posteriors | 5226 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5226
# nposterior =                5226
# nequals    =                   2
# nlike      =             1288509
# <nlike>    =         284.82   (           2.11 per slice )
# log(Z)     =         -755.34 +/-  0.60
# log(Z_1)   =         -755.34 +/-  0.60 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28315 |
# posteriors | 5427 |
# equals     |    6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5427
# nposterior =                5427
# nequals    =                   2
# nlike      =             1346375
# <nlike>    =         289.33   (           2.14 per slice )
# log(Z)     =         -647.08 +/-  0.54
# log(Z_1)   =         -647.08 +/-  0.54 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26324 |
# posteriors | 5628 |
# equals     |    3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5628
# nposterior =                5628
# nequals    =                   2
# nlike      =             1404956
# <nlike>    =         292.91   (           2.17 per slice )
# log(Z)     =         -550.90 +/-  0.60
# log(Z_1)   =         -550.90 +/-  0.60 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |24638 |
# posteriors | 5829 |
# equals     |    4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5829
# nposterior =                5829
# nequals    =                   1
# nlike      =             1465137
# <nlike>    =         300.91   (           2.23 per slice )
# log(Z)     =         -470.08 +/-  0.55
# log(Z_1)   =         -470.08 +/-  0.55 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |24728 |
# posteriors | 6030 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6030
# nposterior =                6030
# nequals    =                   3
# nlike      =             1526529
# <nlike>    =         306.96   (           2.27 per slice )
# log(Z)     =         -406.84 +/-  0.52
# log(Z_1)   =         -406.84 +/-  0.52 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26986 |
# posteriors | 6231 |
# equals     |    6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6231
# nposterior =                6231
# nequals    =                   6
# nlike      =             1589036
# <nlike>    =         312.54   (           2.32 per slice )
# log(Z)     =         -362.53 +/-  0.50
# log(Z_1)   =         -362.53 +/-  0.50 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28234 |
# posteriors | 6432 |
# equals     |   11 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6432
# nposterior =                6432
# nequals    =                  12
# nlike      =             1652927
# <nlike>    =         319.45   (           2.37 per slice )
# log(Z)     =         -325.42 +/-  0.48
# log(Z_1)   =         -325.42 +/-  0.48 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28037 |
# posteriors | 6633 |
# equals     |    8 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6633
# nposterior =                6633
# nequals    =                   8
# nlike      =             1719281
# <nlike>    =         331.77   (           2.46 per slice )
# log(Z)     =         -293.48 +/-  0.49
# log(Z_1)   =         -293.48 +/-  0.49 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28522 |
# posteriors | 6834 |
# equals     |   14 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6834
# nposterior =                6834
# nequals    =                  13
# nlike      =             1787364
# <nlike>    =         340.42   (           2.52 per slice )
# log(Z)     =         -267.46 +/-  0.47
# log(Z_1)   =         -267.46 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29080 |
# posteriors | 7035 |
# equals     |    9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7035
# nposterior =                7035
# nequals    =                   7
# nlike      =             1857487
# <nlike>    =         350.62   (           2.60 per slice )
# log(Z)     =         -244.45 +/-  0.46
# log(Z_1)   =         -244.45 +/-  0.46 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29454 |
# posteriors | 7236 |
# equals     |   10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7236
# nposterior =                7236
# nequals    =                  10
# nlike      =             1929309
# <nlike>    =         359.11   (           2.66 per slice )
# log(Z)     =         -225.24 +/-  0.47
# log(Z_1)   =         -225.24 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |30734 |
# posteriors | 7437 |
# equals     |   13 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7437
# nposterior =                7437
# nequals    =                  16
# nlike      =             2002866
# <nlike>    =         367.79   (           2.72 per slice )
# log(Z)     =         -209.31 +/-  0.47
# log(Z_1)   =         -209.31 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27868 |
# posteriors | 7638 |
# equals     |   14 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7638
# nposterior =                7638
# nequals    =                  15
# nlike      =             2078707
# <nlike>    =         379.20   (           2.81 per slice )
# log(Z)     =         -193.14 +/-  0.47
# log(Z_1)   =         -193.14 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26782 |
# posteriors | 7839 |
# equals     |   20 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7839
# nposterior =                7839
# nequals    =                  16
# nlike      =             2158015
# <nlike>    =         396.54   (           2.94 per slice )
# log(Z)     =         -178.20 +/-  0.47
# log(Z_1)   =         -178.20 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28248 |
# posteriors | 8040 |
# equals     |   19 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                8040
# nposterior =                8040
# nequals    =                  20
# nlike      =             2240386
# <nlike>    =         411.86   (           3.05 per slice )
# log(Z)     =         -167.33 +/-  0.47
# log(Z_1)   =         -167.33 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25718 |
# posteriors | 8241 |
# equals     |   16 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                8241
# nposterior =                8241
# nequals    =                  16
# nlike      =             2326458
# <nlike>    =         430.36   (           3.19 per slice )
# log(Z)     =         -156.16 +/-  0.47
# log(Z_1)   =         -156.16 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27554 |
# posteriors | 8442 |
# equals     |   31 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                8442
# nposterior =                8442
# nequals    =                  26
# nlike      =             2414341
# <nlike>    =         439.42   (           3.25 per slice )
# log(Z)     =         -147.39 +/-  0.47
# log(Z_1)   =         -147.39 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28111 |
# posteriors | 8643 |
# equals     |   33 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                8643
# nposterior =                8643
# nequals    =                  33
# nlike      =             2505104
# <nlike>    =         453.81   (           3.36 per slice )
# log(Z)     =         -139.28 +/-  0.47
# log(Z_1)   =         -139.28 +/-  0.47 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28022 |
# posteriors | 8844 |
# equals     |   29 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                8844
# nposterior =                8844
# nequals    =                  27
# nlike      =             2599168
# <nlike>    =         470.32   (           3.48 per slice )
# log(Z)     =         -132.77 +/-  0.48
# log(Z_1)   =         -132.77 +/-  0.48 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27846 |
# posteriors | 9045 |
# equals     |   32 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                9045
# nposterior =                9045
# nequals    =                  32
# nlike      =             2695395
# <nlike>    =         481.13   (           3.56 per slice )
# log(Z)     =         -126.64 +/-  0.48
# log(Z_1)   =         -126.64 +/-  0.48 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27614 |
# posteriors | 9246 |
# equals     |   33 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                9246
# nposterior =                9246
# nequals    =                  45
# nlike      =             2795570
# <nlike>    =         500.88   (           3.71 per slice )
# log(Z)     =         -121.11 +/-  0.49
# log(Z_1)   =         -121.11 +/-  0.49 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26744 |
# posteriors | 9447 |
# equals     |   49 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                9447
# nposterior =                9447
# nequals    =                  36
# nlike      =             2897852
# <nlike>    =         511.41   (           3.79 per slice )
# log(Z)     =         -115.88 +/-  0.49
# log(Z_1)   =         -115.88 +/-  0.49 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26990 |
# posteriors | 9648 |
# equals     |   43 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                9648
# nposterior =                9648
# nequals    =                  42
# nlike      =             3003758
# <nlike>    =         529.53   (           3.92 per slice )
# log(Z)     =         -111.40 +/-  0.49
# log(Z_1)   =         -111.40 +/-  0.49 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27762 |
# posteriors | 9849 |
# equals     |   55 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                9849
# nposterior =                9849
# nequals    =                  55
# nlike      =             3112013
# <nlike>    =         541.27   (           4.01 per slice )
# log(Z)     =         -107.68 +/-  0.50
# log(Z_1)   =         -107.68 +/-  0.50 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28119 |
# posteriors |10050 |
# equals     |   63 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               10050
# nposterior =               10050
# nequals    =                  57
# nlike      =             3221736
# <nlike>    =         548.62   (           4.06 per slice )
# log(Z)     =         -104.17 +/-  0.50
# log(Z_1)   =         -104.17 +/-  0.50 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29281 |
# posteriors |10251 |
# equals     |   76 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               10251
# nposterior =               10251
# nequals    =                  75
# nlike      =             3332236
# <nlike>    =         552.50   (           4.09 per slice )
# log(Z)     =         -101.35 +/-  0.50
# log(Z_1)   =         -101.35 +/-  0.50 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |30033 |
# posteriors |10452 |
# equals     |   95 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               10452
# nposterior =               10452
# nequals    =                  94
# nlike      =             3445101
# <nlike>    =         564.33   (           4.18 per slice )
# log(Z)     =          -98.72 +/-  0.51
# log(Z_1)   =          -98.72 +/-  0.51 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27811 |
# posteriors |10653 |
# equals     |   77 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               10653
# nposterior =               10653
# nequals    =                  76
# nlike      =             3560119
# <nlike>    =         575.09   (           4.26 per slice )
# log(Z)     =          -96.41 +/-  0.51
# log(Z_1)   =          -96.41 +/-  0.51 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27889 |
# posteriors |10854 |
# equals     |   99 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               10854
# nposterior =               10854
# nequals    =                 100
# nlike      =             3676395
# <nlike>    =         581.38   (           4.31 per slice )
# log(Z)     =          -93.96 +/-  0.52
# log(Z_1)   =          -93.96 +/-  0.52 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27012 |
# posteriors |11055 |
# equals     |   99 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               11055
# nposterior =               11055
# nequals    =                 112
# nlike      =             3793374
# <nlike>    =         584.89   (           4.33 per slice )
# log(Z)     =          -91.79 +/-  0.52
# log(Z_1)   =          -91.79 +/-  0.52 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29431 |
# posteriors |11256 |
# equals     |  125 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               11256
# nposterior =               11256
# nequals    =                 121
# nlike      =             3911568
# <nlike>    =         590.97   (           4.38 per slice )
# log(Z)     =          -90.21 +/-  0.52
# log(Z_1)   =          -90.21 +/-  0.52 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29290 |
# posteriors |11457 |
# equals     |  137 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               11457
# nposterior =               11457
# nequals    =                 127
# nlike      =             4030928
# <nlike>    =         596.80   (           4.42 per slice )
# log(Z)     =          -88.86 +/-  0.53
# log(Z_1)   =          -88.86 +/-  0.53 (still evaluating)
# __________________
# lives      |  200 |
# phantoms   |28412 |
# posteriors |11658 |
# equals     |  152 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               11658
# nposterior =               11658
# nequals    =                 166
# nlike      =             4150829
# <nlike>    =         599.50   (           4.44 per slice )
# log(Z)     =          -87.53 +/-  0.53
# log(Z_1)   =          -87.53 +/-  0.53 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25727 |
# posteriors |11859 |
# equals     |  141 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               11859
# nposterior =               11859
# nequals    =                 165
# nlike      =             4272418
# <nlike>    =         607.95   (           4.50 per slice )
# log(Z)     =          -86.22 +/-  0.54
# log(Z_1)   =          -86.22 +/-  0.54 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25809 |
# posteriors |12060 |
# equals     |  163 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               12060
# nposterior =               12060
# nequals    =                 178
# nlike      =             4393554
# <nlike>    =         605.68   (           4.49 per slice )
# log(Z)     =          -85.03 +/-  0.54
# log(Z_1)   =          -85.03 +/-  0.54 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25380 |
# posteriors |12261 |
# equals     |  183 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               12261
# nposterior =               12261
# nequals    =                 192
# nlike      =             4515689
# <nlike>    =         610.68   (           4.52 per slice )
# log(Z)     =          -83.99 +/-  0.54
# log(Z_1)   =          -83.99 +/-  0.54 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26971 |
# posteriors |12462 |
# equals     |  235 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               12462
# nposterior =               12462
# nequals    =                 269
# nlike      =             4638595
# <nlike>    =         614.53   (           4.55 per slice )
# log(Z)     =          -83.09 +/-  0.55
# log(Z_1)   =          -83.09 +/-  0.55 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29917 |
# posteriors |12663 |
# equals     |  345 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               12663
# nposterior =               12663
# nequals    =                 367
# nlike      =             4763122
# <nlike>    =         622.63   (           4.61 per slice )
# log(Z)     =          -82.46 +/-  0.55
# log(Z_1)   =          -82.46 +/-  0.55 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25788 |
# posteriors |12864 |
# equals     |  330 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               12864
# nposterior =               12864
# nequals    =                 326
# nlike      =             4886864
# <nlike>    =         618.71   (           4.58 per slice )
# log(Z)     =          -81.93 +/-  0.55
# log(Z_1)   =          -81.93 +/-  0.55 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28020 |
# posteriors |13065 |
# equals     |  452 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               13065
# nposterior =               13065
# nequals    =                 422
# nlike      =             5012332
# <nlike>    =         627.34   (           4.65 per slice )
# log(Z)     =          -81.42 +/-  0.55
# log(Z_1)   =          -81.42 +/-  0.55 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28498 |
# posteriors |13266 |
# equals     |  596 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               13266
# nposterior =               13266
# nequals    =                 557
# nlike      =             5138117
# <nlike>    =         628.93   (           4.66 per slice )
# log(Z)     =          -81.03 +/-  0.56
# log(Z_1)   =          -81.03 +/-  0.56 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28302 |
# posteriors |13467 |
# equals     |  686 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               13467
# nposterior =               13467
# nequals    =                 682
# nlike      =             5265173
# <nlike>    =         635.28   (           4.71 per slice )
# log(Z)     =          -80.72 +/-  0.56
# log(Z_1)   =          -80.72 +/-  0.56 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29002 |
# posteriors |13668 |
# equals     |  870 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               13668
# nposterior =               13668
# nequals    =                 872
# nlike      =             5392263
# <nlike>    =         635.45   (           4.71 per slice )
# log(Z)     =          -80.47 +/-  0.56
# log(Z_1)   =          -80.47 +/-  0.56 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27677 |
# posteriors |13869 |
# equals     | 1063 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               13869
# nposterior =               13869
# nequals    =                1060
# nlike      =             5519603
# <nlike>    =         636.70   (           4.72 per slice )
# log(Z)     =          -80.27 +/-  0.56
# log(Z_1)   =          -80.27 +/-  0.56 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |30407 |
# posteriors |14070 |
# equals     | 1238 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               14070
# nposterior =               14070
# nequals    =                1232
# nlike      =             5647702
# <nlike>    =         640.50   (           4.74 per slice )
# log(Z)     =          -80.12 +/-  0.57
# log(Z_1)   =          -80.12 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |29805 |
# posteriors |14271 |
# equals     | 1386 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               14271
# nposterior =               14271
# nequals    =                1368
# nlike      =             5776004
# <nlike>    =         641.51   (           4.75 per slice )
# log(Z)     =          -80.01 +/-  0.57
# log(Z_1)   =          -80.01 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27370 |
# posteriors |14472 |
# equals     | 1502 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               14472
# nposterior =               14472
# nequals    =                1488
# nlike      =             5905231
# <nlike>    =         646.13   (           4.79 per slice )
# log(Z)     =          -79.93 +/-  0.57
# log(Z_1)   =          -79.93 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27760 |
# posteriors |14673 |
# equals     | 1590 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               14673
# nposterior =               14673
# nequals    =                1575
# nlike      =             6034783
# <nlike>    =         647.76   (           4.80 per slice )
# log(Z)     =          -79.87 +/-  0.57
# log(Z_1)   =          -79.87 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28191 |
# posteriors |14874 |
# equals     | 1667 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               14874
# nposterior =               14874
# nequals    =                1641
# nlike      =             6165792
# <nlike>    =         655.04   (           4.85 per slice )
# log(Z)     =          -79.83 +/-  0.57
# log(Z_1)   =          -79.83 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28913 |
# posteriors |15075 |
# equals     | 1710 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15075
# nposterior =               15075
# nequals    =                1681
# nlike      =             6296849
# <nlike>    =         655.28   (           4.85 per slice )
# log(Z)     =          -79.80 +/-  0.57
# log(Z_1)   =          -79.80 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28415 |
# posteriors |15276 |
# equals     | 1734 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15276
# nposterior =               15276
# nequals    =                1709
# nlike      =             6428019
# <nlike>    =         655.85   (           4.86 per slice )
# log(Z)     =          -79.79 +/-  0.57
# log(Z_1)   =          -79.79 +/-  0.57 (still evaluating)
# __________________
# lives      |  200 |
# phantoms   |28241 |
# posteriors |15477 |
# equals     | 1753 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15477
# nposterior =               15477
# nequals    =                1729
# nlike      =             6559480
# <nlike>    =         657.31   (           4.87 per slice )
# log(Z)     =          -79.78 +/-  0.57
# log(Z_1)   =          -79.78 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |27979 |
# posteriors |15678 |
# equals     | 1761 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15678
# nposterior =               15678
# nequals    =                1737
# nlike      =             6691412
# <nlike>    =         659.66   (           4.89 per slice )
# log(Z)     =          -79.77 +/-  0.57
# log(Z_1)   =          -79.77 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |28455 |
# posteriors |15879 |
# equals     | 1766 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15879
# nposterior =               15879
# nequals    =                1740
# nlike      =             6824192
# <nlike>    =         663.90   (           4.92 per slice )
# log(Z)     =          -79.76 +/-  0.57
# log(Z_1)   =          -79.76 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |25565 |
# posteriors |16080 |
# equals     | 1771 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               16080
# nposterior =               16080
# nequals    =                1746
# nlike      =             6957211
# <nlike>    =         665.10   (           4.93 per slice )
# log(Z)     =          -79.76 +/-  0.57
# log(Z_1)   =          -79.76 +/-  0.57 (still evaluating)
#
#
#
# __________________
# lives      |  200 |
# phantoms   |26599 |
# posteriors |16281 |
# equals     | 1776 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               16281
# nposterior =               16281
# nequals    =                1748
# nlike      =             7090827
# <nlike>    =         668.08   (           4.95 per slice )
# log(Z)     =          -79.76 +/-  0.57
# log(Z_1)   =          -79.76 +/-  0.57 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =        16620                              |
# | log(Z) =          -79.75904 +/-            0.57006 |
# |____________________________________________________|

# %%
paramnames = [(f'theta{i}', r'\theta_{}'.format(i)) for i in range(len(means))]
output["control"].make_paramnames_files(paramnames)

# %%
from anesthetic import NestedSamples
from os.path import join
# %matplotlib inline
import matplotlib.pyplot as plt


samples = {"control": NestedSamples(root = join(settings.base_dir, settings.file_root))}
fig, axes = samples["control"].plot_2d(['theta0', 'theta1', 'theta2', 'theta3', 'theta4', 'theta5'], types={'lower': 'kde', 'diagonal': 'kde'})

plt.show()

# %%
logZ_expected = len(means)*np.log(2*np.pi)/2 + np.linalg.slogdet(covs)[1]/2 - np.sum(np.log(bounds[:, 1] - bounds[:,0])); logZ_expected
# Out:
# -78.48697718107633

# %%
(logZ_expected - output["control"].logZ) / output["control"].logZerr
# Out:
# 2.23146529390251

# %%
plt.hist(samples["control"].logZ(1000)); plt.axvline(logZ_expected);plt.show()

# %% [markdown]
# ## Supernest
#
# The way supernest works is by wrapping the the functions given by the model in its own representations.

# %% [markdown]
# First we should create the *proposal*. It's a representation of what we expect to find, rather than what we already know. For now, let's assume that the proposal is a perfect representation of the posterior distribution.

# %%
import supernest as sn

# %%
_proposal = sn.gaussian_proposal(bounds.T, means, covs, loglike=control[1]); settings.file_root = 'proposal';_proposal
# Out:
# Proposal
#
# prior:
# ------
# Gaussian
# ---------
# mean:
# =====
# [3.04421669e+00 9.65085576e-01 1.04092414e+00 2.23728312e-02
#  1.20056065e-01 5.41030130e-02 1.00063447e+00 9.99678773e-01
#  9.98181802e-01 4.67844058e+01 5.24438195e-01 5.47940275e+00
#  3.26837070e+00 8.92010739e+00 1.09139253e+01 1.86530978e+01
#  9.37525934e+01 2.58581541e+02 4.59060976e+01 4.22658986e+01
#  1.15061077e+02 1.14031909e-01 1.34924113e-01 4.81216745e-01
#  2.25044838e-01 6.65724996e-01 2.08338158e+00]
#
# covmat:
# =======
# [[ 1.96672138e-04  1.29109718e-05  5.69363464e-07  4.77220931e-07
#   -4.49644553e-06  9.32240855e-05  9.42192682e-06  1.10037563e-07
#   -1.09806392e-07 -1.86781728e-03  1.94501952e-04  6.80444170e-04
#   -1.74370603e-03  2.39891556e-04 -3.08923715e-04 -5.39295697e-04
#    7.20657994e-04 -1.21910522e-02 -5.58107941e-03  1.60545106e-03
#    2.72757154e-03 -3.42866933e-07 -1.07467294e-05  2.69185589e-05
#   -2.76718399e-05 -6.78084267e-06 -5.88525470e-05]
#  [ 1.29109718e-05  1.64661920e-05  3.25140945e-07  2.35103736e-07
#   -3.26516071e-06  1.05160863e-05  5.23814548e-07 -7.83048387e-08
#   -3.69167692e-08 -4.52623793e-03  1.00065157e-04  1.03775247e-03
#   -2.18341766e-03  4.33973648e-04 -2.42951575e-04  2.52214051e-05
#    1.86492098e-03 -2.32663335e-02 -6.76231560e-03  1.52237520e-03
#    4.72221477e-03  1.03287159e-06 -1.22196009e-06  2.15650515e-06
#   -1.03648333e-05 -2.53088751e-06 -3.37954540e-05]
#  [ 5.69363464e-07  3.25140945e-07  9.21206313e-08  1.39159407e-08
#   -1.10377389e-07  3.39852172e-07  2.98809336e-08 -1.17529646e-09
#    4.75138070e-03  2.08095202e-02  7.66223265e-03  6.83591794e-03
#    1.06165759e-02 -3.70780602e-04  7.42230833e-04 -2.73058668e-04
#    2.87980459e-03  5.64308447e-04 -9.14410009e-04]
#  [-6.78084267e-06 -2.53088751e-06 -1.86768002e-07 -3.96555794e-07
#    2.81850768e-06 -1.07716318e-05  3.23003792e-06  2.30072727e-07
#   -6.93844007e-07 -1.62810117e-02  1.71646654e-04 -1.83642366e-03
#    2.30941991e-04 -1.12361230e-03 -5.62589925e-04 -3.93946671e-03
#    1.83410329e-03  3.00330863e-02  2.10789371e-03  8.51196853e-03
#    2.68003817e-02 -1.36781197e-04  7.69798730e-05  6.74653919e-04
#    5.64308447e-04  6.42238986e-03  7.97606739e-03]
#  [-5.88525470e-05 -3.37954540e-05 -2.75533756e-06 -2.14906632e-06
#    1.62169968e-05 -5.80193701e-05  9.08208105e-06 -6.64273743e-07
#   -1.50909528e-06 -1.84875036e-02  2.68954031e-04 -1.84882336e-03
#   -8.72561308e-03  2.00246245e-04 -4.26028675e-03 -6.26694231e-03
#    3.02610601e-03  4.26470654e-02  4.23263028e-02  4.61377753e-02
#    6.21672998e-02 -6.41940691e-05 -6.34144543e-04  4.64193711e-03
#   -9.14410009e-04  7.97606739e-03  7.17898653e-02]]
#
# likelihood:
# -----------
#
#
# Likelihood wrapping
#     <function gaussian_proposal.<locals>.correction at 0x7fd6dc6b8310>
# which is based on
#     <function generate_model.<locals>.log_likelihood at 0x7fd6dfbc7ee0>

# %% [markdown]
# **note:** Pretty printing is going to be added to proposals.

# %%
proposal = sn.superimpose([control, _proposal], nDims=len(means));proposal
# Out:
# Proposal
#
# prior:
# ------
# <function superimpose.<locals>.prior_quantile at 0x7fd6dc6b8940>
#
# likelihood:
# -----------
#
#
# <function superimpose.<locals>.likelihood at 0x7fd6dc6b89d0>

# %% [markdown]
# **Note**that the new proposal has two extra dimesnions, and is of a special type. In future versions we shall provide convenience wrappers for PolyChord so that it's trivial to use proposals which are named tuples.

# %% [markdown]
# For this version this means that we need a special instance of *settings*.

# %%
proposal_settings = Settings(proposal.nDims, 0)
proposal_settings.file_root = "proposal"

# %%
output["proposal"]= pp.run_polychord(proposal.likelihood, proposal.nDims, 0, proposal_settings, prior=proposal.prior)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     725
# nDims    :      29
# nDerived :       0
# Doing Clustering
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file tochains/proposal.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.135E-03 seconds
# number of repeats:          145
# started sampling
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
#  ____________________________________________________
# |                                                    |
# | ndead  =         1220                              |
# | log(Z) =          -79.17111 +/-            0.03068 |
# |____________________________________________________|
# Warning, unable to proceed after    726: failed spawn events

# %%
paramnames = [(f'theta{i}', r'\theta_{}'.format(i)) for i in range(proposal.nDims)]
output["proposal"].make_paramnames_files(paramnames)

# %%
samples["proposal"] = NestedSamples(root = join(proposal_settings.base_dir, proposal_settings.file_root))

# %%
fig, axes = samples["proposal"].plot_2d(['theta0', 'theta1', 'theta2', 'theta3', 'theta4', 'theta5'], types={'lower': 'kde', 'diagonal': 'kde'})
samples["control"].plot_2d(axes, alpha=0.6)
# Out:
# (<Figure size 432x288 with 27 Axes>,
#                                                  theta0  \
#  theta0  DiagonalAxes(0.125,0.754167;0.129167x0.125833)
#  theta1   AxesSubplot(0.125,0.628333;0.129167x0.125833)
#  theta2     AxesSubplot(0.125,0.5025;0.129167x0.125833)
#  theta3   AxesSubplot(0.125,0.376667;0.129167x0.125833)
#  theta4   AxesSubplot(0.125,0.250833;0.129167x0.125833)
#  theta5      AxesSubplot(0.125,0.125;0.129167x0.125833)
#
#                                                     theta1  \
#  theta0                                               None
#  theta1  DiagonalAxes(0.254167,0.628333;0.129167x0.125833)
#  theta2     AxesSubplot(0.254167,0.5025;0.129167x0.125833)
#  theta3   AxesSubplot(0.254167,0.376667;0.129167x0.125833)
#  theta4   AxesSubplot(0.254167,0.250833;0.129167x0.125833)
#  theta5      AxesSubplot(0.254167,0.125;0.129167x0.125833)
#
#                                                    theta2  \
#  theta0                                              None
#  theta1                                              None
#  theta2   DiagonalAxes(0.383333,0.5025;0.129167x0.125833)
#  theta3  AxesSubplot(0.383333,0.376667;0.129167x0.125833)
#  theta4  AxesSubplot(0.383333,0.250833;0.129167x0.125833)
#  theta5     AxesSubplot(0.383333,0.125;0.129167x0.125833)
#
#                                                   theta3  \
#  theta0                                             None
#  theta1                                             None
#  theta2                                             None
#  theta3  DiagonalAxes(0.5125,0.376667;0.129167x0.125833)
#  theta4   AxesSubplot(0.5125,0.250833;0.129167x0.125833)
#  theta5      AxesSubplot(0.5125,0.125;0.129167x0.125833)
#
#                                                     theta4  \
#  theta0                                               None
#  theta1                                               None
#  theta2                                               None
#  theta3                                               None
#  theta4  DiagonalAxes(0.641667,0.250833;0.129167x0.125833)
#  theta5      AxesSubplot(0.641667,0.125;0.129167x0.125833)
#
#                                                  theta5
#  theta0                                            None
#  theta1                                            None
#  theta2                                            None
#  theta3                                            None
#  theta4                                            None
#  theta5  DiagonalAxes(0.770833,0.125;0.129167x0.125833)  )

# %% [markdown]
# As we can see the results of the proposal's posterior distribution are exactly spot on.

# %%
(logZ_expected - output["proposal"].logZ)/output["proposal"].logZerr
# Out:
# 22.3017373764661

# %% [markdown]
# The evidence is less so: we have to remember that

# %%
plt.hist(samples["control"].logZ(1000), label="control")
plt.axvline(logZ_expected, color="k")
plt.hist(samples["proposal"].logZ(1000), label="proposal")
plt.legend()

# %%
(output["control"].nlike, output["proposal"].nlike)
# Out:
# (7183388, 351452)

# %%
def higson(samples):
    for x in samples: 
        logX = np.log(samples[x].nlive / (samples[x].nlive + 1)).cumsum()
        LXi = samples[x].logL / samples[x].beta + logX
        LX = np.exp(LXi - LXi.max())
        plt.plot(-logX, LX, label=x)
    plt.legend()

# %%
higson(samples)

# %%
output["control"].nlike / output["proposal"].nlike
# Out:
# 20.439172347859735

# %% [markdown]
# In other words, we have managed to reduce the number of likelihood evaluations by a factor of $20$. We can do much better though after a bit of tuning.
