# %% [markdown]
# # `supernest` demonstration

# %% [markdown]
# In this interactive notebook we shall guid you through the typical process of using `supernest` for your Bayesian inference workflow. For simplicity we shall approximate cosmological inference, with a Gaussian approximation. This should demonstrate the efficacy of supernest on a realistic example, while sparing you the expense of HPC testing.

# %% [markdown]
# The code, while not exactly the same as what is used inside the `cobaya`'s supernest integration, is representative of what the of the interface and the kinds of work that need to be done in order to incorporate it into your workflow.

# %% [markdown]
# ##  Dependencies

# %% [markdown]
# In this example we shall be using William Handley's excellent `polychord` package to explore a facsimile of a typical Lambda CDM inference done by a typical cosmological package like `cobaya`.

# %%
# !pip3 install supernest anesthetic mpi4py ipyparallel
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: supernest in /mnt/Archive/Git/sspr (3.1.4)
# Requirement already satisfied: anesthetic in /home/app/.local/lib/python3.9/site-packages (2.0.0b9)
# Requirement already satisfied: mpi4py in /home/app/.local/lib/python3.9/site-packages (3.1.1)
# Requirement already satisfied: ipyparallel in /usr/lib/python3.9/site-packages (6.3.0)
# Requirement already satisfied: matplotlib>=3.3.0 in /home/app/.local/lib/python3.9/site-packages (from anesthetic) (3.4.2)
# Requirement already satisfied: scipy>=1.2.0 in /usr/lib/python3.9/site-packages (from anesthetic) (1.7.1)
# Requirement already satisfied: numpy in /usr/lib/python3.9/site-packages (from anesthetic) (1.21.1)
# Requirement already satisfied: pandas>=1.1.0 in /home/app/.local/lib/python3.9/site-packages (from anesthetic) (1.3.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (8.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/app/.local/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (1.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.9/site-packages (from matplotlib>=3.3.0->anesthetic) (2.8.2)
# Requirement already satisfied: six in /usr/lib/python3.9/site-packages (from cycler>=0.10->matplotlib>=3.3.0->anesthetic) (1.16.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/lib/python3.9/site-packages (from pandas>=1.1.0->anesthetic) (2021.1)
# Requirement already satisfied: ipython_genutils in /usr/lib/python3.9/site-packages (from ipyparallel) (0.2.0)
# Requirement already satisfied: decorator in /usr/lib/python3.9/site-packages (from ipyparallel) (5.1.0)
# Requirement already satisfied: pyzmq>=13 in /usr/lib/python3.9/site-packages (from ipyparallel) (22.2.1)
# Requirement already satisfied: traitlets>=4.3 in /usr/lib/python3.9/site-packages (from ipyparallel) (5.0.5)
# Requirement already satisfied: ipython>=4 in /usr/lib/python3.9/site-packages (from ipyparallel) (7.27.0)
# Requirement already satisfied: jupyter_client in /usr/lib/python3.9/site-packages (from ipyparallel) (6.1.12)
# Requirement already satisfied: ipykernel>=4.4 in /usr/lib/python3.9/site-packages (from ipyparallel) (6.0.3)
# Requirement already satisfied: tornado>=4 in /usr/lib/python3.9/site-packages (from ipyparallel) (6.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /usr/lib/python3.9/site-packages (from ipykernel>=4.4->ipyparallel) (1.4.3)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /usr/lib/python3.9/site-packages (from ipykernel>=4.4->ipyparallel) (0.1.2)
# Requirement already satisfied: jupyter_core>=4.6.0 in /usr/lib/python3.9/site-packages (from jupyter_client->ipyparallel) (4.7.1)

# %% [markdown]
# **NOTE**: there is an issue with `pandas`, so you must reload the runtime after executing the above block.

# %% [markdown]
# Installing polychord is a tiny bit more involved. In real life you want to enable MPI support to make use of multiple CPU cores, but in this colab notebook, it is sufficient to install `polychord` the easy way.

# %%
# !pip3 install https://github.com/PolyChord/PolyChordLite/archive/master.zip
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting https://github.com/PolyChord/PolyChordLite/archive/master.zip
#   Using cached https://github.com/PolyChord/PolyChordLite/archive/master.zip
# Requirement already satisfied: numpy in /usr/lib/python3.9/site-packages (from pypolychord==1.18.2) (1.21.1)
# Requirement already satisfied: scipy in /usr/lib/python3.9/site-packages (from pypolychord==1.18.2) (1.7.1)

# %% [markdown]
# ## Setting up the prior

# %% [markdown]
# Bayesian inference is the process of turning two probability distributions representing your knowledge before a data set, into two other probability distributions, representing your knowledge after, including how confident you are in your underlying theory.
#
# The inputs are called the prior, and the likelihood. The likelihood is ususally specified via the logarithm of the probability density function. Normally the prior is convenient to represent via the point-percent function or quantile; it's a mapping that takes parameters from a uniform unit hypercube `[0, 1]` and maps them onto the real space of your parameters with the desired probability density.

# %% [markdown]
# **Note**: a few nested samplers e.g. `multinest` do not allow  a separate prior and likelihood function, but instead use the unit hypercube as the space for calculating the probability distributions. `Polychord` provides the separation as a purely optional convenience.

# %% [markdown]
# We shall start by defining the prior widths. These can be found in e.g. `cobaya`. This represents the minimum and maximum values a given parameter can obtain during inference.
#
# **NOTE**: In our case, all priors are uniform. This is done for technical reasons, but also inadvertently simplifies the repartitioning. `supernest` operates under the assumption that your priors are all uniform. If you have a non-uniform prior (and a sampler that can cope with `inf` and `nan`), you should refer to the paper (TODO) for how to properly repartition the prior and likelihood.

# %% [markdown]
# The bounds are:

# %%
import numpy as np

bounds = np.array([[1.610000000000000098e+00, 3.910000000000000142e+00],
                  [8.000000000000000444e-01, 1.199999999999999956e+00],
                  [5.000000000000000000e-01, 1.000000000000000000e+01],
                  [5.000000000000000104e-03, 1.000000000000000056e-01],
                  [1.000000000000000021e-03, 9.899999999999999911e-01],
                  [1.000000000000000021e-02, 8.000000000000000444e-01],
                  [9.874342179098187788e-01, 1.012565782090074640e+00],
                  [9.966815810147492405e-01, 1.003718418985220850e+00],
                  [9.947828966565528397e-01, 1.001317103343419390e+00],
                  [0.000000000000000000e+00, 2.000000000000000000e+02],
                  [0.000000000000000000e+00, 1.000000000000000000e+00],
                  [0.000000000000000000e+00, 1.000000000000000000e+01],
                  [0.000000000000000000e+00, 1.000000000000000000e+01],
                  [-1.452625672144938207e+00, 1.865262567205973454e+01],
                  [5.473743278550617930e-01, 2.065262567205973454e+01],
                  [-1.922365910661598321e+01, 6.622365910625386221e+01],
                  [-8.626256721449379938e+00, 1.924262567205973369e+02],
                  [0.000000000000000000e+00, 4.000000000000000000e+02],
                  [0.000000000000000000e+00, 4.000000000000000000e+02],
                  [0.000000000000000000e+00, 4.000000000000000000e+02],
                  [0.000000000000000000e+00, 4.000000000000000000e+02],
                  [-8.110513911504371731e-02, 3.411051391132544075e-01],
                  [-5.094726209860886423e-02, 3.109472620970751833e-01],
                  [7.631844753477834420e-03, 9.123681552426879948e-01],
                  [-1.548945241972177478e-01, 5.688945241941503195e-01],
                  [2.376318447534777611e-01, 1.142368155242687866e+00],
                  [-7.762089314791336125e-01, 4.652208931456128127e+00]])

# %% [markdown]
# Now we want the covariance matrix, which is quite a bit more sizeable.

# %%
covs = np.array([
                [2.968145029999999865e-02, 3.135427750000000131e-03, 8.338248970000000388e-04, -4.217618689999999727e-05, 2.650284049999999947e-03, 1.200952880000000092e-03, 5.068381450000000049e-05, 4.746630099999999926e-06, -1.581929089999999907e-06, 2.663628749999999989e-01, 8.828913119999999603e-05, -2.216902540000000206e-03, 8.404302719999999505e-03, 1.432890180000000126e-04, -7.558739230000000031e-03, 1.944324650000000057e-02, -5.093156110000000153e-02, -6.004830359999999700e-01, 8.669781009999999455e-01, 8.293443280000000195e-01, 2.503914819999999986e-01, 3.708188239999999866e-05, 7.674027270000000588e-05, 1.178210749999999941e-04, 1.037332909999999936e-04, 4.387946019999999802e-04, -2.495634950000000154e-03],
                [3.135427750000000131e-03, 3.185720349999999861e-03, 3.130486989999999871e-05, 9.000653609999999629e-05, 9.083279789999999972e-04, 7.353195660000000269e-04, 2.200058280000000188e-06, 2.044903099999999917e-06, -1.621079909999999999e-06, 1.719608519999999974e-01, 1.571867659999999977e-04, -1.503148840000000054e-03, 7.397394500000000449e-04, 8.864634000000000142e-04, 1.262831960000000133e-04, -3.087391200000000162e-03, -1.691096259999999921e-02, -3.842335519999999782e-01, 5.685709920000000528e-01, 5.616310949999999691e-01, 2.650536399999999793e-01, -1.543663889999999895e-05, -2.117700089999999846e-05, 5.166042389999999827e-05, -2.951145799999999869e-05, 9.090266650000000808e-06, -9.575564690000000012e-04],
                [8.338248970000000388e-04, 3.130486989999999871e-05, 1.816877529999999996e-03, -1.996604279999999933e-04, 2.384585130000000178e-03, -2.852508560000000098e-05, -1.521311770000000076e-07, 5.252263470000000354e-07, 2.437715000000000067e-07, -3.119262570000000054e-02, 7.871063490000000239e-05, -7.434610499999999653e-04, 7.893933009999999856e-04, 6.761066239999999946e-04, -2.290230030000000184e-03, -3.122185720000000028e-04, -1.494500340000000024e-02, -2.381864809999999829e-03, -4.836481229999999715e-02, -4.788839739999999762e-02, -3.567536159999999679e-02, -5.175818659999999991e-05, 2.748901660000000065e-05, 6.211406010000000439e-05, 5.386665410000000294e-05, 1.777272519999999835e-05, -7.698531549999999531e-05],
                [-4.217618689999999727e-05, 9.000653609999999629e-05, -1.996604279999999933e-04, 1.888281059999999986e-04, 1.106031419999999998e-03, 9.007079379999999866e-05, -2.207499039999999946e-06, 1.061611120000000028e-06, -5.089118919999999502e-07, 1.425302519999999962e-01, -4.923472619999999907e-05, -5.899677009999999616e-04, 2.296787319999999809e-03, -1.286683270000000059e-03, 3.491789569999999808e-04, 1.309846360000000050e-02, -1.277812250000000000e-03, -1.475363419999999870e-01, 4.067879440000000124e-01, 4.406117059999999919e-01, 2.457505739999999994e-01, 2.945679510000000020e-05, -1.120544580000000044e-05, -4.700972779999999823e-05, -2.730662089999999958e-05, 1.757231910000000140e-05, -5.257990180000000078e-04],
                [2.650284049999999947e-03, 9.083279789999999972e-04, 2.384585130000000178e-03, 1.106031419999999998e-03, 2.305775319999999948e-02, 8.833757960000000091e-04, -3.094293819999999862e-05, 1.471807969999999937e-05, -5.576546339999999849e-06, 1.724855170000000104e+00, -4.480229409999999949e-04, -9.954579220000000714e-03, 3.094260169999999907e-02, -9.166353650000000353e-03, -6.590823330000000410e-04, 1.871629740000000097e-01, -3.167506099999999741e-02, -1.829276710000000028e+00, 5.180736470000000260e+00, 5.422197459999999580e+00, 3.102142129999999831e+00, 1.465743919999999885e-04, -5.914557379999999730e-05, -5.425758050000000377e-04, -2.333443100000000020e-04, 4.939308170000000515e-04, -5.592697169999999961e-03],
                [1.200952880000000092e-03, 7.353195660000000269e-04, -2.852508560000000098e-05, 9.007079379999999866e-05, 8.833757960000000091e-04, 1.394232150000000075e-03, -5.430461349999999699e-06, 3.162541049999999833e-06, -1.407582420000000052e-06, 2.775386970000000009e-01, 2.874008540000000159e-05, -2.216153279999999968e-03, 7.333879679999999630e-03, -1.789817310000000033e-03, -1.586509480000000086e-03, 2.309489559999999830e-02, -3.918476910000000257e-02, -4.232265399999999844e-01, 9.278675269999999697e-01, 8.092088360000000424e-01, 3.764559630000000046e-01, 8.619862329999999602e-05, 3.497960350000000174e-06, -1.277038529999999868e-04, -8.261150620000000649e-05, 1.411206949999999917e-04, -9.305383449999999907e-04],
                [5.068381450000000049e-05, 2.200058280000000188e-06, -1.521311770000000076e-07, -2.207499039999999946e-06, -3.094293819999999862e-05, -5.430461349999999699e-06, 3.207137569999999878e-05, -9.275151899999999787e-08, 1.536967179999999926e-08, -2.676847170000000182e-03, -7.972937719999999965e-06, 9.967279499999999849e-05, -2.950069400000000056e-05, 1.163374879999999958e-04, -2.177143750000000021e-04, -8.539839430000000257e-04, 2.377882559999999930e-03, 1.017018630000000000e-02, -1.112197019999999932e-02, -1.169547909999999954e-02, 3.558528669999999963e-03, -5.210708710000000400e-06, -3.755179240000000141e-06, 1.589262890000000033e-06, -3.542850149999999793e-06, 6.292153939999999865e-06, 3.827967799999999857e-05],
                [4.746630099999999926e-06, 2.044903099999999917e-06, 5.252263470000000354e-07, 1.061611120000000028e-06, 1.471807969999999937e-05, 3.162541049999999833e-06, -9.275151899999999787e-08, 2.450719240000000013e-06, 2.947908970000000176e-10, 3.294882759999999845e-03, 1.548658669999999992e-07, 6.747006970000000623e-05, 6.256752239999999340e-05, 2.386572300000000047e-04, -4.233408830000000181e-04, 3.562502720000000102e-04, -5.452824429999999795e-04, 5.044431420000000318e-03, 1.121857610000000054e-02, 1.009086319999999946e-02, 5.628793669999999916e-03, 9.622558170000000086e-07, -5.816158569999999957e-07, -2.632452610000000035e-06, -1.420467419999999972e-06, 1.511541179999999934e-06, 3.408651769999999823e-06],
                [-1.581929089999999907e-06, -1.621079909999999999e-06, 2.437715000000000067e-07, -5.089118919999999502e-07, -5.576546339999999849e-06, -1.407582420000000052e-06, 1.536967179999999926e-08, 2.947908970000000176e-10, 2.150061509999999890e-06, 9.534150670000000492e-04, 6.349712240000000204e-08, -3.984490149999999770e-06, -5.037175890000000067e-05, -3.098377860000000255e-05, -3.934796110000000164e-05, 1.030094729999999964e-03, 3.422361860000000099e-03, 1.711678990000000062e-03, -4.159122559999999837e-03, -3.906880540000000172e-03, -5.618961530000000058e-03, -4.119654119999999825e-07, 2.450625880000000164e-07, -2.852389519999999887e-07, 5.749106310000000168e-07, -2.534326339999999862e-06, 4.315492620000000351e-06],
                [2.663628749999999989e-01, 1.719608519999999974e-01, -3.119262570000000054e-02, 1.425302519999999962e-01, 1.724855170000000104e+00, 2.775386970000000009e-01, -2.676847170000000182e-03, 3.294882759999999845e-03, 9.534150670000000492e-04, 1.440978980000000092e+03, -3.081545090000000209e-01, -2.641624010000000133e+00, 7.786807289999999604e+00, -1.606083160000000065e+00, 7.194975639999999784e-01, 1.978751240000000067e+01, -3.526100470000000087e+02, -3.425249029999999948e+02, 1.261326369999999997e+03, 1.154578680000000077e+03, -4.747657399999999583e+00, 1.036431869999999977e-01, -2.436002129999999960e-02, -2.104166219999999976e-01, -9.044435889999999367e-02, 1.450768600000000019e-01, -1.482414160000000036e+00],
                [8.828913119999999603e-05, 1.571867659999999977e-04, 7.871063490000000239e-05, -4.923472619999999907e-05, -4.480229409999999949e-04, 2.874008540000000159e-05, -7.972937719999999965e-06, 1.548658669999999992e-07, 6.349712240000000204e-08, -3.081545090000000209e-01, 8.267654939999999342e-02, -1.473520380000000081e-02, 4.926706389999999623e-03, -7.635348800000000408e-03, 6.532229120000000028e-03, 7.658044989999999996e-02, 8.133349769999999312e-02, -2.376457829999999855e-02, 2.719628419999999824e-01, 9.227935640000000106e-01, -4.086331979999999892e-02, 1.536488919999999899e-05, 8.388438459999999857e-05, -3.777001800000000183e-05, -9.301300049999999668e-05, -1.172250289999999959e-04, -6.434749160000000252e-04],
                [-2.216902540000000206e-03, -1.503148840000000054e-03, -7.434610499999999653e-04, -5.899677009999999616e-04, -9.954579220000000714e-03, -2.216153279999999968e-03, 9.967279499999999849e-05, 6.747006970000000623e-05, -3.984490149999999770e-06, -2.641624010000000133e+00, -1.473520380000000081e-02, 6.518264280000000355e+00, -1.387219179999999996e+00, -1.367270369999999957e-01, 1.194643209999999983e-01, 2.821549019999999963e+00, 3.298345030000000122e+00, -2.491816289999999867e+01, -1.223843970000000070e+01, 1.536538849999999901e+00, -1.645540309999999895e+00, -3.171848639999999943e-04, 5.844647169999999878e-04, 9.933778370000000569e-04, 1.001515060000000108e-03, 2.004961750000000022e-03, 5.215395280000000022e-03],
                [8.404302719999999505e-03, 7.397394500000000449e-04, 7.893933009999999856e-04, 2.296787319999999809e-03, 3.094260169999999907e-02, 7.333879679999999630e-03, -2.950069400000000056e-05, 6.256752239999999340e-05, -5.037175890000000067e-05, 7.786807289999999604e+00, 4.926706389999999623e-03, -1.387219179999999996e+00, 7.920213600000000298e+00, -2.901886500000000133e-02, -2.223419490000000109e-01, -3.436787889999999845e-01, -1.914725250000000045e+00, -8.574309899999999374e+00, 2.145733189999999979e+01, 1.362226629999999972e+01, 2.949081640000000171e+00, 4.618665850000000170e-03, -1.545935339999999960e-03, -3.823149850000000152e-03, -3.927817699999999919e-03, 4.683757769999999723e-03, -5.841703680000000232e-02],
                [1.432890180000000126e-04, 8.864634000000000142e-04, 6.761066239999999946e-04, -1.286683270000000059e-03, -9.166353650000000353e-03, -1.789817310000000033e-03, 1.163374879999999958e-04, 2.386572300000000047e-04, -3.098377860000000255e-05, -1.606083160000000065e+00, -7.635348800000000408e-03, -1.367270369999999957e-01, -2.901886500000000133e-02, 2.005499670000000023e+01, 9.960810639999999605e-01, 4.162989160000000188e-01, -5.134093060000000141e-04, -1.697497690000000148e+01, -6.585026489999999733e+00, -7.224663480000000249e+00, -5.136515300000000117e+00, -9.323316919999999472e-04, 1.522835690000000006e-03, 3.348195369999999813e-03, -2.129415349999999856e-03, 1.603642329999999941e-03, 2.918191380000000057e-02],
                [-7.558739230000000031e-03, 1.262831960000000133e-04, -2.290230030000000184e-03, 3.491789569999999808e-04, -6.590823330000000410e-04, -1.586509480000000086e-03, -2.177143750000000021e-04, -4.233408830000000181e-04, -3.934796110000000164e-05, 7.194975639999999784e-01, 6.532229120000000028e-03, 1.194643209999999983e-01, -2.223419490000000109e-01, 9.960810639999999605e-01, 1.984640130000000013e+01, 8.660322230000000232e+00, 6.153933099999999712e+00, 1.983209829999999840e+01, -9.564703279999999808e+00, -4.002715959999999740e+00, -2.969334379999999829e+00, -8.756303569999999460e-04, 1.029166989999999926e-03, -2.884666640000000185e-03, 5.468167860000000373e-03, 1.839993719999999996e-03, -3.636279600000000278e-02],
                [1.944324650000000057e-02, -3.087391200000000162e-03, -3.122185720000000028e-04, 1.309846360000000050e-02, 1.871629740000000097e-01, 2.309489559999999830e-02, -8.539839430000000257e-04, 3.562502720000000102e-04, 1.030094729999999964e-03, 1.978751240000000067e+01, 7.658044989999999996e-02, 2.821549019999999963e+00, -3.436787889999999845e-01, 4.162989160000000188e-01, 8.660322230000000232e+00, 2.356509039999999970e+02, 1.876819930000000056e+02, -2.703674859999999924e+01, 2.120874919999999975e+02, 3.629690579999999756e+01, 6.100736650000000338e+01, -1.107586719999999973e-03, 1.233026299999999929e-02, 1.622374920000000114e-04, -3.023772970000000032e-02, 5.477839019999999892e-03, 9.368195510000000559e-02],
                [-5.093156110000000153e-02, -1.691096259999999921e-02, -1.494500340000000024e-02, -1.277812250000000000e-03, -3.167506099999999741e-02, -3.918476910000000257e-02, 2.377882559999999930e-03, -5.452824429999999795e-04, 3.422361860000000099e-03, -3.526100470000000087e+02, 8.133349769999999312e-02, 3.298345030000000122e+00, -1.914725250000000045e+00, -5.134093060000000141e-04, 6.153933099999999712e+00, 1.876819930000000056e+02, 1.261320240000000013e+03, 5.039279619999999937e+01, -1.952933979999999892e+01, 8.179167650000000123e+00, 8.485509079999999926e+01, -2.312180470000000168e-02, 1.813267299999999846e-02, 1.114934820000000049e-01, -5.846903770000000042e-03, -6.729364679999999543e-02, 2.169466949999999950e-01],
                [-6.004830359999999700e-01, -3.842335519999999782e-01, -2.381864809999999829e-03, -1.475363419999999870e-01, -1.829276710000000028e+00, -4.232265399999999844e-01, 1.017018630000000000e-02, 5.044431420000000318e-03, 1.711678990000000062e-03, -3.425249029999999948e+02, -2.376457829999999855e-02, -2.491816289999999867e+01, -8.574309899999999374e+00, -1.697497690000000148e+01, 1.983209829999999840e+01, -2.703674859999999924e+01, 5.039279619999999937e+01, 7.114260500000000320e+03, -1.220674170000000004e+03, -1.326360359999999901e+03, -7.387565799999999854e+02, -1.964240640000000093e-01, 2.247111590000000145e-02, 3.523370040000000092e-01, 2.047268070000000106e-01, -1.797178959999999881e-01, 1.291366699999999978e+00],
                [8.669781009999999455e-01, 5.685709920000000528e-01, -4.836481229999999715e-02, 4.067879440000000124e-01, 5.180736470000000260e+00, 9.278675269999999697e-01, -1.112197019999999932e-02, 1.121857610000000054e-02, -4.159122559999999837e-03, 1.261326369999999997e+03, 2.719628419999999824e-01, -1.223843970000000070e+01, 2.145733189999999979e+01, -6.585026489999999733e+00, -9.564703279999999808e+00, 2.120874919999999975e+02, -1.952933979999999892e+01, -1.220674170000000004e+03, 7.373464640000000145e+03, 4.101727829999999813e+03, 1.954825180000000046e+03, 3.747203239999999935e-01, -5.835444840000000161e-02, -3.372460529999999901e-01, -2.188041410000000075e-01, 4.807094419999999868e-01, -4.262176539999999569e+00],
                [8.293443280000000195e-01, 5.616310949999999691e-01, -4.788839739999999762e-02, 4.406117059999999919e-01, 5.422197459999999580e+00, 8.092088360000000424e-01, -1.169547909999999954e-02, 1.009086319999999946e-02, -3.906880540000000172e-03, 1.154578680000000077e+03, 9.227935640000000106e-01, 1.536538849999999901e+00, 1.362226629999999972e+01, -7.224663480000000249e+00, -4.002715959999999740e+00, 3.629690579999999756e+01, 8.179167650000000123e+00, -1.326360359999999901e+03, 4.101727829999999813e+03, 6.486187549999999646e+03, 2.350870899999999892e+03, 3.387937970000000076e-01, -8.457468129999999584e-02, -3.820059860000000196e-01, -2.596811239999999854e-01, 4.515744870000000244e-01, -4.136748350000000407e+00],
                [2.503914819999999986e-01, 2.650536399999999793e-01, -3.567536159999999679e-02, 2.457505739999999994e-01, 3.102142129999999831e+00, 3.764559630000000046e-01, 3.558528669999999963e-03, 5.628793669999999916e-03, -5.618961530000000058e-03, -4.747657399999999583e+00, -4.086331979999999892e-02, -1.645540309999999895e+00, 2.949081640000000171e+00, -5.136515300000000117e+00, -2.969334379999999829e+00, 6.100736650000000338e+01, 8.485509079999999926e+01, -7.387565799999999854e+02, 1.954825180000000046e+03, 2.350870899999999892e+03, 4.760221349999999802e+03, 1.429834060000000073e-01, -5.065991630000000329e-02, -2.989657660000000217e-01, -1.799586410000000025e-01, 2.845544890000000215e-01, -1.751175160000000064e+00],
                [3.708188239999999866e-05, -1.543663889999999895e-05, -5.175818659999999991e-05, 2.945679510000000020e-05, 1.465743919999999885e-04, 8.619862329999999602e-05, -5.210708710000000400e-06, 9.622558170000000086e-07, -4.119654119999999825e-07, 1.036431869999999977e-01, 1.536488919999999899e-05, -3.171848639999999943e-04, 4.618665850000000170e-03, -9.323316919999999472e-04, -8.756303569999999460e-04, -1.107586719999999973e-03, -2.312180470000000168e-02, -1.964240640000000093e-01, 3.747203239999999935e-01, 3.387937970000000076e-01, 1.429834060000000073e-01, 8.777600820000000179e-03, 4.811679979999999792e-04, 1.819639440000000083e-05, -9.129752990000000040e-04, -1.456107410000000038e-04, -4.306397559999999825e-04],
                [7.674027270000000588e-05, -2.117700089999999846e-05, 2.748901660000000065e-05, -1.120544580000000044e-05, -5.914557379999999730e-05, 3.497960350000000174e-06, -3.755179240000000141e-06, -5.816158569999999957e-07, 2.450625880000000164e-07, -2.436002129999999960e-02, 8.388438459999999857e-05, 5.844647169999999878e-04, -1.545935339999999960e-03, 1.522835690000000006e-03, 1.029166989999999926e-03, 1.233026299999999929e-02, 1.813267299999999846e-02, 2.247111590000000145e-02, -5.835444840000000161e-02, -8.457468129999999584e-02, -5.065991630000000329e-02, 4.811679979999999792e-04, 6.183778840000000131e-03, 1.722407989999999965e-04, 1.590148129999999910e-03, -9.959694779999999649e-05, -1.650932680000000022e-03],
                [1.178210749999999941e-04, 5.166042389999999827e-05, 6.211406010000000439e-05, -4.700972779999999823e-05, -5.425758050000000377e-04, -1.277038529999999868e-04, 1.589262890000000033e-06, -2.632452610000000035e-06, -2.852389519999999887e-07, -2.104166219999999976e-01, -3.777001800000000183e-05, 9.933778370000000569e-04, -3.823149850000000152e-03, 3.348195369999999813e-03, -2.884666640000000185e-03, 1.622374920000000114e-04, 1.114934820000000049e-01, 3.523370040000000092e-01, -3.372460529999999901e-01, -3.820059860000000196e-01, -2.989657660000000217e-01, 1.819639440000000083e-05, 1.722407989999999965e-04, 4.114830430000000067e-02, -4.079278590000000228e-04, 9.112142369999999547e-04, 9.620691069999999512e-03],
                [1.037332909999999936e-04, -2.951145799999999869e-05, 5.386665410000000294e-05, -2.730662089999999958e-05, -2.333443100000000020e-04, -8.261150620000000649e-05, -3.542850149999999793e-06, -1.420467419999999972e-06, 5.749106310000000168e-07, -9.044435889999999367e-02, -9.301300049999999668e-05, 1.001515060000000108e-03, -3.927817699999999919e-03, -2.129415349999999856e-03, 5.468167860000000373e-03, -3.023772970000000032e-02, -5.846903770000000042e-03, 2.047268070000000106e-01, -2.188041410000000075e-01, -2.596811239999999854e-01, -1.799586410000000025e-01, -9.129752990000000040e-04, 1.590148129999999910e-03, -4.079278590000000228e-04, 2.398725510000000033e-02, 8.721798849999999863e-04, -3.614700209999999799e-03],
                [4.387946019999999802e-04, 9.090266650000000808e-06, 1.777272519999999835e-05, 1.757231910000000140e-05, 4.939308170000000515e-04, 1.411206949999999917e-04, 6.292153939999999865e-06, 1.511541179999999934e-06, -2.534326339999999862e-06, 1.450768600000000019e-01, -1.172250289999999959e-04, 2.004961750000000022e-03, 4.683757769999999723e-03, 1.603642329999999941e-03, 1.839993719999999996e-03, 5.477839019999999892e-03, -6.729364679999999543e-02, -1.797178959999999881e-01, 4.807094419999999868e-01, 4.515744870000000244e-01, 2.845544890000000215e-01, -1.456107410000000038e-04, -9.959694779999999649e-05, 9.112142369999999547e-04, 8.721798849999999863e-04, 4.031588369999999921e-02, 1.806673790000000099e-02],
                [-2.495634950000000154e-03, -9.575564690000000012e-04, -7.698531549999999531e-05, -5.257990180000000078e-04, -5.592697169999999961e-03, -9.305383449999999907e-04, 3.827967799999999857e-05, 3.408651769999999823e-06, 4.315492620000000351e-06, -1.482414160000000036e+00, -6.434749160000000252e-04, 5.215395280000000022e-03, -5.841703680000000232e-02, 2.918191380000000057e-02, -3.636279600000000278e-02, 9.368195510000000559e-02, 2.169466949999999950e-01, 1.291366699999999978e+00, -4.262176539999999569e+00, -4.136748350000000407e+00, -1.751175160000000064e+00, -4.306397559999999825e-04, -1.650932680000000022e-03, 9.620691069999999512e-03, -3.614700209999999799e-03, 1.806673790000000099e-02, 1.155789100000000014e+00]])

# %% [markdown]
# Finally, we want the means of the distribution.

# %%
means = [3.044288950736070198e+00,
        9.653584708627392930e-01,
        1.040891454387792958e+00,
        2.236941853859109389e-02,
        1.199402663897136123e-01,
        5.437839444140014217e-02,
        1.000558470278606116e+00,
        9.996645570914636236e-01,
        9.981974030346568716e-01,
        4.666402808735772823e+01,
        5.270013177546990502e-01,
        5.454231565893462808e+00,
        3.335504420623564670e+00,
        8.932986941158542749e+00,
        1.088025735501460289e+01,
        1.859118982188342528e+01,
        9.378313784298576650e+01,
        2.586977679317792536e+02,
        4.562007887290639019e+01,
        4.214808456289339489e+01,
        1.150478836453472695e+02,
        1.140812364024545444e-01,
        1.347717854911197333e-01,
        4.820886388532216182e-01,
        2.249421206923959693e-01,
        6.660807358891674967e-01, 
        2.084251798946145318e+00]

# %%
import os


import ipyparallel as ipp
# The difficulty with which this is achieved make me think that I in Ipython stands for Idiotic
rc = ipp.Client(profile="mpi")

rc[:]

rc[:].apply_sync(print, *["hello world"])
# Out:
# [None, None, None, None, None, None]

# %% [markdown]
# # Testing Polychord without supernest

# %% [markdown]
# We set up a control to see how supernest compares, this

# %% [markdown]
# We use a function to generate the prior and the likelihood. This is more convenient, because we can parameterise the creation, if we wanted a different multivariate Gaussian model.

# %%
def generate_model(bounds, means, covs):
    thetamin, thetamax = bounds[:,0], bounds[:,1]
    invCov = np.linalg.inv(covs)

    def prior(cube):
        return thetamin + cube * (thetamax - thetamin)

    def log_likelihood(theta):
        return (-(theta - means) @ invCov @ (theta - means) / 2.0 , [])

    return prior, log_likelihood

# %% [markdown]
# At this point we have a complete set for the problem. The next step is to set up PolyChord itself.

# %%
import pypolychord
from mpi4py import MPI

from pypolychord.settings import PolyChordSettings # Note to WJH, adding PolyChordSettings to pypolychord might make it more readable. 

settings = PolyChordSettings(len(means), 0) # We haven't created any derived parameters and don't intend to
settings.file_root = 'control'
settings.nlive = 60
settings.num_repeats = 128
settings.do_clustering = True
settings.read_resume = False # Shouldn't be there
settings.write_resume = False # Wastes space.

control_pr, control_ll = generate_model(bounds, means, covs)

# %% [markdown]
# **SANITY CHECK**: the prior should map the 0-corner of the hypercube onto the minima.

# %%
np.allclose(control_pr(np.zeros(len(means))),bounds[:,0]) and np.allclose(control_pr(np.zeros(len(means)) + 1 ), bounds[:, 1])
# Out:
# True

# %% [markdown]
# And now run.
#
# **note**: This will take a minute and all output is suppressed.

# %%
output = {"control": pypolychord.run_polychord(control_ll, len(means), 0, settings, prior=control_pr)}
print("\n\n\n\n\n---------- finished control ------------------")
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      60
# nDims    :      27
# nDerived :       0
# Doing Clustering
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.250E-04 seconds
# number of repeats:          128
# started sampling
#
# _________________
# lives      |  60 |
# phantoms   |5089 |
# posteriors |  61 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                  61
# nposterior =                  61
# nequals    =                   1
# nlike      =                9280
# <nlike>    =         153.67   (           1.20 per slice )
# log(Z)     =        -6441.64 +/-  0.83
# log(Z_1)   =        -6441.64 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6075 |
# posteriors | 122 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 122
# nposterior =                 122
# nequals    =                   1
# nlike      =               21961
# <nlike>    =         211.35   (           1.65 per slice )
# log(Z)     =         -367.89 +/-  0.84
# log(Z_1)   =         -367.89 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7001 |
# posteriors | 183 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 183
# nposterior =                 183
# nequals    =                   2
# nlike      =               35293
# <nlike>    =         222.20   (           1.74 per slice )
# log(Z)     =         -148.01 +/-  0.62
# log(Z_1)   =         -148.01 +/-  0.62 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8520 |
# posteriors | 244 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 244
# nposterior =                 244
# nequals    =                   3
# nlike      =               48395
# <nlike>    =         218.37   (           1.71 per slice )
# log(Z)     =          -92.56 +/-  0.53
# log(Z_1)   =          -92.56 +/-  0.53 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7678 |
# posteriors | 305 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 305
# nposterior =                 305
# nequals    =                   5
# nlike      =               61994
# <nlike>    =         226.65   (           1.77 per slice )
# log(Z)     =          -60.78 +/-  0.44
# log(Z_1)   =          -60.78 +/-  0.44 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8223 |
# posteriors | 366 |
# equals     |  12 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 366
# nposterior =                 366
# nequals    =                  13
# nlike      =               76451
# <nlike>    =         240.95   (           1.88 per slice )
# log(Z)     =          -49.26 +/-  0.35
# log(Z_1)   =          -49.26 +/-  0.35 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7985 |
# posteriors | 427 |
# equals     |  21 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 427
# nposterior =                 427
# nequals    =                  13
# nlike      =               91891
# <nlike>    =         257.33   (           2.01 per slice )
# log(Z)     =          -42.57 +/-  0.36
# log(Z_1)   =          -42.57 +/-  0.36 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8019 |
# posteriors | 488 |
# equals     |  24 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 488
# nposterior =                 488
# nequals    =                  24
# nlike      =              108826
# <nlike>    =         282.25   (           2.21 per slice )
# log(Z)     =          -38.50 +/-  0.36
# log(Z_1)   =          -38.50 +/-  0.36 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8181 |
# posteriors | 549 |
# equals     |  26 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 549
# nposterior =                 549
# nequals    =                  30
# nlike      =              126565
# <nlike>    =         295.65   (           2.31 per slice )
# log(Z)     =          -36.00 +/-  0.38
# log(Z_1)   =          -36.00 +/-  0.38 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8487 |
# posteriors | 610 |
# equals     |  40 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 610
# nposterior =                 610
# nequals    =                  41
# nlike      =              145311
# <nlike>    =         312.43   (           2.44 per slice )
# log(Z)     =          -34.11 +/-  0.39
# log(Z_1)   =          -34.11 +/-  0.39 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8189 |
# posteriors | 671 |
# equals     |  51 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 671
# nposterior =                 671
# nequals    =                  35
# nlike      =              165052
# <nlike>    =         329.02   (           2.57 per slice )
# log(Z)     =          -32.59 +/-  0.40
# log(Z_1)   =          -32.59 +/-  0.40 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8753 |
# posteriors | 732 |
# equals     |  68 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 732
# nposterior =                 732
# nequals    =                  58
# nlike      =              185734
# <nlike>    =         344.70   (           2.69 per slice )
# log(Z)     =          -31.40 +/-  0.41
# log(Z_1)   =          -31.40 +/-  0.41 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8231 |
# posteriors | 793 |
# equals     |  68 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 793
# nposterior =                 793
# nequals    =                  77
# nlike      =              207854
# <nlike>    =         368.67   (           2.88 per slice )
# log(Z)     =          -30.42 +/-  0.43
# log(Z_1)   =          -30.42 +/-  0.43 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8219 |
# posteriors | 854 |
# equals     |  91 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 854
# nposterior =                 854
# nequals    =                 101
# nlike      =              231398
# <nlike>    =         392.40   (           3.07 per slice )
# log(Z)     =          -29.64 +/-  0.44
# log(Z_1)   =          -29.64 +/-  0.44 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7570 |
# posteriors | 915 |
# equals     | 105 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 915
# nposterior =                 915
# nequals    =                 111
# nlike      =              256482
# <nlike>    =         418.07   (           3.27 per slice )
# log(Z)     =          -29.09 +/-  0.45
# log(Z_1)   =          -29.09 +/-  0.45 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7759 |
# posteriors | 976 |
# equals     | 130 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 976
# nposterior =                 976
# nequals    =                 145
# nlike      =              282469
# <nlike>    =         433.12   (           3.38 per slice )
# log(Z)     =          -28.57 +/-  0.46
# log(Z_1)   =          -28.57 +/-  0.46 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8789 |
# posteriors |1037 |
# equals     | 186 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1037
# nposterior =                1037
# nequals    =                 199
# nlike      =              309851
# <nlike>    =         456.37   (           3.57 per slice )
# log(Z)     =          -28.25 +/-  0.47
# log(Z_1)   =          -28.25 +/-  0.47 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8339 |
# posteriors |1098 |
# equals     | 235 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1098
# nposterior =                1098
# nequals    =                 240
# nlike      =              337949
# <nlike>    =         468.30   (           3.66 per slice )
# log(Z)     =          -28.03 +/-  0.47
# log(Z_1)   =          -28.03 +/-  0.47 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |8184 |
# posteriors |1159 |
# equals     | 282 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1159
# nposterior =                1159
# nequals    =                 287
# nlike      =              366427
# <nlike>    =         474.63   (           3.71 per slice )
# log(Z)     =          -27.86 +/-  0.48
# log(Z_1)   =          -27.86 +/-  0.48 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7333 |
# posteriors |1220 |
# equals     | 324 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1220
# nposterior =                1220
# nequals    =                 334
# nlike      =              396266
# <nlike>    =         497.32   (           3.89 per slice )
# log(Z)     =          -27.72 +/-  0.49
# log(Z_1)   =          -27.72 +/-  0.49 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7523 |
# posteriors |1281 |
# equals     | 360 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1281
# nposterior =                1281
# nequals    =                 370
# nlike      =              427071
# <nlike>    =         513.42   (           4.01 per slice )
# log(Z)     =          -27.61 +/-  0.49
# log(Z_1)   =          -27.61 +/-  0.49 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7374 |
# posteriors |1342 |
# equals     | 391 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1342
# nposterior =                1342
# nequals    =                 402
# nlike      =              459134
# <nlike>    =         534.38   (           4.17 per slice )
# log(Z)     =          -27.54 +/-  0.49
# log(Z_1)   =          -27.54 +/-  0.49 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7991 |
# posteriors |1403 |
# equals     | 409 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1403
# nposterior =                1403
# nequals    =                 424
# nlike      =              490829
# <nlike>    =         528.25   (           4.13 per slice )
# log(Z)     =          -27.49 +/-  0.50
# log(Z_1)   =          -27.49 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7279 |
# posteriors |1464 |
# equals     | 430 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1464
# nposterior =                1464
# nequals    =                 441
# nlike      =              524269
# <nlike>    =         557.33   (           4.35 per slice )
# log(Z)     =          -27.46 +/-  0.50
# log(Z_1)   =          -27.46 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8415 |
# posteriors |1525 |
# equals     | 440 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1525
# nposterior =                1525
# nequals    =                 448
# nlike      =              558006
# <nlike>    =         562.28   (           4.39 per slice )
# log(Z)     =          -27.44 +/-  0.50
# log(Z_1)   =          -27.44 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7972 |
# posteriors |1586 |
# equals     | 442 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1586
# nposterior =                1586
# nequals    =                 455
# nlike      =              592044
# <nlike>    =         567.30   (           4.43 per slice )
# log(Z)     =          -27.43 +/-  0.50
# log(Z_1)   =          -27.43 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6500 |
# posteriors |1647 |
# equals     | 444 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1647
# nposterior =                1647
# nequals    =                 459
# nlike      =              626020
# <nlike>    =         566.27   (           4.42 per slice )
# log(Z)     =          -27.43 +/-  0.50
# log(Z_1)   =          -27.43 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7077 |
# posteriors |1708 |
# equals     | 446 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1708
# nposterior =                1708
# nequals    =                 462
# nlike      =              660872
# <nlike>    =         580.87   (           4.54 per slice )
# log(Z)     =          -27.42 +/-  0.50
# log(Z_1)   =          -27.42 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7332 |
# posteriors |1769 |
# equals     | 446 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1769
# nposterior =                1769
# nequals    =                 463
# nlike      =              695618
# <nlike>    =         579.10   (           4.52 per slice )
# log(Z)     =          -27.42 +/-  0.50
# log(Z_1)   =          -27.42 +/-  0.50 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         1889                              |
# | log(Z) =          -27.41801 +/-            0.49976 |
# |____________________________________________________|
#
#
#
#
#
# ---------- finished control ------------------

# %% [markdown]
# ## Plotting the results

# %% [markdown]
# Here we're trying to make sure that the plot makes sense. First, for clarity, let's create named parameters

# %%
paramnames = [(f'theta{i}', r'\theta_{}'.format(i)) for i in range(len(means))]
output["control"].make_paramnames_files(paramnames)

# %% [markdown]
# Use anesthetic to plot the results. We specify the types so that the plots don't take up too much space.

# %%
from anesthetic import NestedSamples
from os.path import join
# %matplotlib inline
import matplotlib.pyplot as plt


samples = {"control": NestedSamples(root = join(settings.base_dir, settings.file_root))}
fig, axes = samples["control"].plot_2d(['theta0', 'theta1', 'theta2', 'theta3', 'theta4', 'theta5'], types={'lower': 'kde', 'diagonal': 'kde'})

plt.show()

# %% [markdown]
# ## The evidence

# %% [markdown]
# Bayes' theorem reads as $$ \pi (\theta) {\cal L} (\theta) = {\cal Z}  {\cal P} (\theta),$$ where ${\cal Z}$ is the evidence, a scalar in our case. Because both the prior $\pi$ and ${\cal L}$ the likelihood are probability distributions, one of which is a mere uniform probability distribution, the other a multivariate Gaussian, we can derive the evidence analytically. $${\cal Z} = \int \pi ( \theta) {\cal L} (\theta)\, d\theta $$

# %% [markdown]
# Here $\pi (\theta)$ is a constant, that's equal to $$\prod_i (\theta_{max} - \theta_{min})_i $$ The ${\cal L}(\theta)$, is a correlated multivariate non-normalised Gaussian, which we evaluate to:
# $$ \int d\theta \exp \left[ - (\theta - \mu)^{T} \Sigma^{-1} \frac{(\theta - \mu) }{2}\right] = \sqrt{\det (2 \pi \Sigma)}$$

# %%
logZ_expected = len(means)*np.log(2*np.pi)/2 + np.linalg.slogdet(covs)[1]/2 - np.sum(np.log(bounds[:, 1] - bounds[:,0])); logZ_expected
# Out:
# -25.781804666999363

# %% [markdown]
# analytically, we on the other hand find:

# %%
(output["control"].logZ, output["control"].logZerr)
# Out:
# (-27.4180072395099, 0.499761594535287)

# %% [markdown]
# As we can see, nested sampling isn't perfect. We haven't found the full evidence. Moreover, the internal estimate of the error is insufficient:

# %%
(logZ_expected - output["control"].logZ) / output["control"].logZerr
# Out:
# 3.273966207891569

# %% [markdown]
# This doesn't wholly invalidate nested sampling, just means that you shouldn't **blindly** trust what the nested sampler tells you. If we look at the first 1000 estimates, we can see why.

# %%
plt.hist(samples["control"].logZ(1000)); plt.axvline(logZ_expected);plt.show()

# %% [markdown]
# **NOTE**: If we increased the number of live points, we might be able to suppress one of the source of error. We would *hope* that it would bring the average closer to the true value, but it might just reduce the error estimate, without moving the means closer together in any way.

# %% [markdown]
# # Testing polychord with `supernest`.

# %% [markdown]
# Supernest works by providing alternative (re-partitioned) views of the same problem. One such view is the so-called **proposal**. It's a multivariate Gaussian prior with an adjusted likelihood.

# %% [markdown]
# ## The proposal

# %%
import supernest as sn

# %%
proposal  = sn.gaussian_proposal(bounds.T, means, covs, loglike=control_ll); proposal
settings.file_root="proposal"

# %% [markdown]
# **NOTE**: the resultant proposal is an unbounded prior point-percent function. Meaning that the corners of the hypercube map to infinities. We cannot allow for that to happen, and so we move all `inf` and `nan` values to an agreed upon $\log 0$, and $-\log 0$ for plus and minus infinity.

# %%
proposal.prior(np.zeros(len(means)))
# Out:
# /mnt/Archive/Git/sspr/supernest/core.py:180: RuntimeWarning: invalid value encountered in matmul
#   theta = mean + covmat @ theta
# array([-1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30,
#        -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30,
#        -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30,
#        -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30, -1.e+30])

# %% [markdown]
# As you can see, this is a named tuple, whose members can be used directly in place of `control_ll` and `control_pr`.
#
# **note**: this might take a minute. Be patient!

# %%
output["proposal"] = pypolychord.run_polychord(proposal.likelihood, len(means), 0, settings, prior=proposal.prior)
print("\n\n\n\n\n\n\n\n\n  ------------------ finished proposal -------------------")
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      60
# nDims    :      27
# nDerived :       0
# Doing Clustering
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.156E-03 seconds
# number of repeats:          128
# started sampling
#
# _________________
# lives      |  60 |
# phantoms   |5190 |
# posteriors |  61 |
# equals     |  44 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                  61
# nposterior =                  61
# nequals    =                  39
# nlike      =               17957
# <nlike>    =         298.28   (           2.33 per slice )
# log(Z)     =          -26.24 +/-  0.07
# log(Z_1)   =          -26.24 +/-  0.07 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7311 |
# posteriors | 122 |
# equals     |  57 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 122
# nposterior =                 122
# nequals    =                  58
# nlike      =               73688
# <nlike>    =         928.85   (           7.26 per slice )
# log(Z)     =          -25.93 +/-  0.03
# log(Z_1)   =          -25.93 +/-  0.03 (still evaluating)
#
#
#
# _____________________________
# lives      |  48 |   4 |   8 |
# phantoms   |7379 | 420 | 826 |
# posteriors | 177 | 124 | 124 |
# equals     |  66 |  57 |  57 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                 181
# nposterior =                 181
# nequals    =                  62
# nlike      =              212155
# <nlike>    =        2307.78   (          18.03 per slice )
# log(Z)     =          -25.83 +/-  0.01
# log(Z_1)   =          -25.91 +/-  0.01 (still evaluating)
# log(Z_2)   =          -28.76 +/-  0.07 (still evaluating)
# log(Z_3)   =          -29.74 +/-  0.11 (still evaluating)
#
#
#
# ___________________________________
# lives      |  45 |   6 |   7 |   2 |
# phantoms   |6512 | 954 | 854 | 224 |
# posteriors | 231 | 128 | 127 | 126 |
# equals     |  66 |  57 |  57 |  57 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       4 /       4
# ndead      =                 244
# nposterior =                 244
# nequals    =                  63
# nlike      =              444617
# <nlike>    =        3874.37   (          30.27 per slice )
# log(Z)     =          -25.80 +/-  0.00
# log(Z_1)   =          -25.88 +/-  0.01 (still evaluating)
# log(Z_2)   =          -28.91 +/-  0.07 (still evaluating)
# log(Z_3)   =          -29.67 +/-  0.10 (still evaluating)
# log(Z_4)   =          -30.47 +/-  0.13 (still evaluating)
#
#
#
# _______________________________________________
# lives      |   1 |   8 |  31 |  13 |   6 |   1 |
# phantoms   | 183 | 984 |5786 |1421 |1591 | 204 |
# posteriors | 133 | 127 | 273 | 236 | 132 | 130 |
# equals     |  57 |  57 |  66 |  66 |  57 |  57 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       6 /       6
# ndead      =                 305
# nposterior =                 305
# nequals    =                  64
# nlike      =              913524
# <nlike>    =        7815.12   (          61.06 per slice )
# log(Z)     =          -25.79 +/-  0.00
# log(Z_1)   =          -26.03 +/-  0.01 (still evaluating)
# log(Z_2)   =          -27.79 +/-  0.06 (still evaluating)
# log(Z_3)   =          -29.02 +/-  0.07 (still evaluating)
# log(Z_4)   =          -29.65 +/-  0.10 (still evaluating)
# log(Z_5)   =          -30.45 +/-  0.13 (still evaluating)
# log(Z_6)   =          -30.93 +/-  0.14 (still evaluating)
#
#
#
# ___________________________________________________________
# lives      |   3 |  14 |   9 |   6 |   3 |  15 |   5 |   5 |
# phantoms   | 514 |2520 |1974 | 806 | 226 |3969 |1101 |1437 |
# posteriors | 135 | 247 | 140 | 131 | 128 | 294 | 283 | 276 |
# equals     |  57 |  66 |  57 |  57 |  57 |  66 |  66 |  66 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       8 /       9
# ndead      =                 366
# nposterior =                 366
# nequals    =                  65
# nlike      =             1545252
# <nlike>    =       10528.80   (          82.26 per slice )
# log(Z)     =          -25.78 +/-  0.00
# log(Z_1)   =          -26.54 +/-  0.02 (still evaluating)
# log(Z_2)   =          -27.55 +/-  0.04 (still evaluating)
# log(Z_3)   =          -27.69 +/-  0.04 (still evaluating)
# log(Z_4)   =          -27.79 +/-  0.06 (still evaluating)
# log(Z_5)   =          -29.00 +/-  0.07 (still evaluating)
# log(Z_6)   =          -29.64 +/-  0.10 (still evaluating)
# log(Z_7)   =          -30.80 +/-  0.13 (still evaluating)
# log(Z_8)   =          -30.92 +/-  0.14
# log(Z_9)   =          -31.62 +/-  0.16 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
#  ____________________________________________________
# |                                                    |
# | ndead  =          484                              |
# | log(Z) =          -25.78205 +/-            0.00012 |
# |____________________________________________________|
#
#
#
#
#
#
#
#
#
#   ------------------ finished proposal -------------------

# %% [markdown]
# We can now check the evidence

# %%
(logZ_expected - output["proposal"].logZ) / output["proposal"].logZerr
# Out:
# 2.150770120364112

# %% [markdown]
# Much better! Not only did we get closer to the expected theoretical result, but we did so faster:

# %%
(output["control"].ndead - output["proposal"].ndead)/output["proposal"].ndead
# Out:
# 2.902892561983471

# %% [markdown]
# and on top of all that, we got better precision:

# %%
(output["control"].logZerr - output["proposal"].logZerr) / output["proposal"].logZerr
# Out:
# 4318.111005617884

# %%
paramnames = [(f'theta{i}', r'\theta_{}'.format(i)) for i in range(len(means))]
output["proposal"].make_paramnames_files(paramnames)
samples["proposal"] = NestedSamples(root = join(settings.base_dir, settings.file_root))
fig, axes = samples["control"].plot_2d(['theta0', 'theta1', 'theta2', 'theta3', 'theta4', 'theta5'], types={'lower': 'kde', 'diagonal': 'kde'}, label="control")
samples["proposal"].plot_2d(axes, label="proposal")
handles, labels = axes["theta0"]["theta1"].get_legend_handles_labels()
fig.legend(handles, labels)
plt.show()

# %% [markdown]
# ## HERE BE DRAGONS: Truncated Gaussian proposals

# %% [markdown]
# In theory, the proposal that we've just created contains the exact shape of the posterior distribution. But it also includes areas of the original model that would have been rejected at the prior level. We could sacrifice some information by using the diagonal elements of the covariance matrix, and instead use the truncated normal distribution:

# %%
t_proposal  = sn.truncated_gaussian_proposal(bounds.T, means, covs, loglike=control_ll)
settings.file_root="t_proposal"

# %% [markdown]
# This prior never produces values outside the original prior.

# %%
t_proposal.prior(np.zeros(len(means)))
# Out:
# array([ 1.61000000e+00,  8.00000000e-01,  5.00000000e-01,  5.00000000e-03,
#         1.00000000e-03,  1.00000000e-02,  9.87434218e-01,  9.96681581e-01,
#         9.94782897e-01,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -1.45262567e+00,  5.47374328e-01, -1.92236591e+01,
#        -8.62625672e+00,  0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#         0.00000000e+00, -8.11051391e-02, -5.09472621e-02,  7.63184475e-03,
#        -1.54894524e-01,  2.37631845e-01, -7.76208931e-01])

# %%
output["t_proposal"] = pypolychord.run_polychord(t_proposal.likelihood, len(means), 0, settings, prior=t_proposal.prior)
print("\n\n\n\n\n\n\n\n\n\n ------------------ t_proposal_finished ------------------ ")
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      60
# nDims    :      27
# nDerived :       0
# Doing Clustering
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.163E-03 seconds
# number of repeats:          128
# started sampling
#
# _________________
# lives      |  60 |
# phantoms   |5013 |
# posteriors |  61 |
# equals     |  26 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                  61
# nposterior =                  61
# nequals    =                  28
# nlike      =                9575
# <nlike>    =         158.58   (           1.24 per slice )
# log(Z)     =          -66.05 +/-  0.14
# log(Z_1)   =          -66.05 +/-  0.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6053 |
# posteriors | 122 |
# equals     |  50 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 122
# nposterior =                 122
# nequals    =                  53
# nlike      =               22859
# <nlike>    =         221.40   (           1.73 per slice )
# log(Z)     =          -64.38 +/-  0.13
# log(Z_1)   =          -64.38 +/-  0.13 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7309 |
# posteriors | 183 |
# equals     |  66 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 183
# nposterior =                 183
# nequals    =                  62
# nlike      =               36135
# <nlike>    =         221.27   (           1.73 per slice )
# log(Z)     =          -63.31 +/-  0.15
# log(Z_1)   =          -63.31 +/-  0.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7605 |
# posteriors | 244 |
# equals     |  83 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 244
# nposterior =                 244
# nequals    =                  70
# nlike      =               49311
# <nlike>    =         219.60   (           1.72 per slice )
# log(Z)     =          -62.51 +/-  0.18
# log(Z_1)   =          -62.51 +/-  0.18 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6908 |
# posteriors | 305 |
# equals     | 126 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 305
# nposterior =                 305
# nequals    =                 111
# nlike      =               62805
# <nlike>    =         224.90   (           1.76 per slice )
# log(Z)     =          -61.93 +/-  0.20
# log(Z_1)   =          -61.93 +/-  0.20 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7376 |
# posteriors | 366 |
# equals     | 179 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 366
# nposterior =                 366
# nequals    =                 162
# nlike      =               76138
# <nlike>    =         222.22   (           1.74 per slice )
# log(Z)     =          -61.54 +/-  0.22
# log(Z_1)   =          -61.54 +/-  0.22 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8093 |
# posteriors | 427 |
# equals     | 229 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 427
# nposterior =                 427
# nequals    =                 208
# nlike      =               89450
# <nlike>    =         221.87   (           1.73 per slice )
# log(Z)     =          -61.28 +/-  0.23
# log(Z_1)   =          -61.28 +/-  0.23 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7716 |
# posteriors | 488 |
# equals     | 270 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 488
# nposterior =                 488
# nequals    =                 245
# nlike      =              102639
# <nlike>    =         219.82   (           1.72 per slice )
# log(Z)     =          -61.14 +/-  0.24
# log(Z_1)   =          -61.14 +/-  0.24 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7525 |
# posteriors | 549 |
# equals     | 298 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 549
# nposterior =                 549
# nequals    =                 273
# nlike      =              115961
# <nlike>    =         222.03   (           1.73 per slice )
# log(Z)     =          -61.03 +/-  0.24
# log(Z_1)   =          -61.03 +/-  0.24 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8232 |
# posteriors | 610 |
# equals     | 315 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 610
# nposterior =                 610
# nequals    =                 295
# nlike      =              129283
# <nlike>    =         222.03   (           1.73 per slice )
# log(Z)     =          -60.97 +/-  0.25
# log(Z_1)   =          -60.97 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6977 |
# posteriors | 671 |
# equals     | 332 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 671
# nposterior =                 671
# nequals    =                 305
# nlike      =              142418
# <nlike>    =         218.92   (           1.71 per slice )
# log(Z)     =          -60.93 +/-  0.25
# log(Z_1)   =          -60.93 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7038 |
# posteriors | 732 |
# equals     | 341 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 732
# nposterior =                 732
# nequals    =                 315
# nlike      =              156216
# <nlike>    =         229.97   (           1.80 per slice )
# log(Z)     =          -60.91 +/-  0.25
# log(Z_1)   =          -60.91 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8063 |
# posteriors | 793 |
# equals     | 343 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 793
# nposterior =                 793
# nequals    =                 319
# nlike      =              170147
# <nlike>    =         232.18   (           1.81 per slice )
# log(Z)     =          -60.89 +/-  0.25
# log(Z_1)   =          -60.89 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6466 |
# posteriors | 854 |
# equals     | 345 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 854
# nposterior =                 854
# nequals    =                 319
# nlike      =              183917
# <nlike>    =         229.50   (           1.79 per slice )
# log(Z)     =          -60.89 +/-  0.25
# log(Z_1)   =          -60.89 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8053 |
# posteriors | 915 |
# equals     | 345 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 915
# nposterior =                 915
# nequals    =                 319
# nlike      =              198121
# <nlike>    =         236.73   (           1.85 per slice )
# log(Z)     =          -60.88 +/-  0.25
# log(Z_1)   =          -60.88 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6501 |
# posteriors | 976 |
# equals     | 345 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 976
# nposterior =                 976
# nequals    =                 319
# nlike      =              211784
# <nlike>    =         227.72   (           1.78 per slice )
# log(Z)     =          -60.88 +/-  0.25
# log(Z_1)   =          -60.88 +/-  0.25 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         1083                              |
# | log(Z) =          -60.88075 +/-            0.25363 |
# |____________________________________________________|
#
#
#
#
#
#
#
#
#
#
#  ------------------ t_proposal_finished ------------------

# %%
paramnames = [(f'theta{i}', r'\theta_{}'.format(i)) for i in range(len(means))]
output["t_proposal"].make_paramnames_files(paramnames)

# %%
samples["t_proposal"] = NestedSamples(root = join(settings.base_dir, settings.file_root))
fig, axes = samples["t_proposal"].plot_2d(["theta0", "theta1", "theta2", "theta3", "theta4", "theta5"], types={'lower': 'kde', 'diagonal': 'kde'}, label="truncated_proposal")
samples["control"].plot_2d(axes, types={'lower': 'kde', 'diagonal': 'kde'}, label="contol")
handles, labels = axes["theta0"]["theta1"].get_legend_handles_labels()
fig.legend(handles, labels)

plt.show()

# %% [markdown]
# In summary: tighter posterior peaks, smaller evidence by three orders of magnitude: ($log \mathcal{Z}$ off by a factor of three).

# %% [markdown]
# ## Non-truncated diagonal proposal

# %% [markdown]
# The most reliable way to trigger runaway evidence escalation is to cut off the diagonal elements of the proposal covariance matrix.

# %% [markdown]
# This is *odd* because that's what the truncated proposal does, and it's fine.

# %%
settings.do_clustering = False
u_proposal = sn.gaussian_proposal(bounds.T, means, np.diag(np.diag(covs)), loglike=control_ll); settings.file_root = "u_proposal"
print("\n\n\n\n\n Starting u_proposal -------- this may take a minute ----------------")
output["u_proposal"] = pypolychord.run_polychord(u_proposal.likelihood, len(means), 0, settings, prior=u_proposal.prior)
# Out:
#  Starting u_proposal -------- this may take a minute ----------------
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      60
# nDims    :      27
# nDerived :       0
# Generating equally weighted posteriors
# Generating weighted posteriors
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.181E-03 seconds
# number of repeats:          128
# started sampling
#
# _________________
# lives      |  60 |
# phantoms   |5312 |
# posteriors |  61 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                  61
# nposterior =                  61
# nequals    =                   1
# nlike      =                9583
# <nlike>    =         158.72   (           1.24 per slice )
# log(Z)     =        -4340.30 +/-  0.83
# log(Z_1)   =        -4340.30 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6182 |
# posteriors | 122 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 122
# nposterior =                 122
# nequals    =                   1
# nlike      =               23544
# <nlike>    =         232.68   (           1.82 per slice )
# log(Z)     =        -1128.36 +/-  0.84
# log(Z_1)   =        -1128.36 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6943 |
# posteriors | 183 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 183
# nposterior =                 183
# nequals    =                   1
# nlike      =               37362
# <nlike>    =         230.30   (           1.80 per slice )
# log(Z)     =          117.68 +/-  0.85
# log(Z_1)   =          117.68 +/-  0.85 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7720 |
# posteriors | 244 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 244
# nposterior =                 244
# nequals    =                   1
# nlike      =               51512
# <nlike>    =         235.83   (           1.84 per slice )
# log(Z)     =         1282.26 +/-  0.86
# log(Z_1)   =         1282.26 +/-  0.86 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8417 |
# posteriors | 305 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 305
# nposterior =                 305
# nequals    =                   1
# nlike      =               66353
# <nlike>    =         247.35   (           1.93 per slice )
# log(Z)     =         2387.52 +/-  0.87
# log(Z_1)   =         2387.52 +/-  0.87 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8543 |
# posteriors | 366 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 366
# nposterior =                 366
# nequals    =                   1
# nlike      =               81504
# <nlike>    =         252.52   (           1.97 per slice )
# log(Z)     =         3591.08 +/-  0.88
# log(Z_1)   =         3591.08 +/-  0.88 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7752 |
# posteriors | 427 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 427
# nposterior =                 427
# nequals    =                   1
# nlike      =               96821
# <nlike>    =         255.28   (           1.99 per slice )
# log(Z)     =         5100.56 +/-  0.89
# log(Z_1)   =         5100.56 +/-  0.89 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8287 |
# posteriors | 488 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 488
# nposterior =                 488
# nequals    =                   1
# nlike      =              114238
# <nlike>    =         290.28   (           2.27 per slice )
# log(Z)     =         6349.43 +/-  0.82
# log(Z_1)   =         6349.43 +/-  0.82 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8853 |
# posteriors | 549 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 549
# nposterior =                 549
# nequals    =                   1
# nlike      =              133767
# <nlike>    =         325.48   (           2.54 per slice )
# log(Z)     =         7610.77 +/-  0.91
# log(Z_1)   =         7610.77 +/-  0.91 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8002 |
# posteriors | 610 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 610
# nposterior =                 610
# nequals    =                   1
# nlike      =              154086
# <nlike>    =         338.65   (           2.65 per slice )
# log(Z)     =         9172.63 +/-  0.91
# log(Z_1)   =         9172.63 +/-  0.91 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8080 |
# posteriors | 671 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 671
# nposterior =                 671
# nequals    =                   1
# nlike      =              177032
# <nlike>    =         382.43   (           2.99 per slice )
# log(Z)     =        10563.78 +/-  0.93
# log(Z_1)   =        10563.78 +/-  0.93 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7474 |
# posteriors | 732 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 732
# nposterior =                 732
# nequals    =                   1
# nlike      =              201638
# <nlike>    =         410.10   (           3.20 per slice )
# log(Z)     =        12241.78 +/-  0.93
# log(Z_1)   =        12241.78 +/-  0.93 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7576 |
# posteriors | 793 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 793
# nposterior =                 793
# nequals    =                   1
# nlike      =              228644
# <nlike>    =         450.10   (           3.52 per slice )
# log(Z)     =        13822.58 +/-  0.94
# log(Z_1)   =        13822.58 +/-  0.94 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8137 |
# posteriors | 854 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 854
# nposterior =                 854
# nequals    =                   1
# nlike      =              258388
# <nlike>    =         495.73   (           3.87 per slice )
# log(Z)     =        15155.84 +/-  0.95
# log(Z_1)   =        15155.84 +/-  0.95 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7613 |
# posteriors | 915 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 915
# nposterior =                 915
# nequals    =                   1
# nlike      =              288460
# <nlike>    =         501.20   (           3.92 per slice )
# log(Z)     =        16693.07 +/-  0.96
# log(Z_1)   =        16693.07 +/-  0.96 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8490 |
# posteriors | 976 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 976
# nposterior =                 976
# nequals    =                   1
# nlike      =              323014
# <nlike>    =         575.90   (           4.50 per slice )
# log(Z)     =        18031.75 +/-  0.97
# log(Z_1)   =        18031.75 +/-  0.97 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8346 |
# posteriors |1037 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1037
# nposterior =                1037
# nequals    =                   1
# nlike      =              357652
# <nlike>    =         577.30   (           4.51 per slice )
# log(Z)     =        19523.01 +/-  0.98
# log(Z_1)   =        19523.01 +/-  0.98 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8089 |
# posteriors |1098 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1098
# nposterior =                1098
# nequals    =                   1
# nlike      =              395991
# <nlike>    =         638.98   (           4.99 per slice )
# log(Z)     =        21033.84 +/-  0.99
# log(Z_1)   =        21033.84 +/-  0.99 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |8842 |
# posteriors |1159 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1159
# nposterior =                1159
# nequals    =                   1
# nlike      =              437618
# <nlike>    =         693.78   (           5.42 per slice )
# log(Z)     =        22499.68 +/-  0.99
# log(Z_1)   =        22499.68 +/-  0.99 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8044 |
# posteriors |1220 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1220
# nposterior =                1220
# nequals    =                   1
# nlike      =              477036
# <nlike>    =         656.97   (           5.13 per slice )
# log(Z)     =        24111.49 +/-  1.00
# log(Z_1)   =        24111.49 +/-  1.00 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7109 |
# posteriors |1281 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1281
# nposterior =                1281
# nequals    =                   1
# nlike      =              520015
# <nlike>    =         716.32   (           5.60 per slice )
# log(Z)     =        26054.74 +/-  1.01
# log(Z_1)   =        26054.74 +/-  1.01 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6953 |
# posteriors |1342 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1342
# nposterior =                1342
# nequals    =                   1
# nlike      =              563688
# <nlike>    =         727.88   (           5.69 per slice )
# log(Z)     =        28060.06 +/-  1.02
# log(Z_1)   =        28060.06 +/-  1.02 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6915 |
# posteriors |1403 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1403
# nposterior =                1403
# nequals    =                   1
# nlike      =              613937
# <nlike>    =         837.48   (           6.54 per slice )
# log(Z)     =        29729.25 +/-  1.03
# log(Z_1)   =        29729.25 +/-  1.03 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7414 |
# posteriors |1464 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1464
# nposterior =                1464
# nequals    =                   1
# nlike      =              669584
# <nlike>    =         927.45   (           7.25 per slice )
# log(Z)     =        31154.70 +/-  1.03
# log(Z_1)   =        31154.70 +/-  1.03 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7918 |
# posteriors |1525 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1525
# nposterior =                1525
# nequals    =                   1
# nlike      =              726459
# <nlike>    =         947.92   (           7.41 per slice )
# log(Z)     =        32445.98 +/-  1.04
# log(Z_1)   =        32445.98 +/-  1.04 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7598 |
# posteriors |1586 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1586
# nposterior =                1586
# nequals    =                   1
# nlike      =              785493
# <nlike>    =         983.90   (           7.69 per slice )
# log(Z)     =        34060.38 +/-  1.05
# log(Z_1)   =        34060.38 +/-  1.05 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7846 |
# posteriors |1647 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1647
# nposterior =                1647
# nequals    =                   1
# nlike      =              847275
# <nlike>    =        1029.70   (           8.04 per slice )
# log(Z)     =        35477.81 +/-  1.06
# log(Z_1)   =        35477.81 +/-  1.06 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8047 |
# posteriors |1708 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1708
# nposterior =                1708
# nequals    =                   1
# nlike      =              908877
# <nlike>    =        1026.70   (           8.02 per slice )
# log(Z)     =        36822.08 +/-  1.07
# log(Z_1)   =        36822.08 +/-  1.07 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7696 |
# posteriors |1769 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1769
# nposterior =                1769
# nequals    =                   1
# nlike      =              965226
# <nlike>    =         939.15   (           7.34 per slice )
# log(Z)     =        38232.01 +/-  1.07
# log(Z_1)   =        38232.01 +/-  1.07 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7693 |
# posteriors |1830 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1830
# nposterior =                1830
# nequals    =                   1
# nlike      =             1016656
# <nlike>    =         857.17   (           6.70 per slice )
# log(Z)     =        40081.59 +/-  1.08
# log(Z_1)   =        40081.59 +/-  1.08 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7717 |
# posteriors |1891 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1891
# nposterior =                1891
# nequals    =                   1
# nlike      =             1039013
# <nlike>    =         372.62   (           2.91 per slice )
# log(Z)     =        41971.76 +/-  1.09
# log(Z_1)   =        41971.76 +/-  1.09 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7502 |
# posteriors |1952 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1952
# nposterior =                1952
# nequals    =                   1
# nlike      =             1060706
# <nlike>    =         361.55   (           2.82 per slice )
# log(Z)     =        43783.32 +/-  1.10
# log(Z_1)   =        43783.32 +/-  1.10 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8105 |
# posteriors |2013 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2013
# nposterior =                2013
# nequals    =                   1
# nlike      =             1080599
# <nlike>    =         331.55   (           2.59 per slice )
# log(Z)     =        45266.10 +/-  1.10
# log(Z_1)   =        45266.10 +/-  1.10 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7369 |
# posteriors |2074 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2074
# nposterior =                2074
# nequals    =                   1
# nlike      =             1101426
# <nlike>    =         347.12   (           2.71 per slice )
# log(Z)     =        46973.27 +/-  1.11
# log(Z_1)   =        46973.27 +/-  1.11 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7528 |
# posteriors |2135 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2135
# nposterior =                2135
# nequals    =                   1
# nlike      =             1121174
# <nlike>    =         329.13   (           2.57 per slice )
# log(Z)     =        48549.27 +/-  1.12
# log(Z_1)   =        48549.27 +/-  1.12 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7908 |
# posteriors |2196 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2196
# nposterior =                2196
# nequals    =                   1
# nlike      =             1145267
# <nlike>    =         401.55   (           3.14 per slice )
# log(Z)     =        50000.25 +/-  1.13
# log(Z_1)   =        50000.25 +/-  1.13 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7407 |
# posteriors |2257 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2257
# nposterior =                2257
# nequals    =                   1
# nlike      =             1171353
# <nlike>    =         434.77   (           3.40 per slice )
# log(Z)     =        51660.26 +/-  1.12
# log(Z_1)   =        51660.26 +/-  1.12 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |8506 |
# posteriors |2318 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2318
# nposterior =                2318
# nequals    =                   1
# nlike      =             1194863
# <nlike>    =         391.83   (           3.06 per slice )
# log(Z)     =        53090.57 +/-  1.14
# log(Z_1)   =        53090.57 +/-  1.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8675 |
# posteriors |2379 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2379
# nposterior =                2379
# nequals    =                   1
# nlike      =             1218425
# <nlike>    =         392.70   (           3.07 per slice )
# log(Z)     =        54536.09 +/-  1.15
# log(Z_1)   =        54536.09 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |9129 |
# posteriors |2440 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2440
# nposterior =                2440
# nequals    =                   1
# nlike      =             1238455
# <nlike>    =         333.83   (           2.61 per slice )
# log(Z)     =        55924.51 +/-  1.15
# log(Z_1)   =        55924.51 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8370 |
# posteriors |2501 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2501
# nposterior =                2501
# nequals    =                   1
# nlike      =             1261497
# <nlike>    =         384.03   (           3.00 per slice )
# log(Z)     =        57415.29 +/-  1.16
# log(Z_1)   =        57415.29 +/-  1.16 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7128 |
# posteriors |2562 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2562
# nposterior =                2562
# nequals    =                   1
# nlike      =             1282076
# <nlike>    =         342.98   (           2.68 per slice )
# log(Z)     =        59261.46 +/-  1.17
# log(Z_1)   =        59261.46 +/-  1.17 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7120 |
# posteriors |2623 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2623
# nposterior =                2623
# nequals    =                   1
# nlike      =             1313549
# <nlike>    =         524.55   (           4.10 per slice )
# log(Z)     =        61025.40 +/-  1.18
# log(Z_1)   =        61025.40 +/-  1.18 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8286 |
# posteriors |2684 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2684
# nposterior =                2684
# nequals    =                   1
# nlike      =             1343320
# <nlike>    =         496.18   (           3.88 per slice )
# log(Z)     =        62295.09 +/-  1.18
# log(Z_1)   =        62295.09 +/-  1.18 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7588 |
# posteriors |2745 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2745
# nposterior =                2745
# nequals    =                   1
# nlike      =             1370181
# <nlike>    =         447.68   (           3.50 per slice )
# log(Z)     =        64033.11 +/-  1.19
# log(Z_1)   =        64033.11 +/-  1.19 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8298 |
# posteriors |2806 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2806
# nposterior =                2806
# nequals    =                   1
# nlike      =             1393335
# <nlike>    =         385.90   (           3.01 per slice )
# log(Z)     =        65505.35 +/-  1.19
# log(Z_1)   =        65505.35 +/-  1.19 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8500 |
# posteriors |2867 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2867
# nposterior =                2867
# nequals    =                   1
# nlike      =             1417441
# <nlike>    =         401.77   (           3.14 per slice )
# log(Z)     =        66964.75 +/-  1.20
# log(Z_1)   =        66964.75 +/-  1.20 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7658 |
# posteriors |2928 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2928
# nposterior =                2928
# nequals    =                   1
# nlike      =             1442063
# <nlike>    =         410.37   (           3.21 per slice )
# log(Z)     =        68495.83 +/-  1.21
# log(Z_1)   =        68495.83 +/-  1.21 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7102 |
# posteriors |2989 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2989
# nposterior =                2989
# nequals    =                   1
# nlike      =             1464397
# <nlike>    =         372.23   (           2.91 per slice )
# log(Z)     =        70177.51 +/-  1.22
# log(Z_1)   =        70177.51 +/-  1.22 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7545 |
# posteriors |3050 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3050
# nposterior =                3050
# nequals    =                   1
# nlike      =             1489242
# <nlike>    =         414.08   (           3.24 per slice )
# log(Z)     =        71665.74 +/-  1.22
# log(Z_1)   =        71665.74 +/-  1.22 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7103 |
# posteriors |3111 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3111
# nposterior =                3111
# nequals    =                   1
# nlike      =             1515315
# <nlike>    =         434.55   (           3.39 per slice )
# log(Z)     =        73500.10 +/-  1.23
# log(Z_1)   =        73500.10 +/-  1.23 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7779 |
# posteriors |3172 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3172
# nposterior =                3172
# nequals    =                   1
# nlike      =             1542740
# <nlike>    =         457.08   (           3.57 per slice )
# log(Z)     =        74876.74 +/-  1.24
# log(Z_1)   =        74876.74 +/-  1.24 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7047 |
# posteriors |3233 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3233
# nposterior =                3233
# nequals    =                   1
# nlike      =             1569062
# <nlike>    =         438.70   (           3.43 per slice )
# log(Z)     =        76610.65 +/-  1.24
# log(Z_1)   =        76610.65 +/-  1.24 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7436 |
# posteriors |3294 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3294
# nposterior =                3294
# nequals    =                   1
# nlike      =             1601230
# <nlike>    =         536.13   (           4.19 per slice )
# log(Z)     =        78048.39 +/-  1.25
# log(Z_1)   =        78048.39 +/-  1.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6923 |
# posteriors |3355 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3355
# nposterior =                3355
# nequals    =                   1
# nlike      =             1630040
# <nlike>    =         480.17   (           3.75 per slice )
# log(Z)     =        79618.76 +/-  1.26
# log(Z_1)   =        79618.76 +/-  1.26 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8533 |
# posteriors |3416 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3416
# nposterior =                3416
# nequals    =                   1
# nlike      =             1661703
# <nlike>    =         527.72   (           4.12 per slice )
# log(Z)     =        80696.78 +/-  1.26
# log(Z_1)   =        80696.78 +/-  1.26 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |8003 |
# posteriors |3477 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3477
# nposterior =                3477
# nequals    =                   1
# nlike      =             1691351
# <nlike>    =         494.13   (           3.86 per slice )
# log(Z)     =        82077.11 +/-  1.27
# log(Z_1)   =        82077.11 +/-  1.27 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8474 |
# posteriors |3538 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3538
# nposterior =                3538
# nequals    =                   1
# nlike      =             1723383
# <nlike>    =         533.87   (           4.17 per slice )
# log(Z)     =        83293.60 +/-  1.27
# log(Z_1)   =        83293.60 +/-  1.27 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6912 |
# posteriors |3599 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3599
# nposterior =                3599
# nequals    =                   1
# nlike      =             1760670
# <nlike>    =         621.45   (           4.86 per slice )
# log(Z)     =        84863.68 +/-  1.28
# log(Z_1)   =        84863.68 +/-  1.28 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7389 |
# posteriors |3660 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3660
# nposterior =                3660
# nequals    =                   1
# nlike      =             1793618
# <nlike>    =         549.13   (           4.29 per slice )
# log(Z)     =        86297.76 +/-  1.29
# log(Z_1)   =        86297.76 +/-  1.29 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8115 |
# posteriors |3721 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3721
# nposterior =                3721
# nequals    =                   1
# nlike      =             1826776
# <nlike>    =         552.63   (           4.32 per slice )
# log(Z)     =        87520.98 +/-  1.29
# log(Z_1)   =        87520.98 +/-  1.29 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8290 |
# posteriors |3782 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3782
# nposterior =                3782
# nequals    =                   1
# nlike      =             1857963
# <nlike>    =         519.78   (           4.06 per slice )
# log(Z)     =        88854.70 +/-  1.30
# log(Z_1)   =        88854.70 +/-  1.30 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8031 |
# posteriors |3843 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3843
# nposterior =                3843
# nequals    =                   1
# nlike      =             1892529
# <nlike>    =         576.10   (           4.50 per slice )
# log(Z)     =        90333.18 +/-  1.30
# log(Z_1)   =        90333.18 +/-  1.30 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7690 |
# posteriors |3904 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3904
# nposterior =                3904
# nequals    =                   1
# nlike      =             1924913
# <nlike>    =         539.73   (           4.22 per slice )
# log(Z)     =        91844.03 +/-  1.29
# log(Z_1)   =        91844.03 +/-  1.29 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6914 |
# posteriors |3965 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3965
# nposterior =                3965
# nequals    =                   1
# nlike      =             1952512
# <nlike>    =         459.98   (           3.59 per slice )
# log(Z)     =        93673.32 +/-  1.32
# log(Z_1)   =        93673.32 +/-  1.32 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6797 |
# posteriors |4026 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4026
# nposterior =                4026
# nequals    =                   1
# nlike      =             1977225
# <nlike>    =         411.88   (           3.22 per slice )
# log(Z)     =        95523.20 +/-  1.33
# log(Z_1)   =        95523.20 +/-  1.33 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8476 |
# posteriors |4087 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4087
# nposterior =                4087
# nequals    =                   1
# nlike      =             2007209
# <nlike>    =         499.73   (           3.90 per slice )
# log(Z)     =        96848.01 +/-  1.33
# log(Z_1)   =        96848.01 +/-  1.33 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7170 |
# posteriors |4148 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4148
# nposterior =                4148
# nequals    =                   1
# nlike      =             2039560
# <nlike>    =         539.18   (           4.21 per slice )
# log(Z)     =        98659.46 +/-  1.34
# log(Z_1)   =        98659.46 +/-  1.34 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7645 |
# posteriors |4209 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4209
# nposterior =                4209
# nequals    =                   1
# nlike      =             2067189
# <nlike>    =         460.48   (           3.60 per slice )
# log(Z)     =       100221.43 +/-  1.34
# log(Z_1)   =       100221.43 +/-  1.34 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8573 |
# posteriors |4270 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4270
# nposterior =                4270
# nequals    =                   1
# nlike      =             2102703
# <nlike>    =         591.90   (           4.62 per slice )
# log(Z)     =       101510.85 +/-  1.35
# log(Z_1)   =       101510.85 +/-  1.35 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8260 |
# posteriors |4331 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4331
# nposterior =                4331
# nequals    =                   1
# nlike      =             2141193
# <nlike>    =         641.50   (           5.01 per slice )
# log(Z)     =       102967.56 +/-  1.36
# log(Z_1)   =       102967.56 +/-  1.36 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7745 |
# posteriors |4392 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4392
# nposterior =                4392
# nequals    =                   1
# nlike      =             2179423
# <nlike>    =         637.17   (           4.98 per slice )
# log(Z)     =       104511.31 +/-  1.36
# log(Z_1)   =       104511.31 +/-  1.36 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7851 |
# posteriors |4453 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4453
# nposterior =                4453
# nequals    =                   1
# nlike      =             2221026
# <nlike>    =         693.38   (           5.42 per slice )
# log(Z)     =       105842.00 +/-  1.37
# log(Z_1)   =       105842.00 +/-  1.37 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8384 |
# posteriors |4514 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4514
# nposterior =                4514
# nequals    =                   1
# nlike      =             2257285
# <nlike>    =         604.32   (           4.72 per slice )
# log(Z)     =       107141.16 +/-  1.37
# log(Z_1)   =       107141.16 +/-  1.37 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8246 |
# posteriors |4575 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4575
# nposterior =                4575
# nequals    =                   1
# nlike      =             2299539
# <nlike>    =         704.23   (           5.50 per slice )
# log(Z)     =       108466.95 +/-  1.35
# log(Z_1)   =       108466.95 +/-  1.35 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7856 |
# posteriors |4636 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4636
# nposterior =                4636
# nequals    =                   1
# nlike      =             2346767
# <nlike>    =         787.13   (           6.15 per slice )
# log(Z)     =       109941.00 +/-  1.37
# log(Z_1)   =       109941.00 +/-  1.37 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7511 |
# posteriors |4697 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4697
# nposterior =                4697
# nequals    =                   1
# nlike      =             2415814
# <nlike>    =        1150.78   (           8.99 per slice )
# log(Z)     =       111332.47 +/-  1.39
# log(Z_1)   =       111332.47 +/-  1.39 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7977 |
# posteriors |4758 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4758
# nposterior =                4758
# nequals    =                   1
# nlike      =             2467972
# <nlike>    =         869.30   (           6.79 per slice )
# log(Z)     =       112694.42 +/-  1.35
# log(Z_1)   =       112694.42 +/-  1.35 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8435 |
# posteriors |4819 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4819
# nposterior =                4819
# nequals    =                   1
# nlike      =             2537333
# <nlike>    =        1156.02   (           9.03 per slice )
# log(Z)     =       113953.61 +/-  1.40
# log(Z_1)   =       113953.61 +/-  1.40 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7116 |
# posteriors |4880 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4880
# nposterior =                4880
# nequals    =                   1
# nlike      =             2603494
# <nlike>    =        1102.68   (           8.61 per slice )
# log(Z)     =       115504.10 +/-  1.41
# log(Z_1)   =       115504.10 +/-  1.41 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7784 |
# posteriors |4941 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4941
# nposterior =                4941
# nequals    =                   1
# nlike      =             2667403
# <nlike>    =        1065.15   (           8.32 per slice )
# log(Z)     =       116675.12 +/-  1.42
# log(Z_1)   =       116675.12 +/-  1.42 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7727 |
# posteriors |5002 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5002
# nposterior =                5002
# nequals    =                   1
# nlike      =             2751741
# <nlike>    =        1405.63   (          10.98 per slice )
# log(Z)     =       117897.43 +/-  1.42
# log(Z_1)   =       117897.43 +/-  1.42 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8754 |
# posteriors |5063 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5063
# nposterior =                5063
# nequals    =                   1
# nlike      =             2827124
# <nlike>    =        1256.38   (           9.82 per slice )
# log(Z)     =       118923.29 +/-  1.43
# log(Z_1)   =       118923.29 +/-  1.43 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7734 |
# posteriors |5124 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5124
# nposterior =                5124
# nequals    =                   1
# nlike      =             2916032
# <nlike>    =        1481.80   (          11.58 per slice )
# log(Z)     =       120257.43 +/-  1.43
# log(Z_1)   =       120257.43 +/-  1.43 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8699 |
# posteriors |5185 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5185
# nposterior =                5185
# nequals    =                   1
# nlike      =             2996980
# <nlike>    =        1349.13   (          10.54 per slice )
# log(Z)     =       121388.00 +/-  1.44
# log(Z_1)   =       121388.00 +/-  1.44 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8867 |
# posteriors |5246 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5246
# nposterior =                5246
# nequals    =                   1
# nlike      =             3072081
# <nlike>    =        1251.68   (           9.78 per slice )
# log(Z)     =       122634.94 +/-  1.44
# log(Z_1)   =       122634.94 +/-  1.44 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8536 |
# posteriors |5307 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5307
# nposterior =                5307
# nequals    =                   1
# nlike      =             3145065
# <nlike>    =        1216.40   (           9.50 per slice )
# log(Z)     =       123990.89 +/-  1.45
# log(Z_1)   =       123990.89 +/-  1.45 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6778 |
# posteriors |5368 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5368
# nposterior =                5368
# nequals    =                   1
# nlike      =             3221235
# <nlike>    =        1269.50   (           9.92 per slice )
# log(Z)     =       125817.15 +/-  1.46
# log(Z_1)   =       125817.15 +/-  1.46 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7726 |
# posteriors |5429 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5429
# nposterior =                5429
# nequals    =                   2
# nlike      =             3300961
# <nlike>    =        1328.77   (          10.38 per slice )
# log(Z)     =       127034.43 +/-  1.33
# log(Z_1)   =       127034.43 +/-  1.33 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8540 |
# posteriors |5490 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5490
# nposterior =                5490
# nequals    =                   1
# nlike      =             3379487
# <nlike>    =        1308.77   (          10.22 per slice )
# log(Z)     =       128136.10 +/-  1.47
# log(Z_1)   =       128136.10 +/-  1.47 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8988 |
# posteriors |5551 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5551
# nposterior =                5551
# nequals    =                   1
# nlike      =             3459645
# <nlike>    =        1335.97   (          10.44 per slice )
# log(Z)     =       129318.87 +/-  1.47
# log(Z_1)   =       129318.87 +/-  1.47 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7992 |
# posteriors |5612 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5612
# nposterior =                5612
# nequals    =                   1
# nlike      =             3541570
# <nlike>    =        1365.42   (          10.67 per slice )
# log(Z)     =       130696.94 +/-  1.48
# log(Z_1)   =       130696.94 +/-  1.48 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8258 |
# posteriors |5673 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5673
# nposterior =                5673
# nequals    =                   1
# nlike      =             3624933
# <nlike>    =        1389.38   (          10.85 per slice )
# log(Z)     =       132014.76 +/-  1.48
# log(Z_1)   =       132014.76 +/-  1.48 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7949 |
# posteriors |5734 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5734
# nposterior =                5734
# nequals    =                   1
# nlike      =             3707297
# <nlike>    =        1372.73   (          10.72 per slice )
# log(Z)     =       133237.77 +/-  1.49
# log(Z_1)   =       133237.77 +/-  1.49 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |8840 |
# posteriors |5795 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5795
# nposterior =                5795
# nequals    =                   1
# nlike      =             3792855
# <nlike>    =        1425.97   (          11.14 per slice )
# log(Z)     =       134317.11 +/-  1.49
# log(Z_1)   =       134317.11 +/-  1.49 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7563 |
# posteriors |5856 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5856
# nposterior =                5856
# nequals    =                   1
# nlike      =             3879554
# <nlike>    =        1444.98   (          11.29 per slice )
# log(Z)     =       135645.63 +/-  1.49
# log(Z_1)   =       135645.63 +/-  1.49 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8218 |
# posteriors |5917 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5917
# nposterior =                5917
# nequals    =                   1
# nlike      =             3970097
# <nlike>    =        1509.05   (          11.79 per slice )
# log(Z)     =       136776.10 +/-  1.51
# log(Z_1)   =       136776.10 +/-  1.51 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7469 |
# posteriors |5978 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5978
# nposterior =                5978
# nequals    =                   1
# nlike      =             4057858
# <nlike>    =        1462.68   (          11.43 per slice )
# log(Z)     =       138013.91 +/-  1.51
# log(Z_1)   =       138013.91 +/-  1.51 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8221 |
# posteriors |6039 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6039
# nposterior =                6039
# nequals    =                   1
# nlike      =             4142594
# <nlike>    =        1412.27   (          11.03 per slice )
# log(Z)     =       139134.83 +/-  1.44
# log(Z_1)   =       139134.83 +/-  1.44 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7481 |
# posteriors |6100 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6100
# nposterior =                6100
# nequals    =                   1
# nlike      =             4227453
# <nlike>    =        1414.32   (          11.05 per slice )
# log(Z)     =       140565.79 +/-  1.52
# log(Z_1)   =       140565.79 +/-  1.52 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8303 |
# posteriors |6161 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6161
# nposterior =                6161
# nequals    =                   1
# nlike      =             4318026
# <nlike>    =        1509.55   (          11.79 per slice )
# log(Z)     =       141623.77 +/-  1.53
# log(Z_1)   =       141623.77 +/-  1.53 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7142 |
# posteriors |6222 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6222
# nposterior =                6222
# nequals    =                   1
# nlike      =             4399850
# <nlike>    =        1363.73   (          10.65 per slice )
# log(Z)     =       143113.23 +/-  1.53
# log(Z_1)   =       143113.23 +/-  1.53 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7978 |
# posteriors |6283 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6283
# nposterior =                6283
# nequals    =                   1
# nlike      =             4481301
# <nlike>    =        1357.52   (          10.61 per slice )
# log(Z)     =       144421.29 +/-  1.54
# log(Z_1)   =       144421.29 +/-  1.54 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7182 |
# posteriors |6344 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6344
# nposterior =                6344
# nequals    =                   1
# nlike      =             4561026
# <nlike>    =        1328.75   (          10.38 per slice )
# log(Z)     =       146033.20 +/-  1.54
# log(Z_1)   =       146033.20 +/-  1.54 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8084 |
# posteriors |6405 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6405
# nposterior =                6405
# nequals    =                   1
# nlike      =             4642046
# <nlike>    =        1350.33   (          10.55 per slice )
# log(Z)     =       147358.79 +/-  1.55
# log(Z_1)   =       147358.79 +/-  1.55 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7533 |
# posteriors |6466 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6466
# nposterior =                6466
# nequals    =                   1
# nlike      =             4722988
# <nlike>    =        1349.03   (          10.54 per slice )
# log(Z)     =       148734.28 +/-  1.52
# log(Z_1)   =       148734.28 +/-  1.52 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7115 |
# posteriors |6527 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6527
# nposterior =                6527
# nequals    =                   1
# nlike      =             4799883
# <nlike>    =        1281.58   (          10.01 per slice )
# log(Z)     =       150060.59 +/-  1.56
# log(Z_1)   =       150060.59 +/-  1.56 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7246 |
# posteriors |6588 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6588
# nposterior =                6588
# nequals    =                   1
# nlike      =             4821535
# <nlike>    =         360.87   (           2.82 per slice )
# log(Z)     =       151161.56 +/-  1.56
# log(Z_1)   =       151161.56 +/-  1.56 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7622 |
# posteriors |6649 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6649
# nposterior =                6649
# nequals    =                   1
# nlike      =             4843549
# <nlike>    =         366.90   (           2.87 per slice )
# log(Z)     =       152177.05 +/-  1.56
# log(Z_1)   =       152177.05 +/-  1.56 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7464 |
# posteriors |6710 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ...
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 8035 |
# posteriors |15494 |
# equals     |    6 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15494
# nposterior =               15494
# nequals    =                   6
# nlike      =             9423268
# <nlike>    =         389.00   (           3.04 per slice )
# log(Z)     =       247132.98 +/-  2.07
# log(Z_1)   =       247132.98 +/-  2.07 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 8025 |
# posteriors |15555 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15555
# nposterior =               15555
# nequals    =                   1
# nlike      =             9459664
# <nlike>    =         606.60   (           4.74 per slice )
# log(Z)     =       247177.76 +/-  2.12
# log(Z_1)   =       247177.76 +/-  2.12 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 8459 |
# posteriors |15616 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15616
# nposterior =               15616
# nequals    =                   1
# nlike      =             9483648
# <nlike>    =         399.73   (           3.12 per slice )
# log(Z)     =       247241.97 +/-  2.10
# log(Z_1)   =       247241.97 +/-  2.10 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 7177 |
# posteriors |15677 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15677
# nposterior =               15677
# nequals    =                   2
# nlike      =             9529824
# <nlike>    =         769.60   (           6.01 per slice )
# log(Z)     =       247295.17 +/-  2.11
# log(Z_1)   =       247295.17 +/-  2.11 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 7434 |
# posteriors |15738 |
# equals     |    4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15738
# nposterior =               15738
# nequals    =                   2
# nlike      =             9553245
# <nlike>    =         390.35   (           3.05 per slice )
# log(Z)     =       247327.61 +/-  2.09
# log(Z_1)   =       247327.61 +/-  2.09 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 7798 |
# posteriors |15799 |
# equals     |    9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15799
# nposterior =               15799
# nequals    =                   6
# nlike      =             9577583
# <nlike>    =         405.63   (           3.17 per slice )
# log(Z)     =       247351.62 +/-  2.07
# log(Z_1)   =       247351.62 +/-  2.07 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 8506 |
# posteriors |15860 |
# equals     |   23 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15860
# nposterior =               15860
# nequals    =                  24
# nlike      =             9603030
# <nlike>    =         424.12   (           3.31 per slice )
# log(Z)     =       247371.48 +/-  2.07
# log(Z_1)   =       247371.48 +/-  2.07 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 9239 |
# posteriors |15921 |
# equals     |   11 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15921
# nposterior =               15921
# nequals    =                   9
# nlike      =             9632189
# <nlike>    =         485.98   (           3.80 per slice )
# log(Z)     =       247376.88 +/-  2.08
# log(Z_1)   =       247376.88 +/-  2.08 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 7659 |
# posteriors |15982 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               15982
# nposterior =               15982
# nequals    =                   1
# nlike      =             9661084
# <nlike>    =         481.58   (           3.76 per slice )
# log(Z)     =       247388.22 +/-  2.23
# log(Z_1)   =       247388.22 +/-  2.23 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 8658 |
# posteriors |16043 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               16043
# nposterior =               16043
# nequals    =                   3
# nlike      =             9683258
# <nlike>    =         369.57   (           2.89 per slice )
# log(Z)     =       247472.59 +/-  2.14
# log(Z_1)   =       247472.59 +/-  2.14 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 9154 |
# posteriors |16104 |
# equals     |   20 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               16104
# nposterior =               16104
# nequals    =                  24
# nlike      =             9710292
# <nlike>    =         450.57   (           3.52 per slice )
# log(Z)     =       247507.07 +/-  2.08
# log(Z_1)   =       247507.07 +/-  2.08 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 8581 |
# posteriors |16165 |
# equals     |   48 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               16165
# nposterior =               16165
# nequals    =                  50
# nlike      =             9756906
# <nlike>    =         776.90   (           6.07 per slice )
# log(Z)     =       247507.84 +/-  2.08
# log(Z_1)   =       247507.84 +/-  2.08 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   |11408 |
# posteriors |16226 |
# equals     |   56 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               16226
# nposterior =               16226
# nequals    =                  56
# nlike      =             9833868
# <nlike>    =        1282.70   (          10.02 per slice )
# log(Z)     =       247508.01 +/-  2.08
# log(Z_1)   =       247508.01 +/-  2.08 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =        16323                              |
# | log(Z) =       247508.10250 +/-            2.07875 |
# |____________________________________________________|
# Warning, unable to proceed after     61: failed spawn events

# %%
output["u_proposal"].logZ
# Out:
# 140832.045414337

# %% [markdown]
# So bad that it refuses to plot.

# %%
paramnames = [(f'theta{i}', r'\theta_{}'.format(i)) for i in range(len(means))]
output["u_proposal"].make_paramnames_files(paramnames)
samples["u_proposal"] = NestedSamples(root = join(settings.base_dir, settings.file_root))

fig, axes = samples["u_proposal"].plot_2d(["theta0", "theta1", "theta2", "theta3", "theta4", "theta5"], types={'lower': 'scatter', 'diagonal': 'hist'}, label="uncorrelated proposal")
samples["control"].plot_2d(axes, label="contol")
handles, labels = axes["theta0"]["theta1"].get_legend_handles_labels()

fig.legend(handles, labels)

plt.show()
# Out:
# /home/app/.local/lib/python3.9/site-packages/anesthetic/samples.py:748: RuntimeWarning: 273 out of 8138 samples have logL <= logL_birth,
# 273 of which have logL == logL_birth.
# This may just indicate numerical rounding errors at the peak of the likelihood, but further investigation of the chains files is recommended.
# Dropping the invalid samples.
#   warnings.warn("%i out of %i samples have logL <= logL_birth,"
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_7976/764812930.py in <module>
#       3 samples["u_proposal"] = NestedSamples(root = join(settings.base_dir, settings.file_root))
#       4
# ----> 5 fig, axes = samples["u_proposal"].plot_2d(["theta0", "theta1", "theta2", "theta3", "theta4", "theta5"], types={'lower': 'kde', 'diagonal': 'kde'}, label="uncorrelated proposal")
#       6 samples["control"].plot_2d(axes, types={'lower': 'kde', 'diagonal': 'kde'}, label="contol")
#       7 handles, labels = axes["theta0"]["theta1"].get_legend_handles_labels()
#
# ~/.local/lib/python3.9/site-packages/anesthetic/samples.py in plot_2d(self, axes, *args, **kwargs)
#     342                     plot_type = types.get(pos, None)
#     343                     lkwargs = local_kwargs.get(pos, {})
# --> 344                     self.plot(ax_, x, y, plot_type=plot_type, *args, **lkwargs)
#     345
#     346         return fig, axes
#
# ~/.local/lib/python3.9/site-packages/anesthetic/samples.py in plot(self, ax, paramname_x, paramname_y, *args, **kwargs)
#     211                     x = self[paramname_x]
#     212                     y = self[paramname_y]
# --> 213                     return kde_contour_plot_2d(ax, x, y, weights=self.weights,
#     214                                                ncompress=ncompress,
#     215                                                *args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/anesthetic/plot.py in kde_contour_plot_2d(ax, data_x, data_y, *args, **kwargs)
#     829         linewidths = kwargs.pop('linewidths', 0.5)
#     830         cmap = kwargs.pop('cmap', basic_cmap(facecolor))
# --> 831         contf = ax.tricontourf(tri, p, contours, cmap=cmap, zorder=zorder,
#     832                                vmin=0, vmax=p.max(), *args, **kwargs)
#     833         for c in contf.collections:
#
# ~/.local/lib/python3.9/site-packages/matplotlib/tri/tricontour.py in tricontourf(ax, *args, **kwargs)
#     321     """
#     322     kwargs['filled'] = True
# --> 323     return TriContourSet(ax, *args, **kwargs)
#
# ~/.local/lib/python3.9/site-packages/matplotlib/tri/tricontour.py in __init__(self, ax, *args, **kwargs)
#      27         are described in the docstring of `~.Axes.tricontour`.
#      28         """
# ---> 29         super().__init__(ax, *args, **kwargs)
#      30
#      31     def _process_args(self, *args, **kwargs):
#
# ~/.local/lib/python3.9/site-packages/matplotlib/contour.py in __init__(self, ax, levels, filled, linewidths, linestyles, hatches, alpha, origin, extent, cmap, colors, norm, vmin, vmax, extend, antialiased, nchunk, locator, transform, *args, **kwargs)
#     775         self._transform = transform
#     776
# --> 777         kwargs = self._process_args(*args, **kwargs)
#     778         self._process_levels()
#     779
#
# ~/.local/lib/python3.9/site-packages/matplotlib/tri/tricontour.py in _process_args(self, *args, **kwargs)
#      39         else:
#      40             from matplotlib import _tri
# ---> 41             tri, z = self._contour_args(args, kwargs)
#      42             C = _tri.TriContourGenerator(tri.get_cpp_triangulation(), z)
#      43             self._mins = [tri.x.min(), tri.y.min()]
#
# ~/.local/lib/python3.9/site-packages/matplotlib/tri/tricontour.py in _contour_args(self, args, kwargs)
#      94         if self.logscale and self.zmin <= 0:
#      95             raise ValueError('Cannot %s log of negative values.' % fn)
# ---> 96         self._process_contour_level_args(args[1:])
#      97         return (tri, z)
#      98
#
# ~/.local/lib/python3.9/site-packages/matplotlib/contour.py in _process_contour_level_args(self, args)
#    1117
#    1118         if len(self.levels) > 1 and np.min(np.diff(self.levels)) <= 0.0:
# -> 1119             raise ValueError("Contour levels must be increasing")
#    1120
#    1121     def _process_levels(self):
#
# ValueError: Contour levels must be increasing

# %% [markdown]
# The error is telling. `ValueError: Contour levels must be increasing`. This is problematic for a few reasons.

# %% [markdown]
# ## TODO: What's the catch or why aren't we using proposals directly

# %% [markdown]
# What we fed into nested sampling was effectively the best case input that corresponds to the same model. You usually don't have a proposal that sits right on top of your posterior ${\cal P}$. We effectively told nested sampling what the answer was.

# %% [markdown]
# Suppose now, that the we didn't give it as much information: we gave it both slightly wrong means, and a slightly wrong covariance matrix.

# %%
f_means = means + np.sqrt(np.diag(1.2*covs))
f_covs = covs*1.2
f_means
# Out:
# array([3.23301558e+00, 1.02718779e+00, 1.08758463e+00, 3.74224490e-02,
#        2.86281193e-01, 9.52816777e-02, 1.00676215e+00, 1.00137945e+00,
#        9.99803664e-01, 8.82473754e+01, 8.41980459e-01, 8.25100062e+00,
#        6.41840181e+00, 1.38386975e+01, 1.57603887e+01, 3.54072858e+01,
#        1.32687948e+02, 3.51094265e+02, 1.39684725e+02, 1.30371806e+02,
#        1.90627415e+02, 2.16712231e-01, 2.20914310e-01, 7.04300171e-01,
#        3.94602682e-01, 8.86033141e-01, 3.26193891e+00])

# %% [markdown]
# This is not a lot by any stretch of the meaning, and shouldn't cause any issues.

# %%
ft_proposal  = sn.truncated_gaussian_proposal(bounds.T, f_means, f_covs, loglike=control_ll)
settings.file_root="ft_proposal"
output["ft_proposal"] = pypolychord.run_polychord(ft_proposal.likelihood, len(means), 0, settings, prior=ft_proposal.prior)
print("\n\n\n\n\n\n\n\n\n  --------------------- ft_proposal ------------------ ")
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      60
# nDims    :      27
# nDerived :       0
# Generating equally weighted posteriors
# Generating weighted posteriors
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.255E-03 seconds
# number of repeats:          128
# started sampling
#
# _________________
# lives      |  60 |
# phantoms   |4914 |
# posteriors |  61 |
# equals     |  14 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                  61
# nposterior =                  61
# nequals    =                  10
# nlike      =                9440
# <nlike>    =         156.33   (           1.22 per slice )
# log(Z)     =          -72.41 +/-  0.20
# log(Z_1)   =          -72.41 +/-  0.20 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6478 |
# posteriors | 122 |
# equals     |  31 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 122
# nposterior =                 122
# nequals    =                  34
# nlike      =               23101
# <nlike>    =         227.68   (           1.78 per slice )
# log(Z)     =          -69.72 +/-  0.16
# log(Z_1)   =          -69.72 +/-  0.16 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7280 |
# posteriors | 183 |
# equals     |  43 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 183
# nposterior =                 183
# nequals    =                  54
# nlike      =               36609
# <nlike>    =         225.13   (           1.76 per slice )
# log(Z)     =          -67.94 +/-  0.18
# log(Z_1)   =          -67.94 +/-  0.18 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6882 |
# posteriors | 244 |
# equals     |  45 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 244
# nposterior =                 244
# nequals    =                  41
# nlike      =               49759
# <nlike>    =         219.17   (           1.71 per slice )
# log(Z)     =          -66.78 +/-  0.20
# log(Z_1)   =          -66.78 +/-  0.20 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8540 |
# posteriors | 305 |
# equals     |  76 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 305
# nposterior =                 305
# nequals    =                  78
# nlike      =               62942
# <nlike>    =         219.72   (           1.72 per slice )
# log(Z)     =          -65.82 +/-  0.23
# log(Z_1)   =          -65.82 +/-  0.23 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6671 |
# posteriors | 366 |
# equals     |  77 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 366
# nposterior =                 366
# nequals    =                  81
# nlike      =               76153
# <nlike>    =         220.18   (           1.72 per slice )
# log(Z)     =          -65.02 +/-  0.25
# log(Z_1)   =          -65.02 +/-  0.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7711 |
# posteriors | 427 |
# equals     | 125 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 427
# nposterior =                 427
# nequals    =                 135
# nlike      =               89465
# <nlike>    =         221.87   (           1.73 per slice )
# log(Z)     =          -64.45 +/-  0.27
# log(Z_1)   =          -64.45 +/-  0.27 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8001 |
# posteriors | 488 |
# equals     | 179 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 488
# nposterior =                 488
# nequals    =                 187
# nlike      =              102374
# <nlike>    =         215.15   (           1.68 per slice )
# log(Z)     =          -64.09 +/-  0.28
# log(Z_1)   =          -64.09 +/-  0.28 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7810 |
# posteriors | 549 |
# equals     | 233 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 549
# nposterior =                 549
# nequals    =                 237
# nlike      =              115607
# <nlike>    =         220.55   (           1.72 per slice )
# log(Z)     =          -63.86 +/-  0.29
# log(Z_1)   =          -63.86 +/-  0.29 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6228 |
# posteriors | 610 |
# equals     | 273 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 610
# nposterior =                 610
# nequals    =                 281
# nlike      =              128553
# <nlike>    =         215.77   (           1.69 per slice )
# log(Z)     =          -63.68 +/-  0.30
# log(Z_1)   =          -63.68 +/-  0.30 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6417 |
# posteriors | 671 |
# equals     | 312 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 671
# nposterior =                 671
# nequals    =                 321
# nlike      =              141738
# <nlike>    =         219.75   (           1.72 per slice )
# log(Z)     =          -63.55 +/-  0.30
# log(Z_1)   =          -63.55 +/-  0.30 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7468 |
# posteriors | 732 |
# equals     | 336 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 732
# nposterior =                 732
# nequals    =                 357
# nlike      =              154867
# <nlike>    =         218.82   (           1.71 per slice )
# log(Z)     =          -63.46 +/-  0.31
# log(Z_1)   =          -63.46 +/-  0.31 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8241 |
# posteriors | 793 |
# equals     | 355 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 793
# nposterior =                 793
# nequals    =                 380
# nlike      =              168951
# <nlike>    =         234.73   (           1.83 per slice )
# log(Z)     =          -63.42 +/-  0.31
# log(Z_1)   =          -63.42 +/-  0.31 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7350 |
# posteriors | 854 |
# equals     | 366 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 854
# nposterior =                 854
# nequals    =                 387
# nlike      =              182411
# <nlike>    =         224.33   (           1.75 per slice )
# log(Z)     =          -63.39 +/-  0.31
# log(Z_1)   =          -63.39 +/-  0.31 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7540 |
# posteriors | 915 |
# equals     | 373 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 915
# nposterior =                 915
# nequals    =                 391
# nlike      =              195884
# <nlike>    =         224.55   (           1.75 per slice )
# log(Z)     =          -63.38 +/-  0.31
# log(Z_1)   =          -63.38 +/-  0.31 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7748 |
# posteriors | 976 |
# equals     | 374 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 976
# nposterior =                 976
# nequals    =                 393
# nlike      =              209016
# <nlike>    =         218.87   (           1.71 per slice )
# log(Z)     =          -63.37 +/-  0.31
# log(Z_1)   =          -63.37 +/-  0.31 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7392 |
# posteriors |1037 |
# equals     | 377 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1037
# nposterior =                1037
# nequals    =                 394
# nlike      =              222303
# <nlike>    =         221.45   (           1.73 per slice )
# log(Z)     =          -63.37 +/-  0.31
# log(Z_1)   =          -63.37 +/-  0.31 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7118 |
# posteriors |1098 |
# equals     | 377 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1098
# nposterior =                1098
# nequals    =                 394
# nlike      =              235430
# <nlike>    =         218.78   (           1.71 per slice )
# log(Z)     =          -63.37 +/-  0.31
# log(Z_1)   =          -63.37 +/-  0.31 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |6952 |
# posteriors |1159 |
# equals     | 378 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1159
# nposterior =                1159
# nequals    =                 395
# nlike      =              249017
# <nlike>    =         226.45   (           1.77 per slice )
# log(Z)     =          -63.36 +/-  0.31
# log(Z_1)   =          -63.36 +/-  0.31 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         1220                              |
# | log(Z) =          -63.36394 +/-            0.31498 |
# |____________________________________________________|
#
#
#
#
#
#
#
#
#
#   --------------------- ft_proposal ------------------

# %%
output["ft_proposal"].logZ
# Out:
# -63.3639422854176

# %% [markdown]
# The truncated false proposal seems to be fine. It finds the right posterior peaks, finds them too narrow, and as a result finds only a small part of the evidence.

# %% [markdown]
# However using the same with a false un-truncated proposal isn't fine.
#
# **Note** for some reason it is fine in this instance.

# %%
f_proposal = sn.gaussian_proposal(bounds.T, f_means, f_covs, loglike=control_ll)
settings.file_root="f_proposal"
output["f_proposal"] = pypolychord.run_polychord(f_proposal.likelihood, len(means), 0, settings, prior=f_proposal.prior)
print("\n\n\n\n\n\n\n\n ---------------------- f_proposal -------------------")
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      60
# nDims    :      27
# nDerived :       0
# Generating equally weighted posteriors
# Generating weighted posteriors
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.114E-03 seconds
# number of repeats:          128
# started sampling
#
# _________________
# lives      |  60 |
# phantoms   |5161 |
# posteriors |  61 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                  61
# nposterior =                  61
# nequals    =                   1
# nlike      =                9848
# <nlike>    =         163.13   (           1.27 per slice )
# log(Z)     =        -2090.28 +/-  0.83
# log(Z_1)   =        -2090.28 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6169 |
# posteriors | 122 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 122
# nposterior =                 122
# nequals    =                   1
# nlike      =               23987
# <nlike>    =         235.65   (           1.84 per slice )
# log(Z)     =        -1079.68 +/-  0.84
# log(Z_1)   =        -1079.68 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7695 |
# posteriors | 183 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 183
# nposterior =                 183
# nequals    =                   1
# nlike      =               38566
# <nlike>    =         242.98   (           1.90 per slice )
# log(Z)     =         -716.84 +/-  0.85
# log(Z_1)   =         -716.84 +/-  0.85 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8278 |
# posteriors | 244 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 244
# nposterior =                 244
# nequals    =                   1
# nlike      =               53277
# <nlike>    =         245.18   (           1.92 per slice )
# log(Z)     =         -501.16 +/-  0.84
# log(Z_1)   =         -501.16 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6638 |
# posteriors | 305 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 305
# nposterior =                 305
# nequals    =                   1
# nlike      =               68352
# <nlike>    =         251.25   (           1.96 per slice )
# log(Z)     =         -316.73 +/-  0.66
# log(Z_1)   =         -316.73 +/-  0.66 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6622 |
# posteriors | 366 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 366
# nposterior =                 366
# nequals    =                   2
# nlike      =               83598
# <nlike>    =         254.10   (           1.99 per slice )
# log(Z)     =         -221.21 +/-  0.69
# log(Z_1)   =         -221.21 +/-  0.69 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7334 |
# posteriors | 427 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 427
# nposterior =                 427
# nequals    =                   2
# nlike      =               98819
# <nlike>    =         253.68   (           1.98 per slice )
# log(Z)     =         -168.91 +/-  0.68
# log(Z_1)   =         -168.91 +/-  0.68 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8439 |
# posteriors | 488 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 488
# nposterior =                 488
# nequals    =                   3
# nlike      =              114283
# <nlike>    =         257.73   (           2.01 per slice )
# log(Z)     =         -136.40 +/-  0.60
# log(Z_1)   =         -136.40 +/-  0.60 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8423 |
# posteriors | 549 |
# equals     |   4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 549
# nposterior =                 549
# nequals    =                   4
# nlike      =              129605
# <nlike>    =         255.37   (           2.00 per slice )
# log(Z)     =         -109.87 +/-  0.49
# log(Z_1)   =         -109.87 +/-  0.49 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8785 |
# posteriors | 610 |
# equals     |   7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 610
# nposterior =                 610
# nequals    =                   3
# nlike      =              145224
# <nlike>    =         260.32   (           2.03 per slice )
# log(Z)     =          -92.73 +/-  0.49
# log(Z_1)   =          -92.73 +/-  0.49 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7825 |
# posteriors | 671 |
# equals     |   5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 671
# nposterior =                 671
# nequals    =                   5
# nlike      =              160815
# <nlike>    =         259.85   (           2.03 per slice )
# log(Z)     =          -76.92 +/-  0.53
# log(Z_1)   =          -76.92 +/-  0.53 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7488 |
# posteriors | 732 |
# equals     |   5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 732
# nposterior =                 732
# nequals    =                   3
# nlike      =              175942
# <nlike>    =         252.12   (           1.97 per slice )
# log(Z)     =          -66.09 +/-  0.57
# log(Z_1)   =          -66.09 +/-  0.57 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8617 |
# posteriors | 793 |
# equals     |  11 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 793
# nposterior =                 793
# nequals    =                  12
# nlike      =              191492
# <nlike>    =         259.17   (           2.02 per slice )
# log(Z)     =          -58.49 +/-  0.50
# log(Z_1)   =          -58.49 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |9036 |
# posteriors | 854 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 854
# nposterior =                 854
# nequals    =                  10
# nlike      =              207206
# <nlike>    =         261.90   (           2.05 per slice )
# log(Z)     =          -52.66 +/-  0.50
# log(Z_1)   =          -52.66 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8432 |
# posteriors | 915 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 915
# nposterior =                 915
# nequals    =                  15
# nlike      =              223020
# <nlike>    =         263.57   (           2.06 per slice )
# log(Z)     =          -47.50 +/-  0.50
# log(Z_1)   =          -47.50 +/-  0.50 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8665 |
# posteriors | 976 |
# equals     |  23 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 976
# nposterior =                 976
# nequals    =                  22
# nlike      =              238691
# <nlike>    =         261.18   (           2.04 per slice )
# log(Z)     =          -44.09 +/-  0.51
# log(Z_1)   =          -44.09 +/-  0.51 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8876 |
# posteriors |1037 |
# equals     |  23 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1037
# nposterior =                1037
# nequals    =                  22
# nlike      =              254260
# <nlike>    =         259.48   (           2.03 per slice )
# log(Z)     =          -41.61 +/-  0.52
# log(Z_1)   =          -41.61 +/-  0.52 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7886 |
# posteriors |1098 |
# equals     |  32 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1098
# nposterior =                1098
# nequals    =                  26
# nlike      =              269619
# <nlike>    =         255.98   (           2.00 per slice )
# log(Z)     =          -39.35 +/-  0.54
# log(Z_1)   =          -39.35 +/-  0.54 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7847 |
# posteriors |1159 |
# equals     |  37 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1159
# nposterior =                1159
# nequals    =                  32
# nlike      =              285347
# <nlike>    =         262.13   (           2.05 per slice )
# log(Z)     =          -37.30 +/-  0.55
# log(Z_1)   =          -37.30 +/-  0.55 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7424 |
# posteriors |1220 |
# equals     |  49 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1220
# nposterior =                1220
# nequals    =                  41
# nlike      =              301171
# <nlike>    =         263.73   (           2.06 per slice )
# log(Z)     =          -35.42 +/-  0.56
# log(Z_1)   =          -35.42 +/-  0.56 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8346 |
# posteriors |1281 |
# equals     |  67 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1281
# nposterior =                1281
# nequals    =                  63
# nlike      =              316717
# <nlike>    =         259.10   (           2.02 per slice )
# log(Z)     =          -34.21 +/-  0.57
# log(Z_1)   =          -34.21 +/-  0.57 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7554 |
# posteriors |1342 |
# equals     |  66 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1342
# nposterior =                1342
# nequals    =                  73
# nlike      =              332911
# <nlike>    =         269.90   (           2.11 per slice )
# log(Z)     =          -33.29 +/-  0.57
# log(Z_1)   =          -33.29 +/-  0.57 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |9430 |
# posteriors |1403 |
# equals     | 122 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1403
# nposterior =                1403
# nequals    =                 129
# nlike      =              348565
# <nlike>    =         260.90   (           2.04 per slice )
# log(Z)     =          -32.66 +/-  0.58
# log(Z_1)   =          -32.66 +/-  0.58 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7532 |
# posteriors |1464 |
# equals     | 111 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1464
# nposterior =                1464
# nequals    =                 118
# nlike      =              364462
# <nlike>    =         264.95   (           2.07 per slice )
# log(Z)     =          -32.15 +/-  0.59
# log(Z_1)   =          -32.15 +/-  0.59 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8694 |
# posteriors |1525 |
# equals     | 165 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1525
# nposterior =                1525
# nequals    =                 168
# nlike      =              380206
# <nlike>    =         262.40   (           2.05 per slice )
# log(Z)     =          -31.72 +/-  0.60
# log(Z_1)   =          -31.72 +/-  0.60 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7990 |
# posteriors |1586 |
# equals     | 202 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1586
# nposterior =                1586
# nequals    =                 198
# nlike      =              395849
# <nlike>    =         260.72   (           2.04 per slice )
# log(Z)     =          -31.38 +/-  0.60
# log(Z_1)   =          -31.38 +/-  0.60 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7815 |
# posteriors |1647 |
# equals     | 259 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1647
# nposterior =                1647
# nequals    =                 258
# nlike      =              411314
# <nlike>    =         257.75   (           2.01 per slice )
# log(Z)     =          -31.12 +/-  0.61
# log(Z_1)   =          -31.12 +/-  0.61 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7895 |
# posteriors |1708 |
# equals     | 314 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1708
# nposterior =                1708
# nequals    =                 311
# nlike      =              427164
# <nlike>    =         264.17   (           2.06 per slice )
# log(Z)     =          -30.93 +/-  0.62
# log(Z_1)   =          -30.93 +/-  0.62 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7296 |
# posteriors |1769 |
# equals     | 365 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1769
# nposterior =                1769
# nequals    =                 360
# nlike      =              442893
# <nlike>    =         262.15   (           2.05 per slice )
# log(Z)     =          -30.78 +/-  0.62
# log(Z_1)   =          -30.78 +/-  0.62 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7978 |
# posteriors |1830 |
# equals     | 410 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1830
# nposterior =                1830
# nequals    =                 400
# nlike      =              458673
# <nlike>    =         263.00   (           2.05 per slice )
# log(Z)     =          -30.68 +/-  0.62
# log(Z_1)   =          -30.68 +/-  0.62 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7917 |
# posteriors |1891 |
# equals     | 435 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1891
# nposterior =                1891
# nequals    =                 424
# nlike      =              475120
# <nlike>    =         274.12   (           2.14 per slice )
# log(Z)     =          -30.61 +/-  0.63
# log(Z_1)   =          -30.61 +/-  0.63 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8959 |
# posteriors |1952 |
# equals     | 449 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1952
# nposterior =                1952
# nequals    =                 438
# nlike      =              491136
# <nlike>    =         266.93   (           2.09 per slice )
# log(Z)     =          -30.57 +/-  0.63
# log(Z_1)   =          -30.57 +/-  0.63 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6240 |
# posteriors |2013 |
# equals     | 458 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2013
# nposterior =                2013
# nequals    =                 452
# nlike      =              506887
# <nlike>    =         262.52   (           2.05 per slice )
# log(Z)     =          -30.54 +/-  0.63
# log(Z_1)   =          -30.54 +/-  0.63 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6925 |
# posteriors |2074 |
# equals     | 466 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2074
# nposterior =                2074
# nequals    =                 456
# nlike      =              522867
# <nlike>    =         266.33   (           2.08 per slice )
# log(Z)     =          -30.53 +/-  0.63
# log(Z_1)   =          -30.53 +/-  0.63 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8070 |
# posteriors |2135 |
# equals     | 469 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2135
# nposterior =                2135
# nequals    =                 459
# nlike      =              539025
# <nlike>    =         269.30   (           2.10 per slice )
# log(Z)     =          -30.52 +/-  0.63
# log(Z_1)   =          -30.52 +/-  0.63 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8093 |
# posteriors |2196 |
# equals     | 474 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2196
# nposterior =                2196
# nequals    =                 463
# nlike      =              554713
# <nlike>    =         261.47   (           2.04 per slice )
# log(Z)     =          -30.51 +/-  0.63
# log(Z_1)   =          -30.51 +/-  0.63 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8076 |
# posteriors |2257 |
# equals     | 476 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2257
# nposterior =                2257
# nequals    =                 464
# nlike      =              570923
# <nlike>    =         270.17   (           2.11 per slice )
# log(Z)     =          -30.51 +/-  0.63
# log(Z_1)   =          -30.51 +/-  0.63 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7654 |
# posteriors |2318 |
# equals     | 476 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2318
# nposterior =                2318
# nequals    =                 464
# nlike      =              587243
# <nlike>    =         272.00   (           2.12 per slice )
# log(Z)     =          -30.51 +/-  0.63
# log(Z_1)   =          -30.51 +/-  0.63 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         2417                              |
# | log(Z) =          -30.50375 +/-            0.63008 |
# |____________________________________________________|
#
#
#
#
#
#
#
#
#  ---------------------- f_proposal -------------------

# %%
output["f_proposal"].logZ
# Out:
# -30.5037507821185

# %% [markdown]
# **THIS IS A BIG PROBLEM**
#
# We only disturbed the proposal by a little bit, what we got was
#
# 1. Not even within ballpark of the right evidence.
# 2. Took significantly longer
# 3. Caused a few `inf`s and `nan`s to be generated.

# %% [markdown]
# What if we wanted to confirm a result, but instead got a $5 \sigma$ discovery?

# %%
mf_means = means + np.diag(5*covs); mf_covs = 1.2*covs
mf_proposal = sn.truncated_gaussian_proposal(bounds.T, mf_means, mf_covs, loglike=control_ll)
settings.file_root = "mft_proposal"
output["mft_proposal"] = pypolychord.run_polychord(mf_proposal.likelihood, len(means), 0, settings, prior=mf_proposal.prior)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      60
# nDims    :      27
# nDerived :       0
# Generating equally weighted posteriors
# Generating weighted posteriors
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.273E-03 seconds
# number of repeats:          128
# started sampling
#
# _________________
# lives      |  60 |
# phantoms   |5301 |
# posteriors |  61 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                  61
# nposterior =                  61
# nequals    =                   1
# nlike      =                9270
# <nlike>    =         153.50   (           1.20 per slice )
# log(Z)     =       297299.81 +/-  0.83
# log(Z_1)   =       297299.81 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6459 |
# posteriors | 122 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 122
# nposterior =                 122
# nequals    =                   1
# nlike      =               21678
# <nlike>    =         206.80   (           1.62 per slice )
# log(Z)     =       298248.49 +/-  0.66
# log(Z_1)   =       298248.49 +/-  0.66 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7079 |
# posteriors | 183 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 183
# nposterior =                 183
# nequals    =                   1
# nlike      =               34315
# <nlike>    =         210.62   (           1.65 per slice )
# log(Z)     =       298784.03 +/-  0.85
# log(Z_1)   =       298784.03 +/-  0.85 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6632 |
# posteriors | 244 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 244
# nposterior =                 244
# nequals    =                   1
# nlike      =               46970
# <nlike>    =         210.92   (           1.65 per slice )
# log(Z)     =       299250.37 +/-  0.86
# log(Z_1)   =       299250.37 +/-  0.86 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6777 |
# posteriors | 305 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 305
# nposterior =                 305
# nequals    =                   2
# nlike      =               59679
# <nlike>    =         211.82   (           1.65 per slice )
# log(Z)     =       299570.43 +/-  0.78
# log(Z_1)   =       299570.43 +/-  0.78 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7611 |
# posteriors | 366 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 366
# nposterior =                 366
# nequals    =                   1
# nlike      =               72462
# <nlike>    =         213.05   (           1.66 per slice )
# log(Z)     =       299787.39 +/-  0.76
# log(Z_1)   =       299787.39 +/-  0.76 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8147 |
# posteriors | 427 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 427
# nposterior =                 427
# nequals    =                   1
# nlike      =               85188
# <nlike>    =         212.10   (           1.66 per slice )
# log(Z)     =       299973.83 +/-  0.70
# log(Z_1)   =       299973.83 +/-  0.70 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7116 |
# posteriors | 488 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 488
# nposterior =                 488
# nequals    =                   1
# nlike      =               97612
# <nlike>    =         207.07   (           1.62 per slice )
# log(Z)     =       300202.37 +/-  0.89
# log(Z_1)   =       300202.37 +/-  0.89 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7495 |
# posteriors | 549 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 549
# nposterior =                 549
# nequals    =                   1
# nlike      =              110184
# <nlike>    =         209.53   (           1.64 per slice )
# log(Z)     =       300368.67 +/-  0.83
# log(Z_1)   =       300368.67 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7425 |
# posteriors | 610 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 610
# nposterior =                 610
# nequals    =                   1
# nlike      =              122787
# <nlike>    =         210.05   (           1.64 per slice )
# log(Z)     =       300525.95 +/-  0.84
# log(Z_1)   =       300525.95 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7269 |
# posteriors | 671 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 671
# nposterior =                 671
# nequals    =                   1
# nlike      =              135490
# <nlike>    =         211.72   (           1.65 per slice )
# log(Z)     =       300665.80 +/-  0.83
# log(Z_1)   =       300665.80 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7360 |
# posteriors | 732 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 732
# nposterior =                 732
# nequals    =                   1
# nlike      =              147818
# <nlike>    =         205.47   (           1.61 per slice )
# log(Z)     =       300788.57 +/-  0.71
# log(Z_1)   =       300788.57 +/-  0.71 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7333 |
# posteriors | 793 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 793
# nposterior =                 793
# nequals    =                   1
# nlike      =              160280
# <nlike>    =         207.70   (           1.62 per slice )
# log(Z)     =       300885.82 +/-  0.73
# log(Z_1)   =       300885.82 +/-  0.73 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6771 |
# posteriors | 854 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 854
# nposterior =                 854
# nequals    =                   2
# nlike      =              172598
# <nlike>    =         205.30   (           1.60 per slice )
# log(Z)     =       300962.85 +/-  0.74
# log(Z_1)   =       300962.85 +/-  0.74 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7981 |
# posteriors | 915 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 915
# nposterior =                 915
# nequals    =                   1
# nlike      =              184901
# <nlike>    =         205.05   (           1.60 per slice )
# log(Z)     =       301026.09 +/-  0.93
# log(Z_1)   =       301026.09 +/-  0.93 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7983 |
# posteriors | 976 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 976
# nposterior =                 976
# nequals    =                   3
# nlike      =              197189
# <nlike>    =         204.80   (           1.60 per slice )
# log(Z)     =       301096.80 +/-  0.72
# log(Z_1)   =       301096.80 +/-  0.72 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6870 |
# posteriors |1037 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1037
# nposterior =                1037
# nequals    =                   1
# nlike      =              209344
# <nlike>    =         202.58   (           1.58 per slice )
# log(Z)     =       301170.53 +/-  0.93
# log(Z_1)   =       301170.53 +/-  0.93 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7091 |
# posteriors |1098 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1098
# nposterior =                1098
# nequals    =                   1
# nlike      =              221503
# <nlike>    =         202.65   (           1.58 per slice )
# log(Z)     =       301223.84 +/-  0.86
# log(Z_1)   =       301223.84 +/-  0.86 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6466 |
# posteriors |1159 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1159
# nposterior =                1159
# nequals    =                   1
# nlike      =              233767
# <nlike>    =         204.40   (           1.60 per slice )
# log(Z)     =       301278.54 +/-  0.75
# log(Z_1)   =       301278.54 +/-  0.75 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6980 |
# posteriors |1220 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1220
# nposterior =                1220
# nequals    =                   3
# nlike      =              246195
# <nlike>    =         207.13   (           1.62 per slice )
# log(Z)     =       301324.85 +/-  0.74
# log(Z_1)   =       301324.85 +/-  0.74 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7511 |
# posteriors |1281 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1281
# nposterior =                1281
# nequals    =                   1
# nlike      =              258274
# <nlike>    =         201.32   (           1.57 per slice )
# log(Z)     =       301367.20 +/-  0.78
# log(Z_1)   =       301367.20 +/-  0.78 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7740 |
# posteriors |1342 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1342
# nposterior =                1342
# nequals    =                   2
# nlike      =              270901
# <nlike>    =         210.45   (           1.64 per slice )
# log(Z)     =       301403.89 +/-  0.80
# log(Z_1)   =       301403.89 +/-  0.80 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7644 |
# posteriors |1403 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1403
# nposterior =                1403
# nequals    =                   3
# nlike      =              283364
# <nlike>    =         207.72   (           1.62 per slice )
# log(Z)     =       301442.44 +/-  0.73
# log(Z_1)   =       301442.44 +/-  0.73 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7345 |
# posteriors |1464 |
# equals     |   5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1464
# nposterior =                1464
# nequals    =                   4
# nlike      =              295924
# <nlike>    =         209.33   (           1.64 per slice )
# log(Z)     =       301476.02 +/-  0.71
# log(Z_1)   =       301476.02 +/-  0.71 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7098 |
# posteriors |1525 |
# equals     |   5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1525
# nposterior =                1525
# nequals    =                   4
# nlike      =              308560
# <nlike>    =         210.60   (           1.65 per slice )
# log(Z)     =       301508.01 +/-  0.76
# log(Z_1)   =       301508.01 +/-  0.76 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6879 |
# posteriors |1586 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1586
# nposterior =                1586
# nequals    =                   1
# nlike      =              321330
# <nlike>    =         212.83   (           1.66 per slice )
# log(Z)     =       301533.92 +/-  0.80
# log(Z_1)   =       301533.92 +/-  0.80 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7780 |
# posteriors |1647 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1647
# nposterior =                1647
# nequals    =                   3
# nlike      =              334332
# <nlike>    =         216.70   (           1.69 per slice )
# log(Z)     =       301551.09 +/-  0.76
# log(Z_1)   =       301551.09 +/-  0.76 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7584 |
# posteriors |1708 |
# equals     |   8 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1708
# nposterior =                1708
# nequals    =                   7
# nlike      =              346556
# <nlike>    =         203.73   (           1.59 per slice )
# log(Z)     =       301573.66 +/-  0.74
# log(Z_1)   =       301573.66 +/-  0.74 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7745 |
# posteriors |1769 |
# equals     |   4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1769
# nposterior =                1769
# nequals    =                   4
# nlike      =              359186
# <nlike>    =         210.50   (           1.64 per slice )
# log(Z)     =       301594.84 +/-  0.78
# log(Z_1)   =       301594.84 +/-  0.78 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8576 |
# posteriors |1830 |
# equals     |   7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1830
# nposterior =                1830
# nequals    =                   7
# nlike      =              371881
# <nlike>    =         211.58   (           1.65 per slice )
# log(Z)     =       301610.25 +/-  0.76
# log(Z_1)   =       301610.25 +/-  0.76 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6848 |
# posteriors |1891 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1891
# nposterior =                1891
# nequals    =                   2
# nlike      =              384477
# <nlike>    =         209.93   (           1.64 per slice )
# log(Z)     =       301631.19 +/-  0.81
# log(Z_1)   =       301631.19 +/-  0.81 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7479 |
# posteriors |1952 |
# equals     |   7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1952
# nposterior =                1952
# nequals    =                   2
# nlike      =              397643
# <nlike>    =         219.43   (           1.71 per slice )
# log(Z)     =       301644.22 +/-  0.78
# log(Z_1)   =       301644.22 +/-  0.78 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6696 |
# posteriors |2013 |
# equals     |   5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2013
# nposterior =                2013
# nequals    =                   4
# nlike      =              410692
# <nlike>    =         217.48   (           1.70 per slice )
# log(Z)     =       301656.35 +/-  0.78
# log(Z_1)   =       301656.35 +/-  0.78 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7204 |
# posteriors |2074 |
# equals     |   7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2074
# nposterior =                2074
# nequals    =                   7
# nlike      =              423976
# <nlike>    =         221.40   (           1.73 per slice )
# log(Z)     =       301664.91 +/-  0.79
# log(Z_1)   =       301664.91 +/-  0.79 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7711 |
# posteriors |2135 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2135
# nposterior =                2135
# nequals    =                  11
# nlike      =              437115
# <nlike>    =         218.98   (           1.71 per slice )
# log(Z)     =       301673.27 +/-  0.78
# log(Z_1)   =       301673.27 +/-  0.78 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7617 |
# posteriors |2196 |
# equals     |  11 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2196
# nposterior =                2196
# nequals    =                  13
# nlike      =              451040
# <nlike>    =         232.08   (           1.81 per slice )
# log(Z)     =       301681.09 +/-  0.78
# log(Z_1)   =       301681.09 +/-  0.78 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6767 |
# posteriors |2257 |
# equals     |   9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2257
# nposterior =                2257
# nequals    =                   8
# nlike      =              464489
# <nlike>    =         224.15   (           1.75 per slice )
# log(Z)     =       301689.85 +/-  0.82
# log(Z_1)   =       301689.85 +/-  0.82 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6770 |
# posteriors |2318 |
# equals     |   8 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2318
# nposterior =                2318
# nequals    =                   8
# nlike      =              478686
# <nlike>    =         236.62   (           1.85 per slice )
# log(Z)     =       301698.06 +/-  0.81
# log(Z_1)   =       301698.06 +/-  0.81 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7380 |
# posteriors |2379 |
# equals     |  17 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2379
# nposterior =                2379
# nequals    =                   8
# nlike      =              493520
# <nlike>    =         247.23   (           1.93 per slice )
# log(Z)     =       301704.46 +/-  0.82
# log(Z_1)   =       301704.46 +/-  0.82 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7824 |
# posteriors |2440 |
# equals     |  16 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2440
# nposterior =                2440
# nequals    =                  11
# nlike      =              508038
# <nlike>    =         241.97   (           1.89 per slice )
# log(Z)     =       301710.70 +/-  0.82
# log(Z_1)   =       301710.70 +/-  0.82 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7772 |
# posteriors |2501 |
# equals     |   8 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2501
# nposterior =                2501
# nequals    =                   8
# nlike      =              521299
# <nlike>    =         221.02   (           1.73 per slice )
# log(Z)     =       301715.41 +/-  0.84
# log(Z_1)   =       301715.41 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7414 |
# posteriors |2562 |
# equals     |  13 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2562
# nposterior =                2562
# nequals    =                   8
# nlike      =              535088
# <nlike>    =         229.82   (           1.80 per slice )
# log(Z)     =       301722.28 +/-  0.85
# log(Z_1)   =       301722.28 +/-  0.85 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7279 |
# posteriors |2623 |
# equals     |   9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2623
# nposterior =                2623
# nequals    =                  12
# nlike      =              549004
# <nlike>    =         231.93   (           1.81 per slice )
# log(Z)     =       301728.96 +/-  0.86
# log(Z_1)   =       301728.96 +/-  0.86 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7753 |
# posteriors |2684 |
# equals     |  13 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2684
# nposterior =                2684
# nequals    =                  16
# nlike      =              562788
# <nlike>    =         229.73   (           1.79 per slice )
# log(Z)     =       301735.66 +/-  0.86
# log(Z_1)   =       301735.66 +/-  0.86 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8405 |
# posteriors |2745 |
# equals     |   9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2745
# nposterior =                2745
# nequals    =                  12
# nlike      =              576453
# <nlike>    =         227.75   (           1.78 per slice )
# log(Z)     =       301740.88 +/-  0.87
# log(Z_1)   =       301740.88 +/-  0.87 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7110 |
# posteriors |2806 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2806
# nposterior =                2806
# nequals    =                   8
# nlike      =              589305
# <nlike>    =         214.20   (           1.67 per slice )
# log(Z)     =       301747.51 +/-  0.89
# log(Z_1)   =       301747.51 +/-  0.89 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |5661 |
# posteriors |2867 |
# equals     |   4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2867
# nposterior =                2867
# nequals    =                   9
# nlike      =              602624
# <nlike>    =         221.98   (           1.73 per slice )
# log(Z)     =       301754.80 +/-  0.91
# log(Z_1)   =       301754.80 +/-  0.91 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6477 |
# posteriors |2928 |
# equals     |  13 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2928
# nposterior =                2928
# nequals    =                  11
# nlike      =              616097
# <nlike>    =         224.55   (           1.75 per slice )
# log(Z)     =       301761.26 +/-  0.90
# log(Z_1)   =       301761.26 +/-  0.90 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7340 |
# posteriors |2989 |
# equals     |  22 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2989
# nposterior =                2989
# nequals    =                  16
# nlike      =              629475
# <nlike>    =         222.97   (           1.74 per slice )
# log(Z)     =       301766.19 +/-  0.90
# log(Z_1)   =       301766.19 +/-  0.90 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7190 |
# posteriors |3050 |
# equals     |  15 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3050
# nposterior =                3050
# nequals    =                  10
# nlike      =              642458
# <nlike>    =         216.38   (           1.69 per slice )
# log(Z)     =       301770.12 +/-  0.92
# log(Z_1)   =       301770.12 +/-  0.92 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7428 |
# posteriors |3111 |
# equals     |  16 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3111
# nposterior =                3111
# nequals    =                  16
# nlike      =              655890
# <nlike>    =         223.87   (           1.75 per slice )
# log(Z)     =       301773.87 +/-  0.92
# log(Z_1)   =       301773.87 +/-  0.92 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7461 |
# posteriors |3172 |
# equals     |  23 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3172
# nposterior =                3172
# nequals    =                  20
# nlike      =              669537
# <nlike>    =         227.45   (           1.78 per slice )
# log(Z)     =       301777.02 +/-  0.92
# log(Z_1)   =       301777.02 +/-  0.92 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6580 |
# posteriors |3233 |
# equals     |  22 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3233
# nposterior =                3233
# nequals    =                  20
# nlike      =              683125
# <nlike>    =         226.47   (           1.77 per slice )
# log(Z)     =       301780.62 +/-  0.94
# log(Z_1)   =       301780.62 +/-  0.94 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7414 |
# posteriors |3294 |
# equals     |  28 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3294
# nposterior =                3294
# nequals    =                  27
# nlike      =              696202
# <nlike>    =         217.95   (           1.70 per slice )
# log(Z)     =       301783.43 +/-  0.94
# log(Z_1)   =       301783.43 +/-  0.94 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8759 |
# posteriors |3355 |
# equals     |  43 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3355
# nposterior =                3355
# nequals    =                  38
# nlike      =              709066
# <nlike>    =         214.40   (           1.68 per slice )
# log(Z)     =       301785.34 +/-  0.94
# log(Z_1)   =       301785.34 +/-  0.94 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7380 |
# posteriors |3416 |
# equals     |  18 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3416
# nposterior =                3416
# nequals    =                  16
# nlike      =              721701
# <nlike>    =         210.58   (           1.65 per slice )
# log(Z)     =       301787.44 +/-  0.95
# log(Z_1)   =       301787.44 +/-  0.95 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6760 |
# posteriors |3477 |
# equals     |  25 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3477
# nposterior =                3477
# nequals    =                  21
# nlike      =              734370
# <nlike>    =         211.15   (           1.65 per slice )
# log(Z)     =       301790.36 +/-  0.97
# log(Z_1)   =       301790.36 +/-  0.97 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6489 |
# posteriors |3538 |
# equals     |  38 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3538
# nposterior =                3538
# nequals    =                  30
# nlike      =              747016
# <nlike>    =         210.77   (           1.65 per slice )
# log(Z)     =       301793.26 +/-  0.97
# log(Z_1)   =       301793.26 +/-  0.97 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7625 |
# posteriors |3599 |
# equals     |  43 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3599
# nposterior =                3599
# nequals    =                  42
# nlike      =              759823
# <nlike>    =         213.45   (           1.67 per slice )
# log(Z)     =       301794.87 +/-  0.97
# log(Z_1)   =       301794.87 +/-  0.97 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7599 |
# posteriors |3660 |
# equals     |  52 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3660
# nposterior =                3660
# nequals    =                  37
# nlike      =              772060
# <nlike>    =         203.95   (           1.59 per slice )
# log(Z)     =       301796.02 +/-  0.98
# log(Z_1)   =       301796.02 +/-  0.98 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7195 |
# posteriors |3721 |
# equals     |  31 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3721
# nposterior =                3721
# nequals    =                  34
# nlike      =              784617
# <nlike>    =         209.28   (           1.64 per slice )
# log(Z)     =       301797.58 +/-  0.99
# log(Z_1)   =       301797.58 +/-  0.99 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8413 |
# posteriors |3782 |
# equals     |  39 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3782
# nposterior =                3782
# nequals    =                  47
# nlike      =              798664
# <nlike>    =         234.12   (           1.83 per slice )
# log(Z)     =       301799.12 +/-  1.00
# log(Z_1)   =       301799.12 +/-  1.00 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7282 |
# posteriors |3843 |
# equals     |  31 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3843
# nposterior =                3843
# nequals    =                  27
# nlike      =              812124
# <nlike>    =         224.33   (           1.75 per slice )
# log(Z)     =       301800.79 +/-  1.01
# log(Z_1)   =       301800.79 +/-  1.01 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6328 |
# posteriors |3904 |
# equals     |  35 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3904
# nposterior =                3904
# nequals    =                  32
# nlike      =              824617
# <nlike>    =         208.22   (           1.63 per slice )
# log(Z)     =       301802.57 +/-  1.02
# log(Z_1)   =       301802.57 +/-  1.02 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7207 |
# posteriors |3965 |
# equals     |  49 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3965
# nposterior =                3965
# nequals    =                  49
# nlike      =              837137
# <nlike>    =         208.67   (           1.63 per slice )
# log(Z)     =       301803.98 +/-  1.02
# log(Z_1)   =       301803.98 +/-  1.02 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7432 |
# posteriors |4026 |
# equals     |  55 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4026
# nposterior =                4026
# nequals    =                  57
# nlike      =              849466
# <nlike>    =         205.48   (           1.61 per slice )
# log(Z)     =       301805.15 +/-  1.03
# log(Z_1)   =       301805.15 +/-  1.03 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8148 |
# posteriors |4087 |
# equals     |  69 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4087
# nposterior =                4087
# nequals    =                  69
# nlike      =              861961
# <nlike>    =         208.25   (           1.63 per slice )
# log(Z)     =       301806.07 +/-  1.03
# log(Z_1)   =       301806.07 +/-  1.03 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7381 |
# posteriors |4148 |
# equals     |  64 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4148
# nposterior =                4148
# nequals    =                  62
# nlike      =              875844
# <nlike>    =         231.38   (           1.81 per slice )
# log(Z)     =       301807.07 +/-  1.04
# log(Z_1)   =       301807.07 +/-  1.04 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7564 |
# posteriors |4209 |
# equals     |  76 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4209
# nposterior =                4209
# nequals    =                  71
# nlike      =              888843
# <nlike>    =         216.65   (           1.69 per slice )
# log(Z)     =       301807.83 +/-  1.05
# log(Z_1)   =       301807.83 +/-  1.05 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7353 |
# posteriors |4270 |
# equals     |  89 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4270
# nposterior =                4270
# nequals    =                  65
# nlike      =              902119
# <nlike>    =         221.27   (           1.73 per slice )
# log(Z)     =       301808.64 +/-  1.05
# log(Z_1)   =       301808.64 +/-  1.05 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7023 |
# posteriors |4331 |
# equals     |  66 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4331
# nposterior =                4331
# nequals    =                  62
# nlike      =              914388
# <nlike>    =         204.48   (           1.60 per slice )
# log(Z)     =       301809.47 +/-  1.06
# log(Z_1)   =       301809.47 +/-  1.06 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7266 |
# posteriors |4392 |
# equals     |  79 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4392
# nposterior =                4392
# nequals    =                  75
# nlike      =              928483
# <nlike>    =         234.92   (           1.84 per slice )
# log(Z)     =       301810.29 +/-  1.07
# log(Z_1)   =       301810.29 +/-  1.07 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7984 |
# posteriors |4453 |
# equals     | 109 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4453
# nposterior =                4453
# nequals    =                 102
# nlike      =              943409
# <nlike>    =         248.77   (           1.94 per slice )
# log(Z)     =       301810.93 +/-  1.07
# log(Z_1)   =       301810.93 +/-  1.07 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8037 |
# posteriors |4514 |
# equals     | 138 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4514
# nposterior =                4514
# nequals    =                 122
# nlike      =              958797
# <nlike>    =         256.47   (           2.00 per slice )
# log(Z)     =       301811.40 +/-  1.08
# log(Z_1)   =       301811.40 +/-  1.08 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |9041 |
# posteriors |4575 |
# equals     | 187 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4575
# nposterior =                4575
# nequals    =                 165
# nlike      =              972406
# <nlike>    =         226.82   (           1.77 per slice )
# log(Z)     =       301811.81 +/-  1.08
# log(Z_1)   =       301811.81 +/-  1.08 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8123 |
# posteriors |4636 |
# equals     | 184 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4636
# nposterior =                4636
# nequals    =                 175
# nlike      =              988198
# <nlike>    =         263.20   (           2.06 per slice )
# log(Z)     =       301812.14 +/-  1.09
# log(Z_1)   =       301812.14 +/-  1.09 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7616 |
# posteriors |4697 |
# equals     | 172 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4697
# nposterior =                4697
# nequals    =                 171
# nlike      =             1005390
# <nlike>    =         286.53   (           2.24 per slice )
# log(Z)     =       301812.47 +/-  1.09
# log(Z_1)   =       301812.47 +/-  1.09 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |6779 |
# posteriors |4758 |
# equals     | 153 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4758
# nposterior =                4758
# nequals    =                 160
# nlike      =             1020858
# <nlike>    =         257.80   (           2.01 per slice )
# log(Z)     =       301812.82 +/-  1.10
# log(Z_1)   =       301812.82 +/-  1.10 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7169 |
# posteriors |4819 |
# equals     | 184 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4819
# nposterior =                4819
# nequals    =                 184
# nlike      =             1041496
# <nlike>    =         343.97   (           2.69 per slice )
# log(Z)     =       301813.17 +/-  1.10
# log(Z_1)   =       301813.17 +/-  1.10 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8019 |
# posteriors |4880 |
# equals     | 214 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4880
# nposterior =                4880
# nequals    =                 207
# nlike      =             1063551
# <nlike>    =         367.58   (           2.87 per slice )
# log(Z)     =       301813.47 +/-  1.11
# log(Z_1)   =       301813.47 +/-  1.11 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7504 |
# posteriors |4941 |
# equals     | 230 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4941
# nposterior =                4941
# nequals    =                 221
# nlike      =             1082507
# <nlike>    =         315.93   (           2.47 per slice )
# log(Z)     =       301813.74 +/-  1.12
# log(Z_1)   =       301813.74 +/-  1.12 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7311 |
# posteriors |5002 |
# equals     | 254 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5002
# nposterior =                5002
# nequals    =                 241
# nlike      =             1101829
# <nlike>    =         322.03   (           2.52 per slice )
# log(Z)     =       301813.98 +/-  1.12
# log(Z_1)   =       301813.98 +/-  1.12 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6854 |
# posteriors |5063 |
# equals     | 258 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5063
# nposterior =                5063
# nequals    =                 251
# nlike      =             1120331
# <nlike>    =         308.37   (           2.41 per slice )
# log(Z)     =       301814.21 +/-  1.13
# log(Z_1)   =       301814.21 +/-  1.13 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8112 |
# posteriors |5124 |
# equals     | 312 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5124
# nposterior =                5124
# nequals    =                 304
# nlike      =             1140691
# <nlike>    =         339.33   (           2.65 per slice )
# log(Z)     =       301814.41 +/-  1.13
# log(Z_1)   =       301814.41 +/-  1.13 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8947 |
# posteriors |5185 |
# equals     | 356 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5185
# nposterior =                5185
# nequals    =                 350
# nlike      =             1163392
# <nlike>    =         378.35   (           2.96 per slice )
# log(Z)     =       301814.55 +/-  1.13
# log(Z_1)   =       301814.55 +/-  1.13 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |9463 |
# posteriors |5246 |
# equals     | 393 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5246
# nposterior =                5246
# nequals    =                 385
# nlike      =             1181425
# <nlike>    =         300.55   (           2.35 per slice )
# log(Z)     =       301814.65 +/-  1.14
# log(Z_1)   =       301814.65 +/-  1.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8160 |
# posteriors |5307 |
# equals     | 422 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5307
# nposterior =                5307
# nequals    =                 416
# nlike      =             1199005
# <nlike>    =         293.00   (           2.29 per slice )
# log(Z)     =       301814.72 +/-  1.14
# log(Z_1)   =       301814.72 +/-  1.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8795 |
# posteriors |5368 |
# equals     | 454 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5368
# nposterior =                5368
# nequals    =                 454
# nlike      =             1213706
# <nlike>    =         245.02   (           1.91 per slice )
# log(Z)     =       301814.79 +/-  1.14
# log(Z_1)   =       301814.79 +/-  1.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7979 |
# posteriors |5429 |
# equals     | 482 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5429
# nposterior =                5429
# nequals    =                 487
# nlike      =             1227474
# <nlike>    =         229.47   (           1.79 per slice )
# log(Z)     =       301814.85 +/-  1.14
# log(Z_1)   =       301814.85 +/-  1.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7776 |
# posteriors |5490 |
# equals     | 513 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5490
# nposterior =                5490
# nequals    =                 511
# nlike      =             1241945
# <nlike>    =         241.18   (           1.88 per slice )
# log(Z)     =       301814.90 +/-  1.14
# log(Z_1)   =       301814.90 +/-  1.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7281 |
# posteriors |5551 |
# equals     | 531 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5551
# nposterior =                5551
# nequals    =                 533
# nlike      =             1257277
# <nlike>    =         255.53   (           2.00 per slice )
# log(Z)     =       301814.94 +/-  1.14
# log(Z_1)   =       301814.94 +/-  1.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8019 |
# posteriors |5612 |
# equals     | 549 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5612
# nposterior =                5612
# nequals    =                 548
# nlike      =             1272237
# <nlike>    =         249.33   (           1.95 per slice )
# log(Z)     =       301814.97 +/-  1.15
# log(Z_1)   =       301814.97 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8511 |
# posteriors |5673 |
# equals     | 560 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5673
# nposterior =                5673
# nequals    =                 569
# nlike      =             1286636
# <nlike>    =         239.98   (           1.87 per slice )
# log(Z)     =       301815.00 +/-  1.15
# log(Z_1)   =       301815.00 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8667 |
# posteriors |5734 |
# equals     | 572 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5734
# nposterior =                5734
# nequals    =                 579
# nlike      =             1300823
# <nlike>    =         236.45   (           1.85 per slice )
# log(Z)     =       301815.01 +/-  1.15
# log(Z_1)   =       301815.01 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8404 |
# posteriors |5795 |
# equals     | 576 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5795
# nposterior =                5795
# nequals    =                 586
# nlike      =             1315341
# <nlike>    =         241.97   (           1.89 per slice )
# log(Z)     =       301815.02 +/-  1.15
# log(Z_1)   =       301815.02 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7719 |
# posteriors |5856 |
# equals     | 578 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5856
# nposterior =                5856
# nequals    =                 588
# nlike      =             1328860
# <nlike>    =         225.32   (           1.76 per slice )
# log(Z)     =       301815.03 +/-  1.15
# log(Z_1)   =       301815.03 +/-  1.15 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7259 |
# posteriors |5917 |
# equals     | 580 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5917
# nposterior =                5917
# nequals    =                 589
# nlike      =             1341881
# <nlike>    =         217.02   (           1.70 per slice )
# log(Z)     =       301815.03 +/-  1.15
# log(Z_1)   =       301815.03 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7805 |
# posteriors |5978 |
# equals     | 583 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5978
# nposterior =                5978
# nequals    =                 589
# nlike      =             1355544
# <nlike>    =         227.72   (           1.78 per slice )
# log(Z)     =       301815.03 +/-  1.15
# log(Z_1)   =       301815.03 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7846 |
# posteriors |6039 |
# equals     | 583 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6039
# nposterior =                6039
# nequals    =                 591
# nlike      =             1369049
# <nlike>    =         225.08   (           1.76 per slice )
# log(Z)     =       301815.04 +/-  1.15
# log(Z_1)   =       301815.04 +/-  1.15 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =         6156                              |
# | log(Z) =       301815.03777 +/-            1.14853 |
# |____________________________________________________|

# %%
mf_means = means + np.diag(5*covs); mf_covs = 1.2*covs
mf_proposal = sn.gaussian_proposal(bounds.T, mf_means, mf_covs, loglike=control_ll)
settings.file_root = "mf_proposal"
output["mf_proposal"] = pypolychord.run_polychord(mf_proposal.likelihood, len(means), 0, settings, prior=mf_proposal.prior)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.18.2
#   release: 7th April 2020
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :      60
# nDims    :      27
# nDerived :       0
# Generating equally weighted posteriors
# Generating weighted posteriors
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.140E-03 seconds
# number of repeats:          128
# started sampling
#
# _________________
# lives      |  60 |
# phantoms   |5030 |
# posteriors |  61 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                  61
# nposterior =                  61
# nequals    =                   1
# nlike      =                9448
# <nlike>    =         156.47   (           1.22 per slice )
# log(Z)     =      -317926.30 +/-  0.83
# log(Z_1)   =      -317926.30 +/-  0.83 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7377 |
# posteriors | 122 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 122
# nposterior =                 122
# nequals    =                   1
# nlike      =               22394
# <nlike>    =         215.77   (           1.69 per slice )
# log(Z)     =      -264206.92 +/-  0.84
# log(Z_1)   =      -264206.92 +/-  0.84 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7257 |
# posteriors | 183 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 183
# nposterior =                 183
# nequals    =                   1
# nlike      =               35276
# <nlike>    =         214.70   (           1.68 per slice )
# log(Z)     =      -214245.25 +/-  0.85
# log(Z_1)   =      -214245.25 +/-  0.85 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8275 |
# posteriors | 244 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 244
# nposterior =                 244
# nequals    =                   1
# nlike      =               48244
# <nlike>    =         216.13   (           1.69 per slice )
# log(Z)     =      -186103.68 +/-  0.86
# log(Z_1)   =      -186103.68 +/-  0.86 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7389 |
# posteriors | 305 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 305
# nposterior =                 305
# nequals    =                   1
# nlike      =               61223
# <nlike>    =         216.32   (           1.69 per slice )
# log(Z)     =      -154701.00 +/-  0.87
# log(Z_1)   =      -154701.00 +/-  0.87 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7541 |
# posteriors | 366 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 366
# nposterior =                 366
# nequals    =                   1
# nlike      =               76552
# <nlike>    =         255.48   (           2.00 per slice )
# log(Z)     =      -130187.90 +/-  0.88
# log(Z_1)   =      -130187.90 +/-  0.88 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8156 |
# posteriors | 427 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 427
# nposterior =                 427
# nequals    =                   1
# nlike      =               92333
# <nlike>    =         263.02   (           2.05 per slice )
# log(Z)     =      -111940.55 +/-  0.89
# log(Z_1)   =      -111940.55 +/-  0.89 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6893 |
# posteriors | 488 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 488
# nposterior =                 488
# nequals    =                   1
# nlike      =              108032
# <nlike>    =         261.65   (           2.04 per slice )
# log(Z)     =       -87498.57 +/-  0.90
# log(Z_1)   =       -87498.57 +/-  0.90 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7241 |
# posteriors | 549 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 549
# nposterior =                 549
# nequals    =                   1
# nlike      =              124810
# <nlike>    =         279.63   (           2.18 per slice )
# log(Z)     =       -68542.60 +/-  0.87
# log(Z_1)   =       -68542.60 +/-  0.87 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8327 |
# posteriors | 610 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 610
# nposterior =                 610
# nequals    =                   1
# nlike      =              141707
# <nlike>    =         281.62   (           2.20 per slice )
# log(Z)     =       -54040.33 +/-  0.92
# log(Z_1)   =       -54040.33 +/-  0.92 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8045 |
# posteriors | 671 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 671
# nposterior =                 671
# nequals    =                   1
# nlike      =              159814
# <nlike>    =         301.78   (           2.36 per slice )
# log(Z)     =       -39087.90 +/-  0.93
# log(Z_1)   =       -39087.90 +/-  0.93 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7500 |
# posteriors | 732 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 732
# nposterior =                 732
# nequals    =                   1
# nlike      =              179494
# <nlike>    =         328.00   (           2.56 per slice )
# log(Z)     =       -24095.52 +/-  0.93
# log(Z_1)   =       -24095.52 +/-  0.93 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8529 |
# posteriors | 793 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 793
# nposterior =                 793
# nequals    =                   1
# nlike      =              200884
# <nlike>    =         356.50   (           2.79 per slice )
# log(Z)     =       -11231.33 +/-  0.94
# log(Z_1)   =       -11231.33 +/-  0.94 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8817 |
# posteriors | 854 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 854
# nposterior =                 854
# nequals    =                   1
# nlike      =              220948
# <nlike>    =         334.40   (           2.61 per slice )
# log(Z)     =            6.57 +/-  0.95
# log(Z_1)   =            6.57 +/-  0.95 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8387 |
# posteriors | 915 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 915
# nposterior =                 915
# nequals    =                   1
# nlike      =              246878
# <nlike>    =         432.17   (           3.38 per slice )
# log(Z)     =        13130.72 +/-  0.96
# log(Z_1)   =        13130.72 +/-  0.96 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7966 |
# posteriors | 976 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 976
# nposterior =                 976
# nequals    =                   1
# nlike      =              267872
# <nlike>    =         349.90   (           2.73 per slice )
# log(Z)     =        25403.78 +/-  0.97
# log(Z_1)   =        25403.78 +/-  0.97 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8487 |
# posteriors |1037 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1037
# nposterior =                1037
# nequals    =                   1
# nlike      =              289179
# <nlike>    =         355.12   (           2.77 per slice )
# log(Z)     =        36320.93 +/-  0.98
# log(Z_1)   =        36320.93 +/-  0.98 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8989 |
# posteriors |1098 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1098
# nposterior =                1098
# nequals    =                   1
# nlike      =              310604
# <nlike>    =         357.08   (           2.79 per slice )
# log(Z)     =        46130.12 +/-  0.99
# log(Z_1)   =        46130.12 +/-  0.99 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |8063 |
# posteriors |1159 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1159
# nposterior =                1159
# nequals    =                   1
# nlike      =              331232
# <nlike>    =         343.80   (           2.69 per slice )
# log(Z)     =        58897.47 +/-  0.99
# log(Z_1)   =        58897.47 +/-  0.99 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8082 |
# posteriors |1220 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1220
# nposterior =                1220
# nequals    =                   1
# nlike      =              355362
# <nlike>    =         402.17   (           3.14 per slice )
# log(Z)     =        69645.39 +/-  1.00
# log(Z_1)   =        69645.39 +/-  1.00 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8409 |
# posteriors |1281 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1281
# nposterior =                1281
# nequals    =                   1
# nlike      =              378081
# <nlike>    =         378.65   (           2.96 per slice )
# log(Z)     =        80342.45 +/-  1.01
# log(Z_1)   =        80342.45 +/-  1.01 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8204 |
# posteriors |1342 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1342
# nposterior =                1342
# nequals    =                   1
# nlike      =              403285
# <nlike>    =         420.07   (           3.28 per slice )
# log(Z)     =        91379.64 +/-  1.02
# log(Z_1)   =        91379.64 +/-  1.02 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8280 |
# posteriors |1403 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1403
# nposterior =                1403
# nequals    =                   1
# nlike      =              435347
# <nlike>    =         534.37   (           4.17 per slice )
# log(Z)     =       101334.72 +/-  1.03
# log(Z_1)   =       101334.72 +/-  1.03 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7646 |
# posteriors |1464 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1464
# nposterior =                1464
# nequals    =                   1
# nlike      =              464522
# <nlike>    =         486.25   (           3.80 per slice )
# log(Z)     =       111093.49 +/-  1.03
# log(Z_1)   =       111093.49 +/-  1.03 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7037 |
# posteriors |1525 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1525
# nposterior =                1525
# nequals    =                   1
# nlike      =              496302
# <nlike>    =         529.67   (           4.14 per slice )
# log(Z)     =       121159.73 +/-  1.04
# log(Z_1)   =       121159.73 +/-  1.04 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6430 |
# posteriors |1586 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1586
# nposterior =                1586
# nequals    =                   1
# nlike      =              526188
# <nlike>    =         498.10   (           3.89 per slice )
# log(Z)     =       133073.24 +/-  1.05
# log(Z_1)   =       133073.24 +/-  1.05 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7871 |
# posteriors |1647 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1647
# nposterior =                1647
# nequals    =                   1
# nlike      =              559402
# <nlike>    =         553.57   (           4.32 per slice )
# log(Z)     =       141498.60 +/-  1.06
# log(Z_1)   =       141498.60 +/-  1.06 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7691 |
# posteriors |1708 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1708
# nposterior =                1708
# nequals    =                   1
# nlike      =              590456
# <nlike>    =         517.57   (           4.04 per slice )
# log(Z)     =       150565.55 +/-  1.07
# log(Z_1)   =       150565.55 +/-  1.07 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7679 |
# posteriors |1769 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1769
# nposterior =                1769
# nequals    =                   1
# nlike      =              619389
# <nlike>    =         482.22   (           3.77 per slice )
# log(Z)     =       160218.27 +/-  1.07
# log(Z_1)   =       160218.27 +/-  1.07 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8046 |
# posteriors |1830 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1830
# nposterior =                1830
# nequals    =                   1
# nlike      =              652919
# <nlike>    =         558.83   (           4.37 per slice )
# log(Z)     =       168629.49 +/-  1.08
# log(Z_1)   =       168629.49 +/-  1.08 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8063 |
# posteriors |1891 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1891
# nposterior =                1891
# nequals    =                   1
# nlike      =              683609
# <nlike>    =         511.50   (           4.00 per slice )
# log(Z)     =       177292.54 +/-  1.09
# log(Z_1)   =       177292.54 +/-  1.09 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7766 |
# posteriors |1952 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1952
# nposterior =                1952
# nequals    =                   1
# nlike      =              720678
# <nlike>    =         617.82   (           4.83 per slice )
# log(Z)     =       186430.48 +/-  1.10
# log(Z_1)   =       186430.48 +/-  1.10 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7345 |
# posteriors |2013 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2013
# nposterior =                2013
# nequals    =                   1
# nlike      =              756897
# <nlike>    =         603.65   (           4.72 per slice )
# log(Z)     =       194902.70 +/-  1.10
# log(Z_1)   =       194902.70 +/-  1.10 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7151 |
# posteriors |2074 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2074
# nposterior =                2074
# nequals    =                   1
# nlike      =              791460
# <nlike>    =         576.05   (           4.50 per slice )
# log(Z)     =       204453.18 +/-  1.11
# log(Z_1)   =       204453.18 +/-  1.11 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7614 |
# posteriors |2135 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2135
# nposterior =                2135
# nequals    =                   1
# nlike      =              828557
# <nlike>    =         618.28   (           4.83 per slice )
# log(Z)     =       213109.31 +/-  1.12
# log(Z_1)   =       213109.31 +/-  1.12 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7186 |
# posteriors |2196 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2196
# nposterior =                2196
# nequals    =                   1
# nlike      =              866927
# <nlike>    =         639.50   (           5.00 per slice )
# log(Z)     =       221979.25 +/-  1.12
# log(Z_1)   =       221979.25 +/-  1.12 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7478 |
# posteriors |2257 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2257
# nposterior =                2257
# nequals    =                   1
# nlike      =              902252
# <nlike>    =         588.75   (           4.60 per slice )
# log(Z)     =       229692.17 +/-  1.13
# log(Z_1)   =       229692.17 +/-  1.13 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7397 |
# posteriors |2318 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2318
# nposterior =                2318
# nequals    =                   1
# nlike      =              933877
# <nlike>    =         527.08   (           4.12 per slice )
# log(Z)     =       237113.40 +/-  1.14
# log(Z_1)   =       237113.40 +/-  1.14 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6622 |
# posteriors |2379 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2379
# nposterior =                2379
# nequals    =                   1
# nlike      =              977271
# <nlike>    =         723.23   (           5.65 per slice )
# log(Z)     =       245881.33 +/-  1.15
# log(Z_1)   =       245881.33 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8039 |
# posteriors |2440 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2440
# nposterior =                2440
# nequals    =                   1
# nlike      =             1018225
# <nlike>    =         682.57   (           5.33 per slice )
# log(Z)     =       252387.95 +/-  1.15
# log(Z_1)   =       252387.95 +/-  1.15 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |9199 |
# posteriors |2501 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2501
# nposterior =                2501
# nequals    =                   1
# nlike      =             1064170
# <nlike>    =         765.75   (           5.98 per slice )
# log(Z)     =       257874.41 +/-  1.16
# log(Z_1)   =       257874.41 +/-  1.16 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8864 |
# posteriors |2562 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2562
# nposterior =                2562
# nequals    =                   1
# nlike      =             1110272
# <nlike>    =         768.37   (           6.00 per slice )
# log(Z)     =       263856.34 +/-  1.17
# log(Z_1)   =       263856.34 +/-  1.17 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8552 |
# posteriors |2623 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2623
# nposterior =                2623
# nequals    =                   1
# nlike      =             1153396
# <nlike>    =         718.73   (           5.62 per slice )
# log(Z)     =       269674.29 +/-  1.18
# log(Z_1)   =       269674.29 +/-  1.18 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8712 |
# posteriors |2684 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2684
# nposterior =                2684
# nequals    =                   1
# nlike      =             1201432
# <nlike>    =         800.60   (           6.25 per slice )
# log(Z)     =       274805.64 +/-  1.18
# log(Z_1)   =       274805.64 +/-  1.18 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8110 |
# posteriors |2745 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2745
# nposterior =                2745
# nequals    =                   1
# nlike      =             1248611
# <nlike>    =         786.32   (           6.14 per slice )
# log(Z)     =       282038.17 +/-  1.19
# log(Z_1)   =       282038.17 +/-  1.19 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7706 |
# posteriors |2806 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2806
# nposterior =                2806
# nequals    =                   1
# nlike      =             1290852
# <nlike>    =         704.02   (           5.50 per slice )
# log(Z)     =       289252.97 +/-  1.20
# log(Z_1)   =       289252.97 +/-  1.20 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7290 |
# posteriors |2867 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2867
# nposterior =                2867
# nequals    =                   1
# nlike      =             1332351
# <nlike>    =         691.65   (           5.40 per slice )
# log(Z)     =       296983.97 +/-  1.20
# log(Z_1)   =       296983.97 +/-  1.20 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7346 |
# posteriors |2928 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2928
# nposterior =                2928
# nequals    =                   1
# nlike      =             1377367
# <nlike>    =         750.27   (           5.86 per slice )
# log(Z)     =       303560.50 +/-  1.21
# log(Z_1)   =       303560.50 +/-  1.21 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8001 |
# posteriors |2989 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2989
# nposterior =                2989
# nequals    =                   1
# nlike      =             1415271
# <nlike>    =         631.73   (           4.94 per slice )
# log(Z)     =       309546.12 +/-  1.22
# log(Z_1)   =       309546.12 +/-  1.22 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8175 |
# posteriors |3050 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3050
# nposterior =                3050
# nequals    =                   1
# nlike      =             1453285
# <nlike>    =         633.57   (           4.95 per slice )
# log(Z)     =       315606.31 +/-  1.22
# log(Z_1)   =       315606.31 +/-  1.22 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8377 |
# posteriors |3111 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3111
# nposterior =                3111
# nequals    =                   1
# nlike      =             1491791
# <nlike>    =         641.77   (           5.01 per slice )
# log(Z)     =       321836.26 +/-  1.23
# log(Z_1)   =       321836.26 +/-  1.23 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7871 |
# posteriors |3172 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3172
# nposterior =                3172
# nequals    =                   1
# nlike      =             1530442
# <nlike>    =         644.18   (           5.03 per slice )
# log(Z)     =       328851.38 +/-  1.24
# log(Z_1)   =       328851.38 +/-  1.24 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7695 |
# posteriors |3233 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3233
# nposterior =                3233
# nequals    =                   1
# nlike      =             1567624
# <nlike>    =         619.70   (           4.84 per slice )
# log(Z)     =       335650.98 +/-  1.24
# log(Z_1)   =       335650.98 +/-  1.24 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7580 |
# posteriors |3294 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3294
# nposterior =                3294
# nequals    =                   1
# nlike      =             1605147
# <nlike>    =         625.38   (           4.89 per slice )
# log(Z)     =       341955.54 +/-  1.25
# log(Z_1)   =       341955.54 +/-  1.25 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8168 |
# posteriors |3355 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3355
# nposterior =                3355
# nequals    =                   1
# nlike      =             1646532
# <nlike>    =         689.75   (           5.39 per slice )
# log(Z)     =       347815.60 +/-  1.26
# log(Z_1)   =       347815.60 +/-  1.26 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8706 |
# posteriors |3416 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3416
# nposterior =                3416
# nequals    =                   1
# nlike      =             1683468
# <nlike>    =         615.60   (           4.81 per slice )
# log(Z)     =       353086.76 +/-  1.17
# log(Z_1)   =       353086.76 +/-  1.17 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |8537 |
# posteriors |3477 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3477
# nposterior =                3477
# nequals    =                   1
# nlike      =             1723548
# <nlike>    =         668.00   (           5.22 per slice )
# log(Z)     =       358083.64 +/-  1.27
# log(Z_1)   =       358083.64 +/-  1.27 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8594 |
# posteriors |3538 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3538
# nposterior =                3538
# nequals    =                   1
# nlike      =             1758977
# <nlike>    =         590.48   (           4.61 per slice )
# log(Z)     =       363403.46 +/-  1.28
# log(Z_1)   =       363403.46 +/-  1.28 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8611 |
# posteriors |3599 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3599
# nposterior =                3599
# nequals    =                   1
# nlike      =             1805011
# <nlike>    =         767.23   (           5.99 per slice )
# log(Z)     =       368539.21 +/-  1.26
# log(Z_1)   =       368539.21 +/-  1.26 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7712 |
# posteriors |3660 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3660
# nposterior =                3660
# nequals    =                   1
# nlike      =             1851152
# <nlike>    =         769.02   (           6.01 per slice )
# log(Z)     =       374212.26 +/-  1.29
# log(Z_1)   =       374212.26 +/-  1.29 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7913 |
# posteriors |3721 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3721
# nposterior =                3721
# nequals    =                   1
# nlike      =             1898538
# <nlike>    =         789.77   (           6.17 per slice )
# log(Z)     =       379156.28 +/-  1.29
# log(Z_1)   =       379156.28 +/-  1.29 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7323 |
# posteriors |3782 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3782
# nposterior =                3782
# nequals    =                   1
# nlike      =             1947884
# <nlike>    =         822.43   (           6.43 per slice )
# log(Z)     =       384205.24 +/-  1.30
# log(Z_1)   =       384205.24 +/-  1.30 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7931 |
# posteriors |3843 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3843
# nposterior =                3843
# nequals    =                   1
# nlike      =             2000096
# <nlike>    =         870.20   (           6.80 per slice )
# log(Z)     =       388669.38 +/-  1.31
# log(Z_1)   =       388669.38 +/-  1.31 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8827 |
# posteriors |3904 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3904
# nposterior =                3904
# nequals    =                   1
# nlike      =             2100513
# <nlike>    =        1673.62   (          13.08 per slice )
# log(Z)     =       392515.72 +/-  1.31
# log(Z_1)   =       392515.72 +/-  1.31 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6981 |
# posteriors |3965 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3965
# nposterior =                3965
# nequals    =                   1
# nlike      =             2152416
# <nlike>    =         865.05   (           6.76 per slice )
# log(Z)     =       398465.33 +/-  1.32
# log(Z_1)   =       398465.33 +/-  1.32 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7800 |
# posteriors |4026 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4026
# nposterior =                4026
# nequals    =                   1
# nlike      =             2208556
# <nlike>    =         935.67   (           7.31 per slice )
# log(Z)     =       403066.79 +/-  1.33
# log(Z_1)   =       403066.79 +/-  1.33 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6833 |
# posteriors |4087 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4087
# nposterior =                4087
# nequals    =                   1
# nlike      =             2336799
# <nlike>    =        2137.38   (          16.70 per slice )
# log(Z)     =       408690.24 +/-  1.33
# log(Z_1)   =       408690.24 +/-  1.33 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7084 |
# posteriors |4148 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4148
# nposterior =                4148
# nequals    =                   1
# nlike      =             2476630
# <nlike>    =        2330.52   (          18.21 per slice )
# log(Z)     =       413285.40 +/-  1.34
# log(Z_1)   =       413285.40 +/-  1.34 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7805 |
# posteriors |4209 |
# equals     |   9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4209
# nposterior =                4209
# nequals    =                   7
# nlike      =             2624896
# <nlike>    =        2471.10   (          19.31 per slice )
# log(Z)     =       416680.22 +/-  1.10
# log(Z_1)   =       416680.22 +/-  1.10 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7500 |
# posteriors |4270 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4270
# nposterior =                4270
# nequals    =                   1
# nlike      =             2760078
# <nlike>    =        2253.03   (          17.60 per slice )
# log(Z)     =       420815.89 +/-  1.35
# log(Z_1)   =       420815.89 +/-  1.35 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8447 |
# posteriors |4331 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4331
# nposterior =                4331
# nequals    =                   1
# nlike      =             2884062
# <nlike>    =        2066.40   (          16.14 per slice )
# log(Z)     =       424274.44 +/-  1.36
# log(Z_1)   =       424274.44 +/-  1.36 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7858 |
# posteriors |4392 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4392
# nposterior =                4392
# nequals    =                   1
# nlike      =             3009533
# <nlike>    =        2091.18   (          16.34 per slice )
# log(Z)     =       428698.07 +/-  1.36
# log(Z_1)   =       428698.07 +/-  1.36 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6756 |
# posteriors |4453 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4453
# nposterior =                4453
# nequals    =                   1
# nlike      =             3134116
# <nlike>    =        2076.38   (          16.22 per slice )
# log(Z)     =       433526.48 +/-  1.37
# log(Z_1)   =       433526.48 +/-  1.37 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7556 |
# posteriors |4514 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4514
# nposterior =                4514
# nequals    =                   2
# nlike      =             3258907
# <nlike>    =        2079.85   (          16.25 per slice )
# log(Z)     =       437339.08 +/-  1.27
# log(Z_1)   =       437339.08 +/-  1.27 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# _________________
# lives      |  60 |
# phantoms   |7096 |
# posteriors |4575 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4575
# nposterior =                4575
# nequals    =                   2
# nlike      =             3394221
# <nlike>    =        2255.23   (          17.62 per slice )
# log(Z)     =       441632.87 +/-  1.27
# log(Z_1)   =       441632.87 +/-  1.27 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7251 |
# posteriors |4636 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4636
# nposterior =                4636
# nequals    =                   1
# nlike      =             3528073
# <nlike>    =        2230.87   (          17.43 per slice )
# log(Z)     =       445863.40 +/-  1.39
# log(Z_1)   =       445863.40 +/-  1.39 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7109 |
# posteriors |4697 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4697
# nposterior =                4697
# nequals    =                   1
# nlike      =             3660225
# <nlike>    =        2202.53   (          17.21 per slice )
# log(Z)     =       448532.52 +/-  1.39
# log(Z_1)   =       448532.52 +/-  1.39 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7761 |
# posteriors |4758 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4758
# nposterior =                4758
# nequals    =                   1
# nlike      =             3786420
# <nlike>    =        2103.25   (          16.43 per slice )
# log(Z)     =       452586.61 +/-  1.40
# log(Z_1)   =       452586.61 +/-  1.40 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7420 |
# posteriors |4819 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4819
# nposterior =                4819
# nequals    =                   1
# nlike      =             3917399
# <nlike>    =        2182.98   (          17.05 per slice )
# log(Z)     =       456406.58 +/-  1.40
# log(Z_1)   =       456406.58 +/-  1.40 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8109 |
# posteriors |4880 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4880
# nposterior =                4880
# nequals    =                   1
# nlike      =             4055368
# <nlike>    =        2299.48   (          17.96 per slice )
# log(Z)     =       459388.83 +/-  1.41
# log(Z_1)   =       459388.83 +/-  1.41 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6969 |
# posteriors |4941 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4941
# nposterior =                4941
# nequals    =                   1
# nlike      =             4186250
# <nlike>    =        2181.37   (          17.04 per slice )
# log(Z)     =       463048.19 +/-  1.42
# log(Z_1)   =       463048.19 +/-  1.42 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# _________________
# lives      |  60 |
# phantoms   |7232 |
# posteriors |5002 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5002
# nposterior =                5002
# nequals    =                   1
# nlike      =             4320459
# <nlike>    =        2236.82   (          17.48 per slice )
# log(Z)     =       466766.69 +/-  1.42
# log(Z_1)   =       466766.69 +/-  1.42 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7689 |
# posteriors |5063 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5063
# nposterior =                5063
# nequals    =                   1
# nlike      =             4448159
# <nlike>    =        2128.33   (          16.63 per slice )
# log(Z)     =       468853.46 +/-  1.43
# log(Z_1)   =       468853.46 +/-  1.43 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7818 |
# posteriors |5124 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5124
# nposterior =                5124
# nequals    =                   1
# nlike      =             4572189
# <nlike>    =        2067.17   (          16.15 per slice )
# log(Z)     =       472155.60 +/-  1.43
# log(Z_1)   =       472155.60 +/-  1.43 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8557 |
# posteriors |5185 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5185
# nposterior =                5185
# nequals    =                   1
# nlike      =             4703271
# <nlike>    =        2184.70   (          17.07 per slice )
# log(Z)     =       475020.04 +/-  1.44
# log(Z_1)   =       475020.04 +/-  1.44 (still evaluating)
# /mnt/Archive/Git/sspr/supernest/core.py:180: RuntimeWarning: invalid value encountered in matmul
#   theta = mean + covmat @ theta
# _________________
# lives      |  60 |
# phantoms   |8403 |
# posteriors |5246 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5246
# nposterior =                5246
# nequals    =                   1
# nlike      =             4831033
# <nlike>    =        2129.37   (          16.64 per slice )
# log(Z)     =       477333.44 +/-  1.44
# log(Z_1)   =       477333.44 +/-  1.44 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7943 |
# posteriors |5307 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5307
# nposterior =                5307
# nequals    =                   1
# nlike      =             4953657
# <nlike>    =        2043.73   (          15.97 per slice )
# log(Z)     =       480187.66 +/-  1.45
# log(Z_1)   =       480187.66 +/-  1.45 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7822 |
# posteriors |5368 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5368
# nposterior =                5368
# nequals    =                   1
# nlike      =             5075634
# <nlike>    =        2032.95   (          15.88 per slice )
# log(Z)     =       482861.86 +/-  1.46
# log(Z_1)   =       482861.86 +/-  1.46 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8327 |
# posteriors |5429 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5429
# nposterior =                5429
# nequals    =                   1
# nlike      =             5196547
# <nlike>    =        2015.22   (          15.74 per slice )
# log(Z)     =       485456.49 +/-  1.46
# log(Z_1)   =       485456.49 +/-  1.46 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7803 |
# posteriors |5490 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5490
# nposterior =                5490
# nequals    =                   1
# nlike      =             5316801
# <nlike>    =        2004.23   (          15.66 per slice )
# log(Z)     =       488504.68 +/-  1.47
# log(Z_1)   =       488504.68 +/-  1.47 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7228 |
# posteriors |5551 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5551
# nposterior =                5551
# nequals    =                   1
# nlike      =             5436796
# <nlike>    =        1999.92   (          15.62 per slice )
# log(Z)     =       491640.43 +/-  1.47
# log(Z_1)   =       491640.43 +/-  1.47 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7125 |
# posteriors |5612 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5612
# nposterior =                5612
# nequals    =                   1
# nlike      =             5555919
# <nlike>    =        1985.38   (          15.51 per slice )
# log(Z)     =       494081.57 +/-  1.48
# log(Z_1)   =       494081.57 +/-  1.48 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7764 |
# posteriors |5673 |
# equals     |  32 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5673
# nposterior =                5673
# nequals    =                  33
# nlike      =             5676617
# <nlike>    =        2011.63   (          15.72 per slice )
# log(Z)     =       495429.04 +/-  1.23
# log(Z_1)   =       495429.04 +/-  1.23 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7927 |
# posteriors |5734 |
# equals     |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5734
# nposterior =                5734
# nequals    =                   3
# nlike      =             5794262
# <nlike>    =        1960.75   (          15.32 per slice )
# log(Z)     =       497645.96 +/-  1.35
# log(Z_1)   =       497645.96 +/-  1.35 (still evaluating)
#
#
#
#  too many R steps (       138)
# _________________
# lives      |  60 |
# phantoms   |8242 |
# posteriors |5795 |
# equals     |   9 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5795
# nposterior =                5795
# nequals    =                   9
# nlike      =             5837797
# <nlike>    =         725.58   (           5.67 per slice )
# log(Z)     =       499628.74 +/-  1.28
# log(Z_1)   =       499628.74 +/-  1.28 (still evaluating)
#
#
#
#  too many R steps (       119)
#  too many R steps (       152)
#  too many R steps (       112)
#  too many L steps (       124)
#  too many L steps (       104)
#  too many L steps (       128)
# _________________
# lives      |  60 |
# phantoms   |6954 |
# posteriors |5856 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5856
# nposterior =                5856
# nequals    =                   1
# nlike      =             5887436
# <nlike>    =         827.32   (           6.46 per slice )
# log(Z)     =       502372.53 +/-  1.50
# log(Z_1)   =       502372.53 +/-  1.50 (still evaluating)
#
#
#
#  too many L steps (       114)
#  too many L steps (       138)
#  too many R steps (       113)
# _________________
# lives      |  60 |
# phantoms   |8216 |
# posteriors |5917 |
# equals     |   7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5917
# nposterior =                5917
# nequals    =                  10
# nlike      =             5950555
# <nlike>    =        1051.98   (           8.22 per slice )
# log(Z)     =       504499.46 +/-  1.29
# log(Z_1)   =       504499.46 +/-  1.29 (still evaluating)
#
#
#
#  too many L steps (       110)
#  too many R steps (       127)
#  too many R steps (       118)
#  too many R steps (       139)
#  too many L steps (       138)
#  too many R steps (       168)
#  too many L steps (       194)
#  too many L steps (       102)
# _________________
# lives      |  60 |
# phantoms   |7230 |
# posteriors |5978 |
# equals     |  33 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5978
# nposterior =                5978
# nequals    =                  34
# nlike      =             6023993
# <nlike>    =        1223.97   (           9.56 per slice )
# log(Z)     =       504502.20 +/-  1.26
# log(Z_1)   =       504502.20 +/-  1.26 (still evaluating)
#
#
#
#  too many L steps (       331)
#  too many R steps (       136)
#  too many L steps (       119)
#  too many L steps (       185)
#  too many L steps (       198)
# _________________
# lives      |  60 |
# phantoms   |7512 |
# posteriors |6039 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6039
# nposterior =                6039
# nequals    =                   3
# nlike      =             6098227
# <nlike>    =        1237.23   (           9.67 per slice )
# log(Z)     =       504540.60 +/-  1.39
# log(Z_1)   =       504540.60 +/-  1.39 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6676 |
# posteriors |6100 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6100
# nposterior =                6100
# nequals    =                   1
# nlike      =             6139452
# <nlike>    =         687.08   (           5.37 per slice )
# log(Z)     =       505403.06 +/-  1.52
# log(Z_1)   =       505403.06 +/-  1.52 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7343 |
# posteriors |6161 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6161
# nposterior =                6161
# nequals    =                   1
# nlike      =             6165420
# <nlike>    =         432.80   (           3.38 per slice )
# log(Z)     =       508258.49 +/-  1.53
# log(Z_1)   =       508258.49 +/-  1.53 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7202 |
# posteriors |6222 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6222
# nposterior =                6222
# nequals    =                   1
# nlike      =             6192466
# <nlike>    =         450.77   (           3.52 per slice )
# log(Z)     =       511833.13 +/-  1.53
# log(Z_1)   =       511833.13 +/-  1.53 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |8361 |
# posteriors |6283 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6283
# nposterior =                6283
# nequals    =                   1
# nlike      =             6217955
# <nlike>    =         424.82   (           3.32 per slice )
# log(Z)     =       514587.06 +/-  1.52
# log(Z_1)   =       514587.06 +/-  1.52 (still evaluating)
# _________________
# lives      |  60 |
# phantoms   |7145 |
# posteriors |6344 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6344
# nposterior =                6344
# nequals    =                   1
# nlike      =             6241037
# <nlike>    =         384.70   (           3.01 per slice )
# log(Z)     =       519125.06 +/-  1.54
# log(Z_1)   =       519125.06 +/-  1.54 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6729 |
# posteriors |6405 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6405
# nposterior =                6405
# nequals    =                   1
# nlike      =             6264142
# <nlike>    =         385.08   (           3.01 per slice )
# log(Z)     =       523980.54 +/-  1.55
# log(Z_1)   =       523980.54 +/-  1.55 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7250 |
# posteriors |6466 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6466
# nposterior =                6466
# nequals    =                   1
# nlike      =             6288910
# <nlike>    =         412.80   (           3.23 per slice )
# log(Z)     =       528439.78 +/-  1.55
# log(Z_1)   =       528439.78 +/-  1.55 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |7690 |
# posteriors |6527 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6527
# nposterior =                6527
# nequals    =                   2
# nlike      =             6318938
# <nlike>    =         500.47   (           3.91 per slice )
# log(Z)     =       532518.94 +/-  1.48
# log(Z_1)   =       532518.94 +/-  1.48 (still evaluating)
#
#
#
# _________________
# lives      |  60 |
# phantoms   |6673 |
# ...
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 7986 |
# posteriors |18178 |
# equals     |    4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18178
# nposterior =               18178
# nequals    =                   2
# nlike      =            12916486
# <nlike>    =         319.23   (           2.49 per slice )
# log(Z)     =       722531.58 +/-  2.25
# log(Z_1)   =       722531.58 +/-  2.25 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 8530 |
# posteriors |18239 |
# equals     |   18 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18239
# nposterior =               18239
# nequals    =                  15
# nlike      =            12935910
# <nlike>    =         323.73   (           2.53 per slice )
# log(Z)     =       722536.97 +/-  2.21
# log(Z_1)   =       722536.97 +/-  2.21 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 7089 |
# posteriors |18300 |
# equals     |   26 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18300
# nposterior =               18300
# nequals    =                  27
# nlike      =            12955114
# <nlike>    =         320.07   (           2.50 per slice )
# log(Z)     =       722539.96 +/-  2.22
# log(Z_1)   =       722539.96 +/-  2.22 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 6251 |
# posteriors |18361 |
# equals     |   15 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18361
# nposterior =               18361
# nequals    =                  15
# nlike      =            12973076
# <nlike>    =         299.37   (           2.34 per slice )
# log(Z)     =       722543.86 +/-  2.23
# log(Z_1)   =       722543.86 +/-  2.23 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 7295 |
# posteriors |18422 |
# equals     |   12 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18422
# nposterior =               18422
# nequals    =                  17
# nlike      =            12991252
# <nlike>    =         302.93   (           2.37 per slice )
# log(Z)     =       722548.36 +/-  2.23
# log(Z_1)   =       722548.36 +/-  2.23 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 7002 |
# posteriors |18483 |
# equals     |   19 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18483
# nposterior =               18483
# nequals    =                  21
# nlike      =            13009906
# <nlike>    =         310.90   (           2.43 per slice )
# log(Z)     =       722555.41 +/-  2.23
# log(Z_1)   =       722555.41 +/-  2.23 (still evaluating)
#
#
#
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# Polychord Warning: Non deterministic loglikelihood
# __________________
# lives      |   60 |
# phantoms   | 6705 |
# posteriors |18544 |
# equals     |   20 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18544
# nposterior =               18544
# nequals    =                  19
# nlike      =            13027542
# <nlike>    =         293.93   (           2.30 per slice )
# log(Z)     =       722567.53 +/-  2.24
# log(Z_1)   =       722567.53 +/-  2.24 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 7434 |
# posteriors |18605 |
# equals     |   39 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18605
# nposterior =               18605
# nequals    =                  35
# nlike      =            13045640
# <nlike>    =         301.63   (           2.36 per slice )
# log(Z)     =       722575.08 +/-  2.23
# log(Z_1)   =       722575.08 +/-  2.23 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 7611 |
# posteriors |18666 |
# equals     |   36 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18666
# nposterior =               18666
# nequals    =                  40
# nlike      =            13064319
# <nlike>    =         311.32   (           2.43 per slice )
# log(Z)     =       722587.11 +/-  2.24
# log(Z_1)   =       722587.11 +/-  2.24 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 7014 |
# posteriors |18727 |
# equals     |   53 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18727
# nposterior =               18727
# nequals    =                  49
# nlike      =            13098622
# <nlike>    =         571.72   (           4.47 per slice )
# log(Z)     =       722587.43 +/-  2.24
# log(Z_1)   =       722587.43 +/-  2.24 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 6663 |
# posteriors |18788 |
# equals     |   60 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18788
# nposterior =               18788
# nequals    =                  54
# nlike      =            13131786
# <nlike>    =         552.73   (           4.32 per slice )
# log(Z)     =       722587.53 +/-  2.24
# log(Z_1)   =       722587.53 +/-  2.24 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 6873 |
# posteriors |18849 |
# equals     |   63 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18849
# nposterior =               18849
# nequals    =                  58
# nlike      =            13165221
# <nlike>    =         557.25   (           4.35 per slice )
# log(Z)     =       722587.56 +/-  2.24
# log(Z_1)   =       722587.56 +/-  2.24 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 7125 |
# posteriors |18910 |
# equals     |   64 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18910
# nposterior =               18910
# nequals    =                  60
# nlike      =            13199202
# <nlike>    =         566.35   (           4.42 per slice )
# log(Z)     =       722587.57 +/-  2.24
# log(Z_1)   =       722587.57 +/-  2.24 (still evaluating)
#
#
#
# __________________
# lives      |   60 |
# phantoms   | 6762 |
# posteriors |18971 |
# equals     |   65 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =               18971
# nposterior =               18971
# nequals    =                  60
# nlike      =            13233374
# <nlike>    =         569.53   (           4.45 per slice )
# log(Z)     =       722587.58 +/-  2.24
# log(Z_1)   =       722587.58 +/-  2.24 (still evaluating)
#
#
#
#  ____________________________________________________
# |                                                    |
# | ndead  =        19084                              |
# | log(Z) =       722587.58003 +/-            2.23628 |
# |____________________________________________________|

# %%
(output["mf_proposal"].logZ  - logZ_expected) / output["mf_proposal"].logZerr
# Out:
# 323132.12751994433

# %% [markdown]
# ## Stochastic Superpositional Isometric (model) Mixtures

# %% [markdown]
# There is, however, a method of putting the uniform prior and the proposal on equal footing within the same sampling run, that uses the proposal only where it can speed things up, but falls back to the uniform prior where it makes sense to do so. This step is the Stochastic Superposition-al Isometric (model) Mixture SSIM, and the namesake of `supernest`.
